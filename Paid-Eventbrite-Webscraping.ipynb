# %% [markdown]
# #### Francesca Logiacco and Hilal Işık
#
# # Final Project
# This project is created and shared by the mentioned authors,
# with each joint author enjoying an equal interest in the undivided whole.
#
#
# ## Goal: 'Find best fitting activity for a Summer Day in Berlin-2022'
#
# We want to give the best summer 2022(may-august) activity tipp according to the interests and max budget information of the user. For that purpose we are going to combine different sources:
#
# 1- Eventbrite
# - Using the Webscraping method to download the free and paid event information.
#
# 2- Gratis-in-Berlin
# - Using the Webscraping method to download the event information.
#
# 3- Parks and Lakes in Berlin
# - Preparing csv files with the info from Berlin Bezirksamt and Visit Berlin websites.

# %% [markdown]
# #### This Notebook contain the Webscraping of the PAID events from EventBrite

# %% [markdown]
# # Web Scraping EventBrite

# %%
# Import Lybraries and get the url

import sys
from bs4 import BeautifulSoup
import pandas as pd
import requests
import numpy as np
import random

# %% [markdown]
# ### NO-FREE Events from Eventbrite in Berlin;
# ### Month: MAY;
# ### Category: MUSIC.
# Link from eventbrite selecting the not-free events in May_Category: MUSIC (M)

# %%
url = 'https://www.eventbrite.com/d/germany--berlin/music--events--this-month/paid-events/?page=1'

# %%
Events_May_M = requests.get(url)
Events_May_M.content
# Out:
# b'\n\n\n\n\n\n\n<!DOCTYPE html>\n    <html xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://ogp.me/ns/fb#" lang="en-us" translate="no">\n\n    <head>\n        <title>\n    Berlin, Germany Paid Events This Month | Eventbrite\n</title>\n\n        <meta charset="utf-8" />\n        <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n        <meta http-equiv="Content-Language" content="en" />\n        \n\n    <link rel="icon" type="image/png" href="https://cdn.evbstatic.com/s3-build/484486-rc2022-05-19_16.04-072aa9e/django/images/favicons/favicon-32x32.png" sizes="32x32">\n    <link rel="icon" type="image/png" href="https://cdn.evbstatic.com/s3-build/484486-rc2022-05-19_16.04-072aa9e/django/images/favicons/favicon-194x194.png" sizes="194x194">\n    <link rel="icon" type="image/png" href="https://cdn.evbstatic.com/s3-build/484486-rc2022-05-19_16.04-072aa9e/django/images/favicons/favicon-96x96.png" sizes="96x96">\n    <link rel="icon" type="image/png" href="https://cdn.evbstatic.com/s3-build/484486-rc2022-05-19_16.04-072aa9e/django/images/favicons/android-chrome-192x192.png" sizes="192x192">\n    <link rel="icon" type="image/png" href="https://cdn.evbstatic.com/s3-build/484486-rc2022-05-19_16.04-072aa9e/django/images/favicons/favicon-16x16.png" sizes="16x16">\n    <link rel="shortcut icon" href="https://cdn.evbstatic.com/s3-build/484486-rc2022-05-19_16.04-072aa9e/django/images/favicons/favicon.ico">\n\n<link rel="mask-icon" href="https://cdn.evbstatic.com/s3-build/484486-rc2022-05-19_16.04-072aa9e/django/images/favicons/safari-pinned-tab.svg" color="#f6682f">\n<meta name="apple-mobile-web-app-title" content="Eventbrite">\n<meta name="application-name" content="Eventbrite">\n<meta name="msapplication-TileColor" content="#f6682f">\n<meta name="msapplication-TileImage" content="https://cdn.evbstatic.com/s3-build/484486-rc2022-05-19_16.04-072aa9e/django/images/favicons/mstile-144x144.png">\n<meta name="theme-color" content="#f6682f">\n\n        \n<link rel="apple-touch-icon" href="https://cdn.evbstatic.com/s3-build/484486-rc2022-05-19_16.04-072aa9e/django/images/touch_icons/apple-touch-icon-180x180.png">\n\n\n        \n        <link rel="manifest" href="https://cdn.evbstatic.com/s3-build/484486-rc2022-05-19_16.04-072aa9e/django/images/favicons/manifest.webmanifest">\n\n\n        <meta name="y_key" content="d92e23811007b438">\n        <meta name="msvalidate.01" content="A9AB07B7E430E4608E0BC57AFA5004AA" />\n\n        \n    \n        <meta property="fb:app_id" content="28218816837"/>\n    \n    <meta property="og:site_name" content="Eventbrite"/>\n        <meta property="og:image" content="https://cdn.evbstatic.com/s3-build/484486-rc2022-05-19_16.04-072aa9e/django/images/logos/eb_orange_on_white_1200x630.png"/>\n        <meta property="og:image:width" content="1200" />\n        <meta property="og:image:height" content="1200" />\n    <meta property="og:title" content="Berlin, Germany Paid Events This Month | Eventbrite" />\n        <meta property="og:description" content="Looking for music paid-events events in Berlin? Whether you&#39;re a local, new in town, or just passing through, you&#39;ll be sure to find something on Eventbrite that piques your interest." />\n    <meta property="og:url" content="https://www.eventbrite.com/d/germany--berlin/music--events--this-month/paid-events/"/>\n\n        <meta property="og:type" content="website" />\n    <!--The default time to live is 7 days, we are bumping to 9 days to test if this reduces crawler traffic,\n    documented in ticket EB-85484-->\n    <meta property="og:ttl" content="777600">\n\n\n    \n    <meta name="twitter:card" content="summary_large_image" />\n    <meta name="twitter:site" content="@eventbrite" />\n    <meta name="twitter:title" content="Berlin, Germany Paid Events This Month | Eventbrite" />\n        <meta name="twitter:description" content="Looking for music paid-events events in Berlin? Whether you&#39;re a local, new in town, or just passing through, you& ...

# %%
Events_May_M = BeautifulSoup(Events_May_M.content, "html.parser")
print(Events_May_M .prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-us" translate="no" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://ogp.me/ns/fb#">
#  <head>
#   <title>
#    Berlin, Germany Paid Events This Month | Eventbrite
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="en" http-equiv="Content-Language">
#    <link href="https://cdn.evbstatic.com/s3-build/484486-rc2022-05-19_16.04-072aa9e/django/images/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#    <link href="https://cdn.evbstatic.com/s3-build/484486-rc2022-05-19_16.04-072aa9e/django/images/favicons/favicon-194x194.png" rel="icon" sizes="194x194" type="image/png"/>
#    <link href="https://cdn.evbstatic.com/s3-build/484486-rc2022-05-19_16.04-072aa9e/django/images/favicons/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
#    <link href="https://cdn.evbstatic.com/s3-build/484486-rc2022-05-19_16.04-072aa9e/django/images/favicons/android-chrome-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
#    <link href="https://cdn.evbstatic.com/s3-build/484486-rc2022-05-19_16.04-072aa9e/django/images/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#    <link href="https://cdn.evbstatic.com/s3-build/484486-rc2022-05-19_16.04-072aa9e/django/images/favicons/favicon.ico" rel="shortcut icon"/>
#    <link color="#f6682f" href="https://cdn.evbstatic.com/s3-build/484486-rc2022-05-19_16.04-072aa9e/django/images/favicons/safari-pinned-tab.svg" rel="mask-icon"/>
#    <meta content="Eventbrite" name="apple-mobile-web-app-title"/>
#    <meta content="Eventbrite" name="application-name"/>
#    <meta content="#f6682f" name="msapplication-TileColor"/>
#    <meta content="https://cdn.evbstatic.com/s3-build/484486-rc2022-05-19_16.04-072aa9e/django/images/favicons/mstile-144x144.png" name="msapplication-TileImage"/>
#    <meta content="#f6682f" name="theme-color"/>
#    <link href="https://cdn.evbstatic.com/s3-build/484486-rc2022-05-19_16.04-072aa9e/django/images/touch_icons/apple-touch-icon-180x180.png" rel="apple-touch-icon"/>
#    <link href="https://cdn.evbstatic.com/s3-build/484486-rc2022-05-19_16.04-072aa9e/django/images/favicons/manifest.webmanifest" rel="manifest"/>
#    <meta content="d92e23811007b438" name="y_key"/>
#    <meta content="A9AB07B7E430E4608E0BC57AFA5004AA" name="msvalidate.01">
#     <meta content="28218816837" property="fb:app_id">
#      <meta content="Eventbrite" property="og:site_name">
#       <meta content="https://cdn.evbstatic.com/s3-build/484486-rc2022-05-19_16.04-072aa9e/django/images/logos/eb_orange_on_white_1200x630.png" property="og:image">
#        <meta content="1200" property="og:image:width">
#         <meta content="1200" property="og:image:height">
#          <meta content="Berlin, Germany Paid Events This Month | Eventbrite" property="og:title"/>
#          <meta content="Looking for music paid-events events in Berlin? Whether you're a local, new in town, or just passing through, you'll be sure to find something on Eventbrite that piques your interest." property="og:description"/>
#          <meta content="https://www.eventbrite.com/d/germany--berlin/music--events--this-month/paid-events/" property="og:url"/>
#          <meta content="website" property="og:type"/>
#          <!--The default time to live is 7 days, we are bumping to 9 days to test if this reduces crawler traffic,
#     documented in ticket EB-85484-->
#          <meta content="777600" property="og:ttl"/>
#          <meta content="summary_large_image" name="twitter:card">
#           <meta content="@eventbrite" name="twitter:site"/>
#           <meta content="Berlin, Germany Paid Events This Month | Eventbrite" name="twitter:title"/>
#           <meta content="Looking for music paid-events events in Berlin? Whether you're a local, new in town, or just passing through, you'll be sure to find something on Eventbrite that piques your interest." name="twitter:description"/>
#           <script type="text/javascript">
#            window.EBFONT_PROPERTIES = {
#         'family': 'Neue Plak',
#         'src': 'https://cdn.evbstatic.com/s3-build/perm_001/bf1c05/django/js/src/eb/fonts/neueplak.js',
#         'oldVersions': ['EB.fonts.neueplak.10-24-2018', 'EB.fonts.neueplak.09-20-2018', 'EB.fonts.neueplak.09-04-2018', 'EB.fonts.neueplak.08-30-2018', 'EB.fonts.neueplak.08-24-2018', 'EB.fonts.benton.10-26-2016', 'EB.fonts.benton.11-29-2016'],
#         'version': 'EB.fonts.neueplak.03-19-2019',
#     };
#           </script>
#           <script charset="utf-8" crossorigin="anonymous" type="text/javascript">
#            /* eslint-disable */
# !function(a,b){if(a.EB=a.EB||{},EB.renderFonts=function(a,c){for(var d="",e=b.createElement("style"),f=0,g;g=a[f];f++)d+="@font-face{font-family:'"+c+"';font-weight:"+g.weight+";font-style:"+g.style+";src:url(data:application/font-woff;base64,"+g.base64+") format('woff');}";e.styleSheet&&!e.sheet?e.styleSheet.cssText=d:e.appendChild(b.createTextNode(d)),b.getElementsByTagName("head")[0].appendChild(e),b.documentElement.className+=" font-has-loaded"},EB.readWriteFontFromLocalStorage=function(a){for(var c=0;c<a.EBFONT_PROPERTIES.oldVersions.length;c++)localStorage.removeItem(a.EBFONT_PROPERTIES.oldVersions[c]);var d=JSON.parse(localStorage.getItem(a.EBFONT_PROPERTIES.version));if(d)EB.renderFonts(d,a.EBFONT_PROPERTIES.family);else{EB.shouldRenderFonts=!0;var e=b.createElement("script");e.src=a.EBFONT_PROPERTIES.src,b.getElementsByTagName("head")[0].appendChild(e),setTimeout(function(){EB.shouldRenderFonts=!1},3e3)}},a.localStorage)try{localStorage.setItem("localStorage",1),localStorage.removeItem("localStorage"),EB.readWriteFontFromLocalStorage(a)}catch(c){Storage.prototype._setItem=Storage.prototype.setItem,Storage.prototype.setItem=function(){}}}(window,document);
# //# sourceMappingURL=ebfont.js.map
#           </script>
#           <link href="https://cdn.evbstatic.com/s3-build/fe/build/discover--2.135.0--eds-1.10.19.css" rel="stylesheet" type="text/css">
#            <link data-chunk="discover" href="https://cdn.evbstatic.com/s3-build/fe/build/discover.46a8096dfec8451f8a65.css" rel="stylesheet"/>
#            <link data-chunk="search" href="https://cdn.evbstatic.com/s3-build/fe/build/6464.0038098a913b850d19fa.css" rel="stylesheet"/>
#            <link data-chunk="FilterPanelContainer" href="https://cdn.evbstatic.com/s3-build/fe/build/860.c108572e302b7a3efc68.css" rel="stylesheet"/>
#            <link data-chunk="components-MobileFilterHeader" href="https://cdn.evbstatic.com/s3-build/fe/build/426.99f0346edc62459753c5.css" rel="stylesheet"/>
#            <script crossorigin="anonymous" src="https://cdn.evbstatic.com/s3-build/484486-rc2022-05-19_16.04-072aa9e/django/js/src/eb/evidon_consent.js" type="text/javascript">
#            </script>
#            <!-- Evidon Cookie Consent Code -->
#            <script type="text/javascript">
#             // Define dataLayer and the gtag function.
#         window.dataLayer = window.dataLayer || [];
#         if (typeof gtag !== 'function') function gtag(){ dataLayer.push(arguments); }
#         gtag('set', 'developer_id.dOGRkZj', true);
#
#         // Europe is opt-in consent, so ad storage is denied by default.
#         gtag('consent', 'default', {
#             'ad_storage': 'denied',
#             'analytics_storage': 'denied',
#             'region': ['AT','BE','BG','CZ','DE','DK','ES','FI','FR','GB','GR','HU','IE','IT','LU','NL','PL','PT','RO','SE','BR','TH','TR'],
#             'wait_for_update': 500
#         });
#
#         // Passing ad click, client ID, and session ID information in URLs
#         gtag('set', 'url_passthrough', true);
#            </script>
#            <script type="text/javascript">
#             window.evidon = window.evidon || {};
#
#         window.evidon.handleAdvertisingCategory = window.evidon.handleAdvertisingCategory || []
#         window.evidon.handleAnalyticsAndCustomizationCategory = window.evidon.handleAnalyticsAndCustomizationCategory || []
#         window.evidon.handleEssentialCategory = window.evidon.handleEssentialCategory || []
#         window.evidon.handlePerformanceAndFunctionalityCategory = window.evidon.handlePerformanceAndFunctionalityCategory || []
#         window.evidon.handleOrganizerCategory = window.evidon.handleOrganizerCategory || []
#
#         if (!EB.EvidonConsent.shouldDisableEvidon()) {
#             (function (id) {
#                 function append(scriptid, url, async) {
#                     var d = document, sn = 'script', f = d.getElementsByTagName(sn)[0];
#                     if (!f) f = d.head;
#                     var s = d.createElement(sn);
#                     s.async = async;
#                     s.id = scriptid;
#                     s.src = url;
#                     s.charset = 'utf-8';
#                     f.parentNode.insertBefore(s, f);
#                 }
#
#                 function is2parttld(value) {
#                     var tldindicators = ['co', 'com', 'info', 'web', 'info', 'gov', 'edu', 'biz', 'net', 'org'];
#                     var countryindicators = ['uk', 'us', 'fr', 'es', 'de', 'at', 'au', 'ae', 'be', 'br', 'ca', 'ch', 'cn', 'co', 'cz', 'dk', 'eg', 'eu', 'fi', 'gb', 'gr', 'hk', 'hr', 'hu', 'ie', 'in', 'jp', 'mx', 'nl', 'no', 'nz', 'pl', 'ro', 'ru', 'se'];
#                     return (tldindicators.indexOf(value) !== -1 || countryindicators.indexOf(value) !== -1);
#                 }
#
#                 function getRootDomain() {
#                     var parts = window.location.hostname.split('.');
#                     if (parts.length === 2) rootDomain = parts[0];
#                     else if (parts.length > 2) {
#                         // see if the next to last value is a common tld
#                         var part = parts[parts.length - 2];
#                         if (is2parttld(part)) {
#                             rootDomain = parts[parts.length - 3]; // go back one more
#                         }
#                         else {
#                             rootDomain = part;
#                         }
#                     }
#
#                     return rootDomain;
#                 }
#
#                 window.evidon.id = id;
#
#                 // set to true for non-production testing. this prevents analytics hits on the
#                 // evidon management interface.
#                 window.evidon.test = getRootDomain() !== 'eventbrite' ? true : false;
#
#                 // This property is unused by Eventbrite, but Evidon docs suggest that this is an identifier for the current active user. If we provide an internal id, Evidon will store it with the reporting information. Else, they will use a default correlation key not guaranteed to represent a unique user.
#                 //window.evidon.userid = '';
#
#                 var cdn = '//c.evidon.com/', rootDomain = getRootDomain(), noticecdn = cdn + 'sitenotice/';
#                 append('evidon-notice', noticecdn + 'evidon-sitenotice-tag.js', false);
#                 append('evidon-themes', noticecdn + id + '/snthemes.js', true);
#                 if (rootDomain) append('evidon-settings', noticecdn + id + '/' + rootDomain + (window.evidon.test ? '/test' : '') + '/settings.js', true);
#
#                 // For development purposes you can bypass country detection and hardcode a specific country tag below.
#                 // Ideally, use the ModHeader browser extension and change your location using it for testing.
#                 //
#                 // The translations which show up for you will always be whatever your browser Accept-Language headers are.
#                 // append('evidon-location', cdn + 'tag-gb/country.js', true);
#                 append('evidon-location', cdn + 'geo/country.js', true);
#
#                 window.evidon.priorConsentCallback = function (categories, vendors, cookies) {
#                     // add the tags which need to wait for prior consent
#                     // here. This should be all your advertising tags and
#                     // probably most of your social and tracking tags.
#                     //
#                     // the list of vendor categories is available at https://privacy.evidon.com/v3/sitenotice/vendors
#                     var handlers = {
#                         categories: {
#                             'all': 'handleAllCategories',
#                             'advertising cookies': 'handleAdvertisingCategory',
#                             'analytics and customization cookies': 'handleAnalyticsAndCustomizationCategory',
#                             'essential cookies': 'handleEssentialCategory',
#                             'performance and functionality cookies': 'handlePerformanceAndFunctionalityCategory',
#                             'organizer cookies': 'handleOrganizerCategory',
#                         },
#                         vendors: {}
#                     };
#
#                     for (var category in categories) {
#                         if (!categories[category]) continue;
#
#                         // If general consent is given, the category is going to be "all",
#                         // so we need to manually trigger every group of handler callbacks.
#                         if (category === 'all') {
#                             for (var category in handlers.categories) {
#                                 var callbacks = window.evidon[handlers.categories[category]];
#
#                                 // Iterate through the array of callbacks
#                                 if (Array.isArray(callbacks)) {
#                                     for (var callback of callbacks) {
#                                         if (typeof callback === 'function') callback();
#                                     }
#                                 }
#                             }
#                         } else {
#                             var callbacks = window.evidon[handlers.categories[category]];
#
#                             // Iterate through the array of callbacks
#                             if (Array.isArray(callbacks)) {
#                                 for (var callback of callbacks) {
#                                     if (typeof callback === 'function') callback();
#                                 }
#                             }
#                         }
#                     }
#
#                     for (var vendor in vendors) {
#                         if (!vendors[vendor]) continue;
#                         var handler = window.evidon[handlers.vendors[vendor]];
#                         if (typeof handler === 'function') handler();
#                     }
#                 }
#
#                 window.evidon.closeCallback = function () {
#                     // this is executed if the user closed a UI element without either Accepting (providing consent)
#                     // or Declining (declining to provide consent).
#                     //
#                     // This callback is also executed when a banner autocloses in EU countries after 60seconds of no action.
#                     //
#                     // In the US but not California, we add a suppression cookie so that the banner does not show back up on page reload.
#                     // If we do not do this, it's a very annoying experience where the banner will keep coming back up
#                     if (window.evidon.notice.country.code === 'us'
#                         && window.evidon.notice.country.stateCode
#                         && window.evidon.notice.country.stateCode !== 'ca')
#                     {
#                         window.evidon.notice.dropSuppressionCookie(365);
#                     }
#                 }
#
#                 window.evidon.consentWithdrawnCallback = function () {
#                     // this is executed if the user withdraws consent and elects to
#                     // no longer allow technologies to run on the site.
#                 }
#
#                 window.evidon.consentDeclinedCallback = function () {
#                     // When a site user selects the Decline button in a banner or barrier, the consentDeclined event is triggered.
#                     // This hides the notice for the current session, but when the site user opens a new session, either by refreshing
#                     // or opening a new browser, they will be asked to decline again.
#                     // https://community.crownpeak.com/t5/Universal-Consent-Platform-UCP/How-to-suppress-a-banner/ta-p/4647
#                     window.evidon.notice.dropSuppressionCookie(365);
#                 }
#             })(1611);
#         }
#            </script>
#            <!-- END Evidon Cookie Consent Code -->
#            <script type="text/javascript">
#             //<![CDATA[
#         (function() {
#             var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.defer = true;
#             ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#             var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#         })();
#
#         var _gaq = _gaq || [];
#         //]]>
#            </script>
#            <script>
#             (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#                 (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#                 m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#             })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#             ga('create', 'UA-141520-1', {'allowLinker': true, 'cookieFlags': 'SameSite=None; Secure' }, 'auto');
#
#             ga('set', 'forceSSL', true);
#            </script>
#            <!-- Google Tag Manager - Eventbrite - Main container-->
#            <script type="text/javascript">
#             window.dataLayer = window.dataLayer || [];
#             dataLayer.push({
#                 'dfaPartnerID': 'dfa_partner_id_not_set',
#                 'publicUserID': ''
#             });
#            </script>
#            <script>
#             (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#             new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#             j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#             'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#             })(window,document,'script','dataLayer','GTM-5P8FXJ');
#            </script>
#            <!-- End Google Tag Manager -->
#            <link href="https://www.eventbrite.com/d/germany--berlin/music--events--this-month/paid-events/" rel="canonical">
#             <link href="?page=2" rel="next"/>
#             <script type="text/javascript">
#              var customActions = {
#         SaveClicked: 'save_event',
#     };
#     var branchMedatata = { metadata : {} };
#     //Adding user authenticated metatag
#
#     (function(b,r,a,n,c,h,_,s,d,k){if(!b[n]||!b[n]._q){for(;s<_.length;)c(h,_[s++]);d=r.createElement(a);d.defer=1;d.src="https://cdn.branch.io/branch-latest.min.js";k=r.getElementsByTagName(a)[0];k.parentNode.insertBefore(d,k);b[n]=h}})(window,document,"script","branch",function(b,r){b[r]=function(){b._q.push([r,arguments])}},{_q:[],_v:1},"addListener applyCode autoAppIndex banner closeBanner closeJourney creditHistory credits data deepview deepviewCta first getCode init link logout redeem referrals removeListener sendSMS setBranchViewData setIdentity track validateCode trackCommerceEvent logEvent disableTracking".split(" "), 0);
#         branch.init('key_live_epYrpbv3NngOvWj47OM81jmgCFkeYUlx' , branchMedatata, function(err, data) {branch.addListener(branchListener);});
#
#     function branchListener(eventName, data) {
#
#         var eventsToTrack = [
#             'didShowJourney',
#             'didClickJourneyCTA',
#             'didClickJourneyClose',
#         ]; // List of events to track
#
#         if (eventName && data && data.journey_link_data && eventsToTrack.includes(eventName)){
#             var journeyName = data.journey_link_data.journey_name + ' - ' + data.journey_link_data.view_name +' - ' + data.journey_link_data.journey_id;
#             trackEventBranchIO(eventName, journeyName);
#         }
#     }
#
#     function trackEventBranchIO(eventName, journeyName){
#
#         if(typeof ga != "undefined" ){
#             ga('send', 'event',
#                 {
#                 eventCategory: 'BranchEvent',
#                 eventAction: eventName,
#                 eventLabel: journeyName,
#                 }
#             );
#         }
#     }
#
#     function addBranchIOMetatags(
#         name,
#         content,
#         extraData = null,
#     ){
#
#         var metadata = {
#             [name]: content,
#             custom_action: customActions[name] ? customActions[name] : name,
#         };
#
#         //Keep userAuthenticated metadata
#
#         //Adding metadata
#         addMetadata(metadata);
#
#         //Add extra data
#         extraData && addMetadata(extraData);
#
#         branch.track('pageview');
#     }
#
#    function addMetadata(branchData){
#         if (document) {
#             Object.entries(branchData).forEach(([key, value]) => {
#                 const meta = document.createElement('meta');
#                 meta.content = value;
#                 meta.name = 'branch:deeplink:' + key;
#                 document.head.appendChild(meta);
#             });
#         }
#     }
#             </script>
#             <meta content="noindex, follow, " name="robots"/>
#             <meta content="Looking for music paid-events events in Berlin? Whether you're a local, new in town, or just passing through, you'll be sure to find something on Eventbrite that piques your interest." name="description"/>
#             <meta content="initial-scale=1, width=device-width" name="viewport"/>
#             <link href="https://www.eventbrite.com/d/germany--berlin/music--events--this-month/paid-events/" hreflang="en-us" rel="alternate">
#              <link href="https://www.eventbrite.ca/d/germany--berlin/music--events--this-month/paid-events/" hreflang="en-ca" rel="alternate">
#               <link href="https://www.eventbrite.ca/fr_CA/d/germany--berlin/music--events--this-month/paid-events/" hreflang="fr-ca" rel="alternate">
#                <link href="https://www.eventbrite.com.ar/d/germany--berlin/music--events--this-month/paid-events/" hreflang="es-ar" rel="alternate">
#                 <link href="https://www.eventbrite.com.br/d/germany--berlin/music--events--this-month/paid-events/" hreflang="pt-br" rel="alternate">
#                  <link href="https://www.eventbrite.cl/d/germany--berlin/music--events--this-month/paid-events/" hreflang="es-cl" rel="alternate">
#                   <link href="https://www.eventbrite.com.mx/d/germany--berlin/music--events--this-month/paid-events/" hreflang="es-mx" rel="alternate">
#                    <link href="https://www.eventbrite.com.pe/d/germany--berlin/music--events--this-month/paid-events/" hreflang="es-pe" rel="alternate">
#                     <link href="https://www.eventbrite.co/d/germany--berlin/music--events--this-month/paid-events/" hreflang="es-co" rel="alternate">
#                      <link href="https://www.eventbrite.co.uk/d/germany--berlin/music--events--this-month/paid-events/" hreflang="en-gb" rel="alternate">
#                       <link href="https://www.eventbrite.ie/d/germany--berlin/music--events--this-month/paid-events/" hreflang="en-ie" rel="alternate">
#                        <link href="https://www.eventbrite.de/d/germany--berlin/music--events--this-month/paid-events/" hreflang="de-de" rel="alternate">
#                         <link href="https://www.eventbrite.at/d/germany--berlin/music--events--this-month/paid-events/" hreflang="de-at" rel="alternate"/>
#                         <link href="https://www.eventbrite.nl/d/germany--berlin/music--events--this-month/paid-events/" hreflang="nl-nl" rel="alternate"/>
#                         <link href="https://www.eventbrite.be/d/germany--berlin/music--events--this-month/paid-events/" hreflang="nl-be" rel="alternate"/>
#                         <link href="https://www.eventbrite.es/d/germany--berlin/music--events--this-month/paid-events/" hreflang="es-es" rel="alternate"/>
#                         <link href="https://www.eventbrite.fr/d/germany--berlin/music--events--this-month/paid-events/" hreflang="fr-fr" rel="alternate"/>
#                         <link href="https://www.eventbrite.be/fr_BE/d/germany--berlin/music--events--this-month/paid-events/" hreflang="fr-be" rel="alternate"/>
#                         <link href="https://www.eventbrite.it/d/germany--berlin/music--events--this-month/paid-events/" hreflang="it-it" rel="alternate"/>
#                         <link href="https://www.eventbrite.pt/d/germany--berlin/music--events--this-month/paid-events/" hreflang="pt-pt" rel="alternate"/>
#                         <link href="https://www.eventbrite.se/d/germany--berlin/music--events--this-month/paid-events/" hreflang="sv-se" rel="alternate"/>
#                         <link href="https://www.eventbrite.com.au/d/germany--berlin/music--events--this-month/paid-events/" hreflang="en-au" rel="alternate"/>
#                         <link href="https://www.eventbrite.co.nz/d/germany--berlin/music--events--this-month/paid-events/" hreflang="en-nz" rel="alternate"/>
#                         <link href="https://www.eventbrite.sg/d/germany--berlin/music--events--this-month/paid-events/" hreflang="en-sg" rel="alternate"/>
#                         <link href="https://www.eventbrite.hk/d/germany--berlin/music--events--this-month/paid-events/" hreflang="en-hk" rel="alternate"/>
#                         <link href="https://www.eventbrite.dk/d/germany--berlin/music--events--this-month/paid-events/" hreflang="en-dk" rel="alternate"/>
#                         <link href="https://www.eventbrite.fi/d/germany--berlin/music--events--this-month/paid-events/" hreflang="en-fi" rel="alternate"/>
#                         <link href="https://www.eventbrite.ch/d/germany--berlin/music--events--this-month/paid-events/" hreflang="de-ch" rel="alternate"/>
#                         <link href="https://www.eventbrite.ch/fr_CH/d/germany--berlin/music--events--this-month/paid-events/" hreflang="fr-ch" rel="alternate"/>
#                         <link href="https://www.eventbrite.com/d/germany--berlin/music--events--this-month/paid-events/" hreflang="x-default" rel="alternate"/>
#                        </link>
#                       </link>
#                      </link>
#                     </link>
#                    </link>
#                   </link>
#                  </link>
#                 </link>
#                </link>
#               </link>
#              </link>
#             </link>
#            </link>
#           </link>
#          </meta>
#         </meta>
#        </meta>
#       </meta>
#      </meta>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body class="">
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-5P8FXJ" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <div class="eds-g-grid eds-l-mar-top-2 eds-l-mar-bot-2 eds-hide" id="unsupported-browser-alert">
#    <div class="eds-g-cell eds-g-cell-1-1">
#     <div class="eds-notification-bar eds-notification-bar--warning">
#      <span>
#       Your version of Internet Explorer is not longer supported. Please
#       <a href="/support/articles/en_US/Troubleshooting/how-to-troubleshoot-internet-browser-issues" target="_blank">
#        upgrade your browser
#       </a>
#       .
#      </span>
#     </div>
#    </div>
#   </div>
#   <script type="text/javascript">
#    function isItIE() {
# 	  user_agent = navigator.userAgent;
# 	  var is_it_ie = user_agent.indexOf("MSIE ") > -1 || user_agent.indexOf("Trident/") > -1;
# 	  return is_it_ie;
# 	}
# 	if (isItIE()){
#         var alert = document.getElementById('unsupported-browser-alert');
#         var newClasses = alert.className.split('eds-hide').join('');
#         alert.className = newClasses;
# 	}
#   </script>
#   <div id="root">
#    <div class="eds-structure eds-structure--min-height" data-spec="eds-structure">
#     <div class="eds-structure__header">
#      <header class="consumer-header consumer-header__not-homepage" data-spec="consumer-header" id="global-header">
#       <a class="consumer-header__skip-links eds-is-hidden-accessible" href="#skip-heading">
#        Skip Main Navigation
#       </a>
#       <div class="consumer-header__main" data-role="header">
#        <div class="consumer-header__content consumer-header__desktop eds-show-up-md" data-spec="consumer-header-desktop">
#         <a class="consumer-header__logo-link" data-spec="consumer-header-logo-link" href="https://www.eventbrite.com">
#          <i class="eds-vector-image eds-brand--small eds-vector-image--ui-orange eds-vector-image--block eds-vector-image-size--reset" data-spec="icon" data-testid="icon" style="height:20px;width:110px" title="Eventbrite">
#           <svg viewbox="0 0 200 36">
#            <g fill-rule="evenodd">
#             <g>
#              <g transform="translate(.347)">
#               <path d="M185.945 17.513c2.693-.61 5.381.495 6.878 2.584l-11.905 2.693c.411-2.52 2.333-4.668 5.027-5.277zm6.944 9.91a6.57 6.57 0 01-3.979 2.679c-2.711.614-5.417-.51-6.908-2.626l11.942-2.702 1.945-.44 3.719-.841a11.782 11.782 0 00-.31-2.372c-1.513-6.426-8.055-10.432-14.611-8.949-6.556 1.484-10.644 7.896-9.13 14.321 1.513 6.426 8.055 10.433 14.61 8.95 3.864-.875 6.869-3.46 8.377-6.751l-5.655-1.269z">
#               </path>
#               <path d="M164.788 35.118V18.082h-3.677v-5.804h3.677V4.289h6.244v7.989h4.69v5.804h-4.69v17.036z" id="logo-wordmark-brand_svg__Fill-10">
#               </path>
#               <path d="M152.86 35.118h6.03v-22.84h-6.03v22.84zm-.785-30.853c0-2.114 1.667-3.7 3.825-3.7 2.157 0 3.775 1.586 3.775 3.7 0 2.115-1.618 3.748-3.775 3.748-2.158 0-3.825-1.633-3.825-3.748zM150.76 12.342c-3.082.16-4.9.633-6.75 1.973v-2.037h-6.026v22.84h6.026v-11.2c0-3.524.86-5.529 6.75-5.726v-5.85zM117.16 24.057c.15 3.333 3.051 6.128 6.602 6.128 3.601 0 6.552-2.942 6.552-6.422 0-3.432-2.95-6.373-6.552-6.373-3.551 0-6.452 2.843-6.602 6.128v.539zm-5.88 11.061V1.38l6.03-1.364v13.962c1.863-1.49 4.07-2.115 6.472-2.115 6.864 0 12.355 5.286 12.355 11.918 0 6.583-5.491 11.965-12.355 11.965-2.403 0-4.609-.624-6.472-2.114v1.487h-6.03z">
#               </path>
#               <path d="M98.445 35.118V17.965h-3.677v-5.687h3.677V4.283l6.244-1.413v9.408h4.69v5.687h-4.69v17.153z" id="logo-wordmark-brand_svg__Fill-1">
#               </path>
#               <path d="M87.394 35.118V22.915c0-4.421-2.402-5.382-4.805-5.382-2.402 0-4.805.913-4.805 5.286v12.299h-6.03v-22.84h6.03v1.699c1.324-.961 2.942-2.115 6.13-2.115 5.098 0 9.51 2.932 9.51 10.092v13.164h-6.03zM56.484 17.513c2.694-.61 5.382.495 6.878 2.584L51.458 22.79c.41-2.52 2.332-4.668 5.026-5.277zm6.945 9.91a6.57 6.57 0 01-3.98 2.679c-2.711.614-5.416-.51-6.907-2.626l11.942-2.702 1.944-.44 3.72-.841a11.782 11.782 0 00-.31-2.372c-1.514-6.426-8.056-10.432-14.612-8.949-6.556 1.484-10.644 7.896-9.13 14.321 1.513 6.426 8.055 10.433 14.611 8.95 3.863-.875 6.868-3.46 8.376-6.751l-5.654-1.269z">
#               </path>
#               <path d="M31.89 35.118l-9.364-22.84h6.57l5.932 15.49 5.982-15.49h6.57l-9.365 22.84z" id="logo-wordmark-brand_svg__Fill-2">
#               </path>
#               <path d="M10.703 17.507c2.694-.61 5.382.495 6.878 2.584L5.677 22.785c.41-2.52 2.332-4.668 5.026-5.278zm6.945 9.91a6.57 6.57 0 01-3.98 2.68c-2.71.613-5.416-.51-6.907-2.626l11.942-2.702 1.945-.44 3.718-.842a11.782 11.782 0 00-.31-2.371c-1.513-6.426-8.055-10.433-14.61-8.95C2.888 13.65-1.2 20.063.314 26.489c1.514 6.426 8.055 10.432 14.611 8.949 3.864-.874 6.869-3.46 8.376-6.75l-5.654-1.27z">
#               </path>
#              </g>
#             </g>
#            </g>
#           </svg>
#           <span class="eds-is-hidden-accessible">
#            Eventbrite
#           </span>
#          </i>
#         </a>
#         <div class="consumer-header__search__placeholder">
#         </div>
#         <div class="consumer-header__links">
#          <div class="consumer-header__menus" data-spec="consumer-header-menus">
#           <div class="consumer-header__menu">
#            <a aria-label="Menu dropdown link" class="eds-dropdown-menu__link ignore-react-onclickoutside" data-spec="dropdown-menu-link" role="menuitem">
#             <div class="eds-dropdown-menu__contents" data-spec="dropdown-menu-contents">
#              <span class="consumer-header__menu-label" data-spec="consumer-header-menu-label">
#               Organize
#              </span>
#             </div>
#             <span class="eds-dropdown-menu__icon">
#              <i aria-hidden="true" class="eds-vector-image eds-icon--small eds-vector-image--grey-400 eds-vector-image--block" data-spec="icon" data-testid="icon">
#               <svg id="chevron-down-chunky_svg__eds-icon--chevron-down-chunky_svg" viewbox="0 0 24 24" x="0" xml:space="preserve" y="0">
#                <path clip-rule="evenodd" d="M7 10.2l5 5 5-5-1.4-1.4-3.6 3.6-3.6-3.6z" fill-rule="evenodd" id="chevron-down-chunky_svg__eds-icon--chevron-down-chunky_base">
#                </path>
#               </svg>
#              </i>
#             </span>
#            </a>
#           </div>
#           <div class="consumer-header__menu">
#            <a aria-label="Menu dropdown link" class="eds-dropdown-menu__link ignore-react-onclickoutside" data-spec="dropdown-menu-link" role="menuitem">
#             <div class="eds-dropdown-menu__contents" data-spec="dropdown-menu-contents">
#              <span class="consumer-header__menu-label" data-spec="consumer-header-menu-label">
#               Help
#              </span>
#             </div>
#             <span class="eds-dropdown-menu__icon">
#              <i aria-hidden="true" class="eds-vector-image eds-icon--small eds-vector-image--grey-400 eds-vector-image--block" data-spec="icon" data-testid="icon">
#               <svg id="chevron-down-chunky_svg__eds-icon--chevron-down-chunky_svg" viewbox="0 0 24 24" x="0" xml:space="preserve" y="0">
#                <path clip-rule="evenodd" d="M7 10.2l5 5 5-5-1.4-1.4-3.6 3.6-3.6-3.6z" fill-rule="evenodd" id="chevron-down-chunky_svg__eds-icon--chevron-down-chunky_base">
#                </path>
#               </svg>
#              </i>
#             </span>
#            </a>
#           </div>
#          </div>
#          <div class="consumer-header__quick-links eds-l-mar-left-2" data-testid="consumer-header-quick-links">
#           <a class="consumer-header__quick-link" href="https://www.eventbrite.com/signin/?referrer=%2F">
#            <span>
#            </span>
#            <span>
#             Log In
#            </span>
#           </a>
#           <a class="consumer-header__quick-link" href="https://www.eventbrite.com/signin/signup/?referrer=%2F">
#            <span>
#            </span>
#            <span>
#             Sign Up
#            </span>
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="consumer-header__content consumer-header__mobile eds-show-down-mn eds-g-cell eds-g-cell--has-overflow eds-g-cell-1-1" data-spec="consumer-header-mobile">
#         <div class="consumer-header__mobile-links eds-align--space-between">
#          <a class="consumer-header__logo-link" data-spec="consumer-header-logo-link" href="https://www.eventbrite.com">
#           <i class="eds-vector-image eds-brand--small eds-vector-image--ui-orange eds-vector-image--block eds-vector-image-size--reset" data-spec="icon" data-testid="icon" style="height:20px;width:110px" title="Eventbrite">
#            <svg viewbox="0 0 200 36">
#             <g fill-rule="evenodd">
#              <g>
#               <g transform="translate(.347)">
#                <path d="M185.945 17.513c2.693-.61 5.381.495 6.878 2.584l-11.905 2.693c.411-2.52 2.333-4.668 5.027-5.277zm6.944 9.91a6.57 6.57 0 01-3.979 2.679c-2.711.614-5.417-.51-6.908-2.626l11.942-2.702 1.945-.44 3.719-.841a11.782 11.782 0 00-.31-2.372c-1.513-6.426-8.055-10.432-14.611-8.949-6.556 1.484-10.644 7.896-9.13 14.321 1.513 6.426 8.055 10.433 14.61 8.95 3.864-.875 6.869-3.46 8.377-6.751l-5.655-1.269z">
#                </path>
#                <path d="M164.788 35.118V18.082h-3.677v-5.804h3.677V4.289h6.244v7.989h4.69v5.804h-4.69v17.036z" id="logo-wordmark-brand_svg__Fill-10">
#                </path>
#                <path d="M152.86 35.118h6.03v-22.84h-6.03v22.84zm-.785-30.853c0-2.114 1.667-3.7 3.825-3.7 2.157 0 3.775 1.586 3.775 3.7 0 2.115-1.618 3.748-3.775 3.748-2.158 0-3.825-1.633-3.825-3.748zM150.76 12.342c-3.082.16-4.9.633-6.75 1.973v-2.037h-6.026v22.84h6.026v-11.2c0-3.524.86-5.529 6.75-5.726v-5.85zM117.16 24.057c.15 3.333 3.051 6.128 6.602 6.128 3.601 0 6.552-2.942 6.552-6.422 0-3.432-2.95-6.373-6.552-6.373-3.551 0-6.452 2.843-6.602 6.128v.539zm-5.88 11.061V1.38l6.03-1.364v13.962c1.863-1.49 4.07-2.115 6.472-2.115 6.864 0 12.355 5.286 12.355 11.918 0 6.583-5.491 11.965-12.355 11.965-2.403 0-4.609-.624-6.472-2.114v1.487h-6.03z">
#                </path>
#                <path d="M98.445 35.118V17.965h-3.677v-5.687h3.677V4.283l6.244-1.413v9.408h4.69v5.687h-4.69v17.153z" id="logo-wordmark-brand_svg__Fill-1">
#                </path>
#                <path d="M87.394 35.118V22.915c0-4.421-2.402-5.382-4.805-5.382-2.402 0-4.805.913-4.805 5.286v12.299h-6.03v-22.84h6.03v1.699c1.324-.961 2.942-2.115 6.13-2.115 5.098 0 9.51 2.932 9.51 10.092v13.164h-6.03zM56.484 17.513c2.694-.61 5.382.495 6.878 2.584L51.458 22.79c.41-2.52 2.332-4.668 5.026-5.277zm6.945 9.91a6.57 6.57 0 01-3.98 2.679c-2.711.614-5.416-.51-6.907-2.626l11.942-2.702 1.944-.44 3.72-.841a11.782 11.782 0 00-.31-2.372c-1.514-6.426-8.056-10.432-14.612-8.949-6.556 1.484-10.644 7.896-9.13 14.321 1.513 6.426 8.055 10.433 14.611 8.95 3.863-.875 6.868-3.46 8.376-6.751l-5.654-1.269z">
#                </path>
#                <path d="M31.89 35.118l-9.364-22.84h6.57l5.932 15.49 5.982-15.49h6.57l-9.365 22.84z" id="logo-wordmark-brand_svg__Fill-2">
#                </path>
#                <path d="M10.703 17.507c2.694-.61 5.382.495 6.878 2.584L5.677 22.785c.41-2.52 2.332-4.668 5.026-5.278zm6.945 9.91a6.57 6.57 0 01-3.98 2.68c-2.71.613-5.416-.51-6.907-2.626l11.942-2.702 1.945-.44 3.718-.842a11.782 11.782 0 00-.31-2.371c-1.513-6.426-8.055-10.433-14.61-8.95C2.888 13.65-1.2 20.063.314 26.489c1.514 6.426 8.055 10.432 14.611 8.949 3.864-.874 6.869-3.46 8.376-6.75l-5.654-1.27z">
#                </path>
#               </g>
#              </g>
#             </g>
#            </svg>
#            <span class="eds-is-hidden-accessible">
#             Eventbrite
#            </span>
#           </i>
#          </a>
#          <div class="eds-align--center-vertical">
#           <div class="consumer-header__links">
#            <span class="eds-global-header__narrow-menu eds-show-down-mn">
#             <div class="consumer-header__menu">
#              <a aria-label="Menu dropdown link" class="eds-dropdown-menu__link ignore-react-onclickoutside" data-spec="dropdown-menu-link" role="menuitem">
#               <div class="eds-dropdown-menu__contents" data-spec="dropdown-menu-contents">
#                <span>
#                 <span class="consumer-header__menu-icon" data-spec="consumer-header-menu-icon-container">
#                  <i aria-hidden="true" class="eds-vector-image eds-icon--small eds-vector-image--grey-700" data-spec="icon" data-testid="icon">
#                   <svg id="vertical-dots-chunky_svg__eds-icon--vertical-dots-chunky_svg" viewbox="0 0 24 24" x="0" xml:space="preserve" y="0">
#                    <path clip-rule="evenodd" d="M10 18c0-1.1.9-2 2-2s2 .9 2 2-.9 2-2 2-2-.9-2-2z" fill-rule="evenodd" id="vertical-dots-chunky_svg__eds-icon--vertical-dots-chunky_dot_2">
#                    </path>
#                    <circle clip-rule="evenodd" cx="12" cy="12" fill-rule="evenodd" id="vertical-dots-chunky_svg__eds-icon--vertical-dots-chunky_dot" r="2">
#                    </circle>
#                    <circle clip-rule="evenodd" cx="12" cy="6" fill-rule="evenodd" id="vertical-dots-chunky_svg__eds-icon--vertical-dots-chunky_dot_1" r="2">
#                    </circle>
#                   </svg>
#                  </i>
#                 </span>
#                </span>
#               </div>
#               <span class="eds-dropdown-menu__icon">
#                <i aria-hidden="true" class="eds-vector-image eds-icon--small eds-vector-image--grey-400 eds-vector-image--block" data-spec="icon" data-testid="icon">
#                 <svg id="chevron-down-chunky_svg__eds-icon--chevron-down-chunky_svg" viewbox="0 0 24 24" x="0" xml:space="preserve" y="0">
#                  <path clip-rule="evenodd" d="M7 10.2l5 5 5-5-1.4-1.4-3.6 3.6-3.6-3.6z" fill-rule="evenodd" id="chevron-down-chunky_svg__eds-icon--chevron-down-chunky_base">
#                  </path>
#                 </svg>
#                </i>
#               </span>
#              </a>
#             </div>
#            </span>
#            <div class="consumer-header__quick-links eds-l-mar-left-2" data-testid="consumer-header-quick-links">
#             <a class="consumer-header__quick-link" href="https://www.eventbrite.com/signin/?referrer=%2F">
#              <span>
#              </span>
#              <span>
#               Log In
#              </span>
#             </a>
#             <a class="consumer-header__quick-link" href="https://www.eventbrite.com/signin/signup/?referrer=%2F">
#              <span>
#              </span>
#              <span>
#               Sign Up
#              </span>
#             </a>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <span class="eds-is-hidden-accessible" id="skip-heading">
#        Page Content
#       </span>
#      </header>
#     </div>
#     <div class="eds-structure__body">
#      <section class="eds-structure__drawer eds-structure__right-drawer" data-spec="eds-structure-drawer-right">
#       <div class="eds-structure__drawer-content">
#       </div>
#      </section>
#      <div class="eds-structure__main-mask" data-spec="eds-structure-main-mask">
#       <div class="eds-structure__fixed-bottom-bar-layout-wrapper">
#        <div class="eds-fixed-bottom-bar-layout" data-spec="fixed-bottom-bar-layout">
#         <div class="eds-fixed-bottom-bar-layout__content">
#          <div class="eds-structure__main-container">
#           <main class="eds-structure__main" data-spec="eds-structure-main">
#            <div class="feed-search-page">
#             <div class="search-base-screen__root search-base-screen--bot-request">
#              <aside class="search-base-screen__filter-panel">
#               <section data-testid="bot-friendly-filters">
#                <div data-testid="bot-friendly-filter--heading">
#                 <section>
#                  Category
#                 </section>
#                 <ul>
#                  <li>
#                   <a href="/d/germany--berlin/business--events/">
#                    Business
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/d/germany--berlin/science-and-tech--events/">
#                    Science &amp; Tech
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/d/germany--berlin/music--events/">
#                    Music
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/d/germany--berlin/film-and-media--events/">
#                    Film &amp; Media
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/d/germany--berlin/arts--events/">
#                    Performing &amp; Visual Arts
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/d/germany--berlin/fashion--events/">
#                    Fashion
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/d/germany--berlin/health--events/">
#                    Health
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/d/germany--berlin/sports-and-fitness--events/">
#                    Sports &amp; Fitness
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/d/germany--berlin/travel-and-outdoor--events/">
#                    Travel &amp; Outdoor
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/d/germany--berlin/food-and-drink--events/">
#                    Food &amp; Drink
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/d/germany--berlin/charity-and-causes--events/">
#                    Charity &amp; Causes
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/d/germany--berlin/government--events/">
#                    Government
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/d/germany--berlin/community--events/">
#                    Community
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/d/germany--berlin/spirituality--events/">
#                    Spirituality
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/d/germany--berlin/family-and-education--events/">
#                    Family &amp; Education
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/d/germany--berlin/holiday--events/">
#                    Holiday
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/d/germany--berlin/home-and-lifestyle--events/">
#                    Home &amp; Lifestyle
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/d/germany--berlin/auto-boat-and-air--events/">
#                    Auto, Boat &amp; Air
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/d/germany--berlin/hobbies--events/">
#                    Hobbies
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/d/germany--berlin/school-activities--events/">
#                    School Activities
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/d/germany--berlin/other--events/">
#                    Other
#                   </a>
#                  </li>
#                 </ul>
#                </div>
#                <div data-testid="bot-friendly-filter--heading">
#                 <section>
#                  Format
#                 </section>
#                 <ul>
#                  <li>
#                   <a href="/d/germany--berlin/conferences/">
#                    Conference
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/d/germany--berlin/seminars/">
#                    Seminar
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/d/germany--berlin/expos/">
#                    Expo
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/d/germany--berlin/conventions/">
#                    Convention
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/d/germany--berlin/festivals/">
#                    Festival
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/d/germany--berlin/performances/">
#                    Performance
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/d/germany--berlin/screenings/">
#                    Screening
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/d/germany--berlin/galas/">
#                    Gala
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/d/germany--berlin/classes/">
#                    Class
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/d/germany--berlin/networking/">
#                    Networking
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/d/germany--berlin/parties/">
#                    Party
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/d/germany--berlin/rallies/">
#                    Rally
#                   </a>
# ...
#   </script>
#   <!-- Facebook Pixel Code -->
#   <script>
#    var options = {};
#
#         function _buildTrackPixel(eventName, pixelId, options) {
#             var img = document.createElement('img'),
#                 pixelId = pixelId,
#                 baseUrl = 'https://www.facebook.com/tr',
#                 imageUrl = baseUrl + '?id=' + pixelId + '&ev=' + eventName + '&noscript=1';
#
#             for (var key in options){
#                 if (options.hasOwnProperty(key)) {
#                      imageUrl += '&cd[' + key + ']=' + options[key];
#                 }
#             }
#
#             img.src = imageUrl;
#             img.height = '1';
#             img.width = '1';
#             img.style.display = 'none';
#
#             document.body.appendChild(img);
#         }
#
#         function _isInsideAttributionWindow (nowTimestamp, previousTimestamp) {
#             var facebookAttributionWindowInMs = 2419200000;
#
#             if (previousTimestamp) {
#                 return nowTimestamp - previousTimestamp <= facebookAttributionWindowInMs;
#             } else {
#                 return false;
#             }
#         }
#
#         function facebookTrackPixel(eventName, options) {
#             _buildTrackPixel(
#                 eventName,
#                 '1070931846288596',
#                 options
#             );
#         }
#
#         function facebookPurchaseTrackPixel(eventName, options) {
#             var eventStoredId,
#                 nowTimestamp;
#
#
#             try {
#                 if (eventName === 'ViewContent') {
#                     localStorage.setItem(eventStoredId, nowTimestamp);
#                     facebookTrackPixel(eventName, options);
#                 } else {
#                     var previousTimestamp = localStorage.getItem(eventStoredId),
#                         isInsideAttributionWindow = _isInsideAttributionWindow(nowTimestamp, previousTimestamp);
#
#                     if (isInsideAttributionWindow) {
#                         facebookTrackPixel(eventName, options);
#                     } else {
#                         localStorage.removeItem(eventStoredId);
#                     }
#                 }
#             } catch (error) {
#                 // If the error is TypeError, it means we don't have access to the localStorage
#                 // (thus we can't access setItem on null)
#                 // We will skip trying to fire the pixel tracking. If there's another error, it should be thrown.
#                 if (!error instanceof TypeError) {
#                     throw error;
#                 }
#             }
#         }
#
#         function facebookADSTrackPixel(eventName, options) {
#             _buildTrackPixel(
#                 eventName,
#                 '1595986097313505',
#                 options
#             );
#         }
#
#             window.evidon.handleAdvertisingCategory.push(function () {
#             window.facebookTrackPixel = window.facebookTrackPixel || facebookTrackPixel;
#             window.facebookPurchaseTrackPixel = window.facebookPurchaseTrackPixel || facebookPurchaseTrackPixel;
#             window.facebookADSTrackPixel = window.facebookADSTrackPixel || facebookADSTrackPixel;
#
#
#                 options['eventref'] = 'fb_oea';
#                 options['content_type'] = 'product';
#
#
#                 facebookADSTrackPixel('PageView', options);
#             })
#   </script>
#   <!-- End Facebook Pixel Code -->
#   <script type="text/javascript">
#    window.__i18n__ = {"locale":"en_US"};
#
#
#
#
#                 window.__SERVER_DATA__ = {"app_name":"discover","search_data":{"articles":{},"current_user_id":null,"profile_search":{},"article_search":{},"profiles":{},"events":{"pagination":{"object_count":37,"page_count":2,"page_number":1,"page_size":20,"continuation":"eyJwYWdlIjoyfQ"},"results":[{"image":{"edge_color_set":true,"edge_color":"#08082b","url":"https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F253923719%2F52020780162%2F1%2Foriginal.20220324-170152?w=512\u0026auto=format%2Ccompress\u0026q=75\u0026sharp=10\u0026rect=0%2C160%2C2560%2C1280\u0026s=36e97f1d90eb366e7c6fdaf6ed6d356b","original":{"url":"https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F253923719%2F52020780162%2F1%2Foriginal.20220324-170152?auto=format%2Ccompress\u0026q=75\u0026sharp=10\u0026s=f92e553b42d6cefd26a13e0e71128af7","width":2560,"height":1440},"crop_mask":{"width":2560,"height":1280,"top_left":{"y":160,"x":0}},"aspect_ratio":2.0,"id":"253923719"},"timezone":"Europe/Berlin","id":"272955706867","tickets_url":"https://www.eventbrite.com/checkout-external?eid=272955706867","tickets_by":"Eventbrite","primary_organizer_id":"17478803114","dedup":{"count":1,"hash":"facafa5102127996811a770b5e1fb0f0"},"num_children":1,"debug_info":{},"parent_url":null,"hide_end_date":false,"start_date":"2022-05-20","end_time":"23:00","_type":"destination_event","end_date":"2022-05-20","tags":[{"prefix":"EventbriteCategory","tag":"EventbriteCategory/103","display_name":"Music","localized":{"display_name":"Music"}},{"prefix":"EventbriteFormat","tag":"EventbriteFormat/6","display_name":"Concert or Performance"},{"_type":"tag","tag":"OrganizerTag/Music","display_name":"Music","prefix":"OrganizerTag"},{"_type":"tag","tag":"OrganizerTag/Berlin","display_name":"Berlin","prefix":"OrganizerTag"},{"_type":"tag","tag":"OrganizerTag/Kiezsalon","display_name":"Kiezsalon","prefix":"OrganizerTag"},{"_type":"tag","tag":"OrganizerTag/berlin_events","display_name":"berlin_events","prefix":"OrganizerTag"},{"_type":"tag","tag":"OrganizerTag/digitalinberlin","display_name":"digitalinberlin","prefix":"OrganizerTag"},{"_type":"tag","tag":"OrganizerTag/zionskirche","display_name":"zionskirche","prefix":"OrganizerTag"},{"_type":"tag","tag":"OrganizerTag/tartarelena","display_name":"tartarelena","prefix":"OrganizerTag"},{"_type":"tag","tag":"OrganizerTag/jasonsharp","display_name":"jasonsharp","prefix":"OrganizerTag"},{"_type":"tag","tag":"OrganizerTag/kabaird","display_name":"kabaird","prefix":"OrganizerTag"},{"_type":"tag","tag":"OrganizerTag/richardskelton","display_name":"richardskelton","prefix":"OrganizerTag"}],"eventbrite_event_id":"272955706867","start_time":"19:00","primary_venue":{"_type":"destination_venue","name":"Zionskirche","venue_profile_id":null,"address":{"city":"Berlin","country":"DE","region":"BE","longitude":"13.4036111","localized_address_display":"Zionskirchplatz, 10119 Berlin","postal_code":"10119","address_1":"Zionskirchplatz","address_2":"","latitude":"52.535","localized_multi_line_address_display":["Zionskirchplatz","10119 Berlin"],"localized_area_display":"Berlin"},"venue_profile_url":"","id":"84424609"},"full_description":null,"image_id":"253923719","is_protected_event":false,"is_cancelled":null,"primary_venue_id":"84424609","checkout_flow":"widget","series_id":null,"name":"Kiezsalon opening w/ Tarta Relena and Jason Sharp","language":"de-de","url":"https://www.eventbrite.de/e/kiezsalon-opening-w-tarta-relena-and-jason-sharp-tickets-272955706867","hide_start_date":false,"summary":"Kiezsalon is back! Season starts in May with a 2 day happening with 4 concerts, including 3 premieres at Zionskirche in Berlin-Mitte.","is_online_event":false,"eid":"272955706867","published":"2022-03-11T10:32:52Z"},{"image":{"edge_color_set":true,"edge_color":"#aab3bc","url":"https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F263391299%2F52020780162%2F1%2Foriginal.20220408-162815?w=512\u0026auto=format%2Ccompress\u0026q=75\u0026sharp=10\u0026rect=1%2C150%2C ...
#
#
#                     window.__REACT_QUERY_STATE__ = {"mutations":[],"queries":[]}
#   </script>
#   <script src="https://cdn.evbstatic.com/s3-build/fe/build/vendor.996a3a48d0899bceac21.dll.js">
#   </script>
#   <script id="__LOADABLE_REQUIRED_CHUNKS__" type="application/json">
#    [4099,2163,1947,7241,404,3705,2768,9701,7023,9380,9557,2294,3936,1946,4019,5581,9168,8183,3058,6464,860,8921,426]
#   </script>
#   <script id="__LOADABLE_REQUIRED_CHUNKS___ext" type="application/json">
#    {"namedChunks":["search","FilterPanelContainer","BotFilters","components-MobileFilterHeader","components"]}
#   </script>
#   <script async="" data-chunk="discover" src="https://cdn.evbstatic.com/s3-build/fe/build/vendor.994c293e8f97e4f65f22.web.js">
#   </script>
#   <script async="" data-chunk="discover" src="https://cdn.evbstatic.com/s3-build/fe/build/discover.dfffc000bf4ca7c3a2bd.web.js">
#   </script>
#   <script async="" data-chunk="search" src="https://cdn.evbstatic.com/s3-build/fe/build/4099.8d0dc16769c91d38cab7.async.web.js">
#   </script>
#   <script async="" data-chunk="search" src="https://cdn.evbstatic.com/s3-build/fe/build/2163.96cfd16871112ba926c0.async.web.js">
#   </script>
#   <script async="" data-chunk="search" src="https://cdn.evbstatic.com/s3-build/fe/build/1947.1d62b799f9ae3d737da8.async.web.js">
#   </script>
#   <script async="" data-chunk="search" src="https://cdn.evbstatic.com/s3-build/fe/build/7241.a2f165e8df4af1305066.async.web.js">
#   </script>
#   <script async="" data-chunk="search" src="https://cdn.evbstatic.com/s3-build/fe/build/404.6864faeebf1b3bc4a9f1.async.web.js">
#   </script>
#   <script async="" data-chunk="search" src="https://cdn.evbstatic.com/s3-build/fe/build/3705.623c44d533b1c2e5451b.async.web.js">
#   </script>
#   <script async="" data-chunk="search" src="https://cdn.evbstatic.com/s3-build/fe/build/2768.5c888b935e663da4672a.async.web.js">
#   </script>
#   <script async="" data-chunk="search" src="https://cdn.evbstatic.com/s3-build/fe/build/9701.5faa860a6e46f191e5f1.async.web.js">
#   </script>
#   <script async="" data-chunk="search" src="https://cdn.evbstatic.com/s3-build/fe/build/7023.c6b359adac0ccb19b243.async.web.js">
#   </script>
#   <script async="" data-chunk="search" src="https://cdn.evbstatic.com/s3-build/fe/build/9380.6f6975223c8b495f181d.async.web.js">
#   </script>
#   <script async="" data-chunk="search" src="https://cdn.evbstatic.com/s3-build/fe/build/9557.b641982db8458da20300.async.web.js">
#   </script>
#   <script async="" data-chunk="search" src="https://cdn.evbstatic.com/s3-build/fe/build/2294.d5a2863bb92e6301f295.async.web.js">
#   </script>
#   <script async="" data-chunk="search" src="https://cdn.evbstatic.com/s3-build/fe/build/3936.5b1a92a6989e2be96b9c.async.web.js">
#   </script>
#   <script async="" data-chunk="search" src="https://cdn.evbstatic.com/s3-build/fe/build/1946.fc22ff0a44dcb2b8c6af.async.web.js">
#   </script>
#   <script async="" data-chunk="search" src="https://cdn.evbstatic.com/s3-build/fe/build/4019.ac2b6fb2c90a5137d84e.async.web.js">
#   </script>
#   <script async="" data-chunk="search" src="https://cdn.evbstatic.com/s3-build/fe/build/5581.f54ff17bfcdffbda09e9.async.web.js">
#   </script>
#   <script async="" data-chunk="search" src="https://cdn.evbstatic.com/s3-build/fe/build/9168.40f3d5f304d514e1b324.async.web.js">
#   </script>
#   <script async="" data-chunk="search" src="https://cdn.evbstatic.com/s3-build/fe/build/8183.aea83ad1f82b29e12e98.async.web.js">
#   </script>
#   <script async="" data-chunk="search" src="https://cdn.evbstatic.com/s3-build/fe/build/3058.507be858687686f59b38.async.web.js">
#   </script>
#   <script async="" data-chunk="search" src="https://cdn.evbstatic.com/s3-build/fe/build/search.e1256495fb1d02b74f92.async.web.js">
#   </script>
#   <script async="" data-chunk="FilterPanelContainer" src="https://cdn.evbstatic.com/s3-build/fe/build/FilterPanelContainer.abf699a55f5fc3dc4cc9.async.web.js">
#   </script>
#   <script async="" data-chunk="BotFilters" src="https://cdn.evbstatic.com/s3-build/fe/build/BotFilters.db47d14cb1a254d613a0.async.web.js">
#   </script>
#   <script async="" data-chunk="components-MobileFilterHeader" src="https://cdn.evbstatic.com/s3-build/fe/build/components-MobileFilterHeader.179b38bd2672abb6107b.async.web.js">
#   </script>
#   <!-- NO JS TAGS GENERATED -->
#   <script>
#    window.EB = window.EB || {}; EB.VHit = [];
#   </script>
#   <script type="application/ld+json">
#    [{"startDate":"2022-05-20","endDate":"2022-05-20","name":"Kiezsalon opening w/ Tarta Relena and Jason Sharp","url":"https://www.eventbrite.de/e/kiezsalon-opening-w-tarta-relena-and-jason-sharp-tickets-272955706867","image":"https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F253923719%2F52020780162%2F1%2Foriginal.20220324-170152?w=512\u0026auto=format%2Ccompress\u0026q=75\u0026sharp=10\u0026rect=0%2C160%2C2560%2C1280\u0026s=36e97f1d90eb366e7c6fdaf6ed6d356b","offers":{"url":"https://www.eventbrite.de/e/kiezsalon-opening-w-tarta-relena-and-jason-sharp-tickets-272955706867","lowPrice":"0.00","highPrice":"0.00","@type":"AggregateOffer","priceCurrency":""},"location":{"address":{"addressCountry":"DE","addressLocality":"Berlin","addressRegion":"BE","streetAddress":"Zionskirchplatz","postalCode":"10119","@type":"PostalAddress"},"geo":{"latitude":"52.535","@type":"GeoCoordinates","longitude":"13.4036111"},"@type":"Place","name":"Zionskirche"},"eventAttendanceMode":"https://schema.org/OfflineEventAttendanceMode","@context":"http://schema.org","@type":"Event","description":"Kiezsalon is back! Season starts in May with a 2 day happening with 4 concerts, including 3 premieres at Zionskirche in Berlin-Mitte."},{"startDate":"2022-05-21","endDate":"2022-05-21","name":"Kiezsalon opening w/ Richard Skelton and Booker Stardrum","url":"https://www.eventbrite.de/e/kiezsalon-opening-w-richard-skelton-and-booker-stardrum-tickets-295137613547","image":"https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F263391299%2F52020780162%2F1%2Foriginal.20220408-162815?w=512\u0026auto=format%2Ccompress\u0026q=75\u0026sharp=10\u0026rect=1%2C150%2C1666%2C833\u0026s=72d4a87f731f0a4c3e14de9e9583cc1c","offers":{"url":"https://www.eventbrite.de/e/kiezsalon-opening-w-richard-skelton-and-booker-stardrum-tickets-295137613547","lowPrice":"0.00","highPrice":"0.00","@type":"AggregateOffer","priceCurrency":""},"location":{"address":{"addressCountry":"DE","addressLocality":"Berlin","addressRegion":"BE","streetAddress":"Zionskirchplatz","postalCode":"10119","@type":"PostalAddress"},"geo":{"latitude":"52.535","@type":"GeoCoordinates","longitude":"13.4036111"},"@type":"Place","name":"Zionskirche"},"eventAttendanceMode":"https://schema.org/OfflineEventAttendanceMode","@context":"http://schema.org","@type":"Event","description":"Kiezsalon is back! Season starts in May with a 2 day happening with 4 concerts, including 3 premieres at Zionskirche in Berlin-Mitte."},{"startDate":"2022-05-20","endDate":"2022-05-21","name":"Banana Party","url":"https://www.eventbrite.com/e/banana-party-tickets-330792608597","image":"https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F275848629%2F414522304733%2F1%2Foriginal.20220429-184821?w=512\u0026auto=format%2Ccompress\u0026q=75\u0026sharp=10\u0026rect=0%2C67%2C1640%2C820\u0026s=58bee2bb6f2142faa4d3878b0b0009c7","offers":{"url":"https://www.eventbrite.com/e/banana-party-tickets-330792608597","lowPrice":"0.00","highPrice":"0.00","@type":"AggregateOffer","priceCurrency":""},"location":{"address":{"addressCountry":"DE","addressLocality":"Berlin","addressRegion":"BE","streetAddress":"Alexanderstra\u00dfe 7","postalCode":"10178","@type":"PostalAddress"},"geo":{"latitude":"52.52328979999999","@type":"GeoCoordinates","longitude":"13.4164776"},"@type":"Place","name":"ASeven Club"},"eventAttendanceMode":"https://schema.org/OfflineEventAttendanceMode","@context":"http://schema.org","@type":"Event","description":"East"},{"startDate":"2022-05-28","endDate":"2022-05-29","name":"CDC Festival Boatride Party","url":"https://www.eventbrite.de/e/cdc-festival-boatride-party-tickets-332729130787","image":"https://img.evbuc.com/https%3A%2F%2Fcdn.evbuc.com%2Fimages%2F277550829%2F248634673303%2F1%2Foriginal.20220503-115518?w=512\u0026auto=format%2Ccompress\u0026q=75\u0026sharp=10\u0026rect=0%2C326%2C1700%2C850\u0026s=e1d95e10e360d486d309c11c921cfcde","offers":{"url":"https://www.eventbrite.de/e/cdc-festival-boatride-party-tickets-332729130787 ...
#   </script>
#  </body>
# </html>

# %%
# links of all pages of the events of the current month 

iterations = range(1, 11)
for i in iterations:
    start_at= str(i)
    url = "https://www.eventbrite.com/d/germany--berlin/events--this-month/paid-events/?page=" + start_at
    print(url)
# Out:
# https://www.eventbrite.com/d/germany--berlin/events--this-month/paid-events/?page=1
# https://www.eventbrite.com/d/germany--berlin/events--this-month/paid-events/?page=2
# https://www.eventbrite.com/d/germany--berlin/events--this-month/paid-events/?page=3
# https://www.eventbrite.com/d/germany--berlin/events--this-month/paid-events/?page=4
# https://www.eventbrite.com/d/germany--berlin/events--this-month/paid-events/?page=5
# https://www.eventbrite.com/d/germany--berlin/events--this-month/paid-events/?page=6
# https://www.eventbrite.com/d/germany--berlin/events--this-month/paid-events/?page=7
# https://www.eventbrite.com/d/germany--berlin/events--this-month/paid-events/?page=8
# https://www.eventbrite.com/d/germany--berlin/events--this-month/paid-events/?page=9
# https://www.eventbrite.com/d/germany--berlin/events--this-month/paid-events/?page=10

# %%
# A list with all the Event Names in May

Events_Names_M_M = []
Events_Dates_M_M = []
Events_Links_M_M = []
Events_Prices_M_M = []


for i in range(1,28):
    url = 'https://www.eventbrite.com/d/germany--berlin/music--events--this-month/paid-events/?page='
    url = url + str(i)
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    names = soup.select('div.eds-is-hidden-accessible')[1::2]
    dates = soup.select('.eds-event-card-content__sub-title')[1::2]
    links = soup.select('.eds-event-card-content__action-link')[1::4]
    for name in names:
        Events_Names_M_M.append(name.get_text(strip=True).lower())
    for date in dates:
        Events_Dates_M_M.append(date.get_text(strip=True)[9:11].lower())
    for link in links:
        Events_Links_M_M.append(link['href'])
        

    # EVENTS PRICES
    price_links = soup.select('.eds-event-card-content__primary-content a')[1::2]

    for price in price_links:
        response = requests.get(price['href'])
        soup = BeautifulSoup(response.content, 'html.parser')
        eprice = soup.select('.js-display-price')
    # print(price[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0])
        Events_Prices_M_M.append(eprice[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0]) 
    


print(Events_Names_M_M)
print(Events_Dates_M_M)
print(Events_Links_M_M)
print(Events_Prices_M_M)
# Out:
# ['kiezsalon opening w/ tarta relena and jason sharp', 'kiezsalon opening w/ richard skelton and booker stardrum', 'banana party', 'cdc festival boatride party', 'wahn: music, words, dance, performance', 'open mic night @ vagabund kesselhaus', 'wise by night', 'gest invites 003: halogenix', 'general levy', '[il]legal with nico moreno & basswell', 'living room concert serie #2', "kilkelly's open sofa sessions (musicians/poets)", "michelle daly 'january skies' album launch", 'strand liebe -  open air club festival w/ k-paul, mike la funk uvm.', 'beyond now pres. nakadia | bdme closing party', 'tech it deep', 'psychedelic vibe w/ major7 & x-noize', '28.05.2022 | epic fail party berlin i 300 kilo konfetti i und viel mehr <3', 'bar tausend x doormen on vacation', "olivia belli presents 'sol novo'", 'wise 2022  │  digital is (not) better!?', 'queer bedroom pop (feat. elio icaza + guests)', 'guča meets wacken „balkan metal party” special guest: balkan beat', 'og - christi himmelrave [bunker & beach garden]', 'patch | berlin dme after party w/ local suicide @ christa kupfer | 22.05', 'yazkah  anniversary concert', 'nick howard live in berlin', 'tausend electronica i andy roda at bar tausend', '33. mantrakonzert auf spendenbasis am 21. mai 2022', 'label showcase | deep tales x grey bar hotel x dit klingt jut', '♫ harcdore punk soli concert: in lovin memory of sergio en caceres', 'femmilie is in the house of music', 'psychedelic cumbia party - la cumbia es amor', 'void meets setisfaction', 'c4 - brandenburg rave', 'brandenburgs größte 2000er party | 20.05.22 | sound club cottbus', 'neon madness | das xxl-open air in magdeburg | 21.05.22']
# ['7:', 'at', '10', '28', '27', '25', '8:', '11', 'at', '27', '27', '24', '26', '25', '22', '11', '25', '28', '27', '24', '19', '26', '23', '26', '22', '29', '26', '26', 'at', 'at', '27', 'at', '27', 'at', 'at', '9:', 'at']
# ['https://www.eventbrite.de/e/kiezsalon-opening-w-tarta-relena-and-jason-sharp-tickets-272955706867?aff=ebdssbdestsearch', 'https://www.eventbrite.de/e/kiezsalon-opening-w-richard-skelton-and-booker-stardrum-tickets-295137613547?aff=ebdssbdestsearch', 'https://www.eventbrite.com/e/banana-party-tickets-330792608597?aff=ebdssbdestsearch', 'https://www.eventbrite.de/e/cdc-festival-boatride-party-tickets-332729130787?aff=ebdssbdestsearch', 'https://www.eventbrite.de/e/wahn-music-words-dance-performance-tickets-337442649047?aff=ebdssbdestsearch', 'https://www.eventbrite.com/e/open-mic-night-vagabund-kesselhaus-tickets-303455141497?aff=ebdssbdestsearch', 'https://www.eventbrite.de/e/wise-by-night-tickets-294450698967?aff=ebdssbdestsearch', 'https://www.eventbrite.de/e/gest-invites-003-halogenix-tickets-323161563937?aff=ebdssbdestsearch', 'https://www.eventbrite.de/e/general-levy-tickets-338842887197?aff=ebdssbdestsearch', 'https://www.eventbrite.de/e/illegal-with-nico-moreno-basswell-tickets-320795346517?aff=ebdssbdestsearch', 'https://www.eventbrite.de/e/living-room-concert-serie-2-tickets-336642766577?aff=ebdssbdestsearch', 'https://www.eventbrite.ie/e/kilkellys-open-sofa-sessions-musicianspoets-tickets-331101843527?aff=ebdssbdestsearch', 'https://www.eventbrite.de/e/michelle-daly-january-skies-album-launch-tickets-300547434467?aff=ebdssbdestsearch', 'https://www.eventbrite.de/e/strand-liebe-open-air-club-festival-w-k-paul-mike-la-funk-uvm-tickets-325759002947?aff=ebdssbdestsearch', 'https://www.eventbrite.co.uk/e/beyond-now-pres-nakadia-bdme-closing-party-tickets-339022203537?aff=ebdssbdestsearch', 'https://www.eventbrite.de/e/tech-it-deep-tickets-303482352887?aff=ebdssbdestsearch', 'https://www.eventbrite.de/e/psychedelic-vibe-w-major7-x-noize-tickets-317201918477?aff=ebdssbdestsearch', 'https://www.eventbrite.de/e/28052022-epic-fail-party-berlin-i-300-kilo-konfetti-i-und-viel-mehr-3-tickets-328979495527?aff=ebdssbdestsearch', 'https://www.eventbrite.de/e/bar-tausend-x-doormen-on-vacation-tickets-327966054297?aff=ebdssbdestsearch', 'https://www.eventbrite.de/e/olivia-belli-presents-sol-novo-tickets-251305941837?aff=ebdssbdestsearch', 'https://www.eventbrite.de/e/wise-2022-digital-is-not-better-tickets-254613966227?aff=ebdssbdestsearch', 'https://www.eventbrite.de/e/queer-bedroom-pop-feat-elio-icaza-guests-tickets-338987880877?aff=ebdssbdestsearch', 'https://www.eventbrite.de/e/guca-meets-wacken-balkan-metal-party-special-guest-balkan-beat-tickets-314511230557?aff=ebdssbdestsearch', 'https://www.eventbrite.de/e/og-christi-himmelrave-bunker-beach-garden-tickets-344436076577?aff=ebdssbdestsearch', 'https://www.eventbrite.com/e/patch-berlin-dme-after-party-w-local-suicide-christa-kupfer-2205-tickets-331985857637?aff=ebdssbdestsearch', 'https://www.eventbrite.de/e/yazkah-anniversary-concert-tickets-325026221177?aff=ebdssbdestsearch', 'https://www.eventbrite.com/e/nick-howard-live-in-berlin-tickets-325962872727?aff=ebdssbdestsearch', 'https://www.eventbrite.de/e/tausend-electronica-i-andy-roda-at-bar-tausend-tickets-340318480737?aff=ebdssbdestsearch', 'https://www.eventbrite.de/e/33-mantrakonzert-auf-spendenbasis-am-21-mai-2022-tickets-299054238277?aff=ebdssbdestsearch', 'https://www.eventbrite.co.uk/e/label-showcase-deep-tales-x-grey-bar-hotel-x-dit-klingt-jut-tickets-338343042147?aff=ebdssbdestsearch', 'https://www.eventbrite.de/e/harcdore-punk-soli-concert-in-lovin-memory-of-sergio-en-caceres-tickets-343941015837?aff=ebdssbdestsearch', 'https://www.eventbrite.de/e/femmilie-is-in-the-house-of-music-tickets-342660626157?aff=ebdssbdestsearch', 'https://www.eventbrite.de/e/psychedelic-cumbia-party-la-cumbia-es-amor-tickets-342351922817?aff=ebdssbdestsearch', 'https://www.eventbrite.de/e/void-meets-setisfaction-tickets-344241875717?aff=ebdssbdestsearch', 'https://www.eventbrite.de/e/c4-brandenburg-rave-tickets-331128362847?aff=ebdssbdestsearch', 'https://www.eventbrite.de/e/brandenburgs-grote-2000er-party-200522-sound-club-cottbus-ticke ...
# ['11,29€', '11,29€', '15€', '€43.80', '€11.83', 'Free', '€17.17', '€16.09', '7€', '15,74€', '8€', 'Donation', '€19', '19,69€', '10€', '17,17€', '11,46€', '12€', '11,83€', '20€', '€38.47', '€10', '10€', '11,83€', '11,83€', '€15', '$19.93', 'Kostenlos', 'Kostenlos', '15€', 'FreiwilligeSpende', '8,52€', '8,52€', '13,96€', '13,96€', '7,48€', '10,08€']

# %%
print(len(Events_Names_M_M))
print(len(Events_Dates_M_M))
print(len(Events_Links_M_M))
print(len(Events_Prices_M_M))
# Out:
# 37
# 37
# 37
# 37

# %%
# Make dictionary, keys that will become dataframe column names
Events_May_M_dict = {'Name':Events_Names_M_M, 'Date':Events_Dates_M_M, 'Price': Events_Prices_M_M, 'Links':Events_Links_M_M}

# Convert dictionary to Pandas dataframe
Events_May_M_df = pd.DataFrame(Events_May_M_dict)

# Set the index of the DataFrame from 1.
Events_May_M_df.index = Events_May_M_df.index + 1

# Data Cleaning (replace wrong values in 'Date' column). 
Events_May_M_df['Date'] = Events_May_M_df['Date'].astype(str)+'.05'
Events_May_M_df['Date'] = Events_May_M_df['Date'].str.replace(',','')
Events_May_M_df['Date'] = Events_May_M_df['Date'].str.replace('8:.05','Tomorrow')
Events_May_M_df['Date'] = Events_May_M_df['Date'].str.replace('7:.05','Tomorrow')
Events_May_M_df['Date'] = Events_May_M_df['Date'].str.replace('at.05','Tomorrow')
Events_May_M_df['Price'] = Events_May_M_df['Price'].str.replace('€',' ')
Events_May_M_df['Price'] = Events_May_M_df['Price'].str.replace('$',' ')
Events_May_M_df.drop(Events_May_M_df.loc[Events_May_M_df['Price']== 'Free'].index, inplace=True)
Events_May_M_df.drop(Events_May_M_df.loc[Events_May_M_df['Price']== 'Kostenlos'].index, inplace=True)



# change the column names to lower cases
Events_May_M_df.columns = Events_May_M_df.columns.str.strip().str.lower()

Events_May_M_df
# Out:
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/2474941748.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_May_M_df['Date'] = Events_May_M_df['Date'].str.replace('8:.05','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/2474941748.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_May_M_df['Date'] = Events_May_M_df['Date'].str.replace('7:.05','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/2474941748.py:15: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_May_M_df['Date'] = Events_May_M_df['Date'].str.replace('at.05','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/2474941748.py:17: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Events_May_M_df['Price'] = Events_May_M_df['Price'].str.replace('$',' ')
#                                                  name      date  \
# 1   kiezsalon opening w/ tarta relena and jason sharp  Tomorrow
# 2   kiezsalon opening w/ richard skelton and booke...  Tomorrow
# 3                                        banana party     10.05
# 4                         cdc festival boatride party     28.05
# 5              wahn: music, words, dance, performance     27.05
# 7                                       wise by night  Tomorrow
# 8                         gest invites 003: halogenix     11.05
# 9                                        general levy  Tomorrow
# 10              [il]legal with nico moreno & basswell     27.05
# 11                       living room concert serie #2     27.05
# 12    kilkelly's open sofa sessions (musicians/poets)     24.05
# 13         michelle daly 'january skies' album launch     26.05
# 14  strand liebe -  open air club festival w/ k-pa...     25.05
# 15      beyond now pres. nakadia | bdme closing party     22.05
# 16                                       tech it deep     11.05
# 17               psychedelic vibe w/ major7 & x-noize     25.05
# 18  28.05.2022 | epic fail party berlin i 300 kilo...     28.05
# 19                  bar tausend x doormen on vacation     27.05
# 20                   olivia belli presents 'sol novo'     24.05
# 21            wise 2022  │  digital is (not) better!?     19.05
# 22      queer bedroom pop (feat. elio icaza + guests)     26.05
# 23  guča meets wacken „balkan metal party” special...     23.05
# 24    og - christi himmelrave [bunker & beach garden]     26.05
# 25  patch | berlin dme after party w/ local suicid...     22.05
# 26                        yazkah  anniversary concert     29.05
# 27                         nick howard live in berlin     26.05
# 30  label showcase | deep tales x grey bar hotel x...  Tomorrow
# 31  ♫ harcdore punk soli concert: in lovin memory ...     27.05
# 32                  femmilie is in the house of music  Tomorrow
# 33       psychedelic cumbia party - la cumbia es amor     27.05
# 34                            void meets setisfaction  Tomorrow
# 35                              c4 - brandenburg rave  Tomorrow
# 36  brandenburgs größte 2000er party | 20.05.22 | ...     9:.05
# 37  neon madness | das xxl-open air in magdeburg |...  Tomorrow
#
#                 price                                              links
# 1              11,29   https://www.eventbrite.de/e/kiezsalon-opening-...
# 2              11,29   https://www.eventbrite.de/e/kiezsalon-opening-...
# 3                 15   https://www.eventbrite.com/e/banana-party-tick...
# 4               43.80  https://www.eventbrite.de/e/cdc-festival-boatr...
# 5               11.83  https://www.eventbrite.de/e/wahn-music-words-d...
# 7               17.17  https://www.eventbrite.de/e/wise-by-night-tick...
# 8               16.09  https://www.eventbrite.de/e/gest-invites-003-h...
# 9                  7   https://www.eventbrite.de/e/general-levy-ticke...
# 10             15,74   https://www.eventbrite.de/e/illegal-with-nico-...
# 11                 8   https://www.eventbrite.de/e/living-room-concer...
# 12           Donation  https://www.eventbrite.ie/e/kilkellys-open-sof...
# 13                 19  https://www.eventbrite.de/e/michelle-daly-janu...
# 14             19,69   https://www.eventbrite.de/e/strand-liebe-open-...
# 15                10   https://www.eventbrite.co.uk/e/beyond-now-pres...
# 16             17,17   https://www.eventbrite.de/e/tech-it-deep-ticke...
# 17             11,46   https://www.eventbrite.de/e/psychedelic-vibe-w...
# 18                12   https://www.eventbrite.de/e/28052022-epic-fail...
# 19             11,83   https://www.eventbrite.de/e/bar-tausend-x-door...
# 20                20   https://www.eventbrite.de/e/olivia-belli-prese...
# 21              38.47  https://www.eventbrite.de/e/wise-2022-digital-...
# 22                 10  https://www.eventbrite.de/e/queer-bedroom-pop-...
# 23                10   https://www.eventbrite.de/e/guca-meets-wacken-...
# 24             11,83   https://www.eventbrite.de/e/og-christi-himmelr...
# 25             11,83   https://www.eventbrite.com/e/patch-berlin-dme-...
# 26                 15  https://www.eventbrite.de/e/yazkah-anniversary...
# 27              19.93  https://www.eventbrite.com/e/nick-howard-live-...
# 30                15   https://www.eventbrite.co.uk/e/label-showcase-...
# 31  FreiwilligeSpende  https://www.eventbrite.de/e/harcdore-punk-soli...
# 32              8,52   https://www.eventbrite.de/e/femmilie-is-in-the...
# 33              8,52   https://www.eventbrite.de/e/psychedelic-cumbia...
# 34             13,96   https://www.eventbrite.de/e/void-meets-setisfa...
# 35             13,96   https://www.eventbrite.de/e/c4-brandenburg-rav...
# 36              7,48   https://www.eventbrite.de/e/brandenburgs-grote...
# 37             10,08   https://www.eventbrite.de/e/neon-madness-das-x...

# %% [markdown]
# #### NO-FREE Events from Eventbrite in Berlin;
# #### Month: June (J);
# #### Category: MUSIC.
# Link from eventbrite selecting the not-free events in May_Category: MUSIC (M)

# %%
url = 'https://www.eventbrite.com/d/germany--berlin/music--events--next-month/paid-events/?page=1'

# %%
# A list with all the Event Names in June

Events_Names_J_M = []
Events_Dates_J_M = []
Events_Links_J_M = []
Events_Prices_J_M = []


for i in range(1,28):
    url = 'https://www.eventbrite.com/d/germany--berlin/music--events--next-month/paid-events/?page='
    url = url + str(i)
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    names = soup.select('div.eds-is-hidden-accessible')[1::2]
    dates = soup.select('.eds-event-card-content__sub-title')[1::2]
    links = soup.select('.eds-event-card-content__action-link')[1::4]
    price_links = soup.select('.eds-event-card-content__primary-content a')[1::2]
    for name in names:
        Events_Names_J_M.append(name.get_text(strip=True).lower())
    for date in dates:
        Events_Dates_J_M.append(date.get_text(strip=True)[9:11].lower())
    for link in links:
        Events_Links_J_M.append(link['href'])
    
    for price in price_links:
        response = requests.get(price['href'])
        soup = BeautifulSoup(response.content, 'html.parser')
        eprice = soup.select('.js-display-price')
    # print(price[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0])
        Events_Prices_J_M.append(eprice[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0]) 
    


print(len(Events_Names_J_M))
print(len(Events_Dates_J_M))
print(len(Events_Links_J_M))
print(len(Events_Prices_J_M))
# Out:
# 24
# 24
# 24
# 24

# %%
# Make dictionary, keys that will become dataframe column names
Events_June_M_dict = {'Name':Events_Names_J_M, 'Date':Events_Dates_J_M, 'Price': Events_Prices_J_M, 'Links':Events_Links_J_M}

# Convert dictionary to Pandas dataframe
Events_June_M_df = pd.DataFrame(Events_June_M_dict)
Events_June_M_df.index = Events_June_M_df.index + 1

Events_June_M_df['Date'] = Events_June_M_df['Date'].astype(str)+'.06'
Events_June_M_df['Date'] = Events_June_M_df['Date'].str.replace(',','')
Events_June_M_df['Date'] = Events_June_M_df['Date'].str.replace('8:.06','Tomorrow')
Events_June_M_df['Date'] = Events_June_M_df['Date'].str.replace('7:.06','Tomorrow')
Events_June_M_df['Date'] = Events_June_M_df['Date'].str.replace('at.06','Tomorrow')
Events_June_M_df['Price'] = Events_June_M_df['Price'].str.replace('€',' ')
Events_June_M_df['Price'] = Events_June_M_df['Price'].str.replace('$',' ')
Events_June_M_df['Price'] = Events_June_M_df['Price'].str.replace('£',' ')

Events_June_M_df.drop(Events_June_M_df.loc[Events_June_M_df['Price']== 'Free'].index, inplace=True)
Events_June_M_df.drop(Events_June_M_df.loc[Events_June_M_df['Price']== 'Kostenlos'].index, inplace=True)


Events_June_M_df.columns = Events_June_M_df.columns.str.strip().str.lower()


Events_June_M_df
# Out:
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/776353382.py:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_June_M_df['Date'] = Events_June_M_df['Date'].str.replace('8:.06','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/776353382.py:11: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_June_M_df['Date'] = Events_June_M_df['Date'].str.replace('7:.06','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/776353382.py:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_June_M_df['Date'] = Events_June_M_df['Date'].str.replace('at.06','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/776353382.py:14: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Events_June_M_df['Price'] = Events_June_M_df['Price'].str.replace('$',' ')
#                                                  name   date    price  \
# 1   kiezsalon w/ mario batkovic, hatis noit, park ...  18.06   22,58
# 4   berlin carnival 2022  - 3 to 6 june | event + ...   3.06   251.70
# 5            50 jahre tipberlin – 20 years exberliner  18.06      19
# 6                   novafuture x .defaultbox open air   4.06   15,99
# 7                              massar egbari (berlin)   3.06    27.54
# 8                   andrew bear live in maschinenhaus  18.06    17.17
# 9   queens alliance w/ sisters in dub (uk), roots ...   4.06       12
# 10                          ignition - glam & glitter   2.06    13.96
# 11                           infected feat. monty (f)  18.06   13,96
# 12                             daniel romano's outfit  27.06   22,49
# 13                    lps le petit signal showcase #1  23.06    17.17
# 14                                   garrett t. capps   7.06   23,56
# 15                tixǝ - rock, blues + special guests   9.06   10,65
# 16          halli-galli-party in grünheide - open air  11.06    8,79
# 17                             bollywood night berlin  10.06      12
# 18            cph x bln: brimheim, greta, rebecca lou   9.06      18
# 19           local heroes - berlin qualifikation 2022   3.06       7
# 20                                        step higher   2.06    8,64
# 21        meet the carnival - pow pow movement (köln)   3.06   15,99
# 22     popcamp festival im columbia theater (fr & sa)  10.06   17,17
# 23                  fem concerts - kira hummen + koka  23.06    9,70
# 24  sachsens größte 2000er party | 11.06.22 | twen...  11.06   12,34
#
#                                                 links
# 1   https://www.eventbrite.de/e/kiezsalon-w-mario-...
# 4   https://www.eventbrite.co.uk/e/berlin-carnival...
# 5   https://www.eventbrite.de/e/50-jahre-tipberlin...
# 6   https://www.eventbrite.com/e/novafuture-x-defa...
# 7   https://www.eventbrite.co.uk/e/massar-egbari-b...
# 8   https://www.eventbrite.com/e/andrew-bear-live-...
# 9   https://www.eventbrite.de/e/queens-alliance-w-...
# 10  https://www.eventbrite.co.uk/e/ignition-glam-g...
# 11  https://www.eventbrite.de/e/infected-feat-mont...
# 12  https://www.eventbrite.de/e/daniel-romanos-out...
# 13  https://www.eventbrite.de/e/lps-le-petit-signa...
# 14  https://www.eventbrite.de/e/garrett-t-capps-ti...
# 15  https://www.eventbrite.de/e/tix-rock-blues-spe...
# 16  https://www.eventbrite.de/e/halli-galli-party-...
# 17  https://www.eventbrite.de/e/bollywood-night-be...
# 18  https://www.eventbrite.de/e/cph-x-bln-brimheim...
# 19  https://www.eventbrite.de/e/local-heroes-berli...
# 20  https://www.eventbrite.de/e/step-higher-ticket...
# 21  https://www.eventbrite.de/e/meet-the-carnival-...
# 22  https://www.eventbrite.com/e/popcamp-festival-...
# 23  https://www.eventbrite.de/e/fem-concerts-kira-...
# 24  https://www.eventbrite.de/e/sachsens-grote-200...

# %% [markdown]
# #### NO-FREE Events from Eventbrite in Berlin;
# #### Month: July (JL);
# #### Category: MUSIC.
# Link from eventbrite selecting the not-free events in May_Category: MUSIC (M)

# %%
url = 'https://www.eventbrite.com/d/germany--berlin/music--events/paid-events/?page=1&start_date=2022-07-01&end_date=2022-07-31'

# %%
# A list with all the Event Names in July

Events_Names_JL_M = []
Events_Dates_JL_M = []
Events_Links_JL_M = []
Events_Prices_JL_M = []


for i in range(1,28):
    url = 'https://www.eventbrite.com/d/germany--berlin/music--events/paid-events/?page='
    url = url + str(i) + '&start_date=2022-07-01&end_date=2022-07-31'
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    names = soup.select('div.eds-is-hidden-accessible')[1::2]
    dates = soup.select('.eds-event-card-content__sub-title')[1::2]
    links = soup.select('.eds-event-card-content__action-link')[1::4]
    for name in names:
        Events_Names_JL_M.append(name.get_text(strip=True).lower())
    for date in dates:
        Events_Dates_JL_M.append(date.get_text(strip=True)[9:11].lower())
    for link in links:
        Events_Links_JL_M.append(link['href'])

    # EVENTS PRICES
    price_links = soup.select('.eds-event-card-content__primary-content a')[1::2]

    for price in price_links:
        response = requests.get(price['href'])
        soup = BeautifulSoup(response.content, 'html.parser')
        eprice = soup.select('.js-display-price')
    # print(price[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0])
        Events_Prices_JL_M.append(eprice[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0]) 
    

print(len(Events_Names_JL_M))
print(len(Events_Dates_JL_M))
print(len(Events_Links_JL_M))
print(len(Events_Prices_JL_M))
# Out:
# 13
# 13
# 13
# 13

# %%
# Make dictionary, keys that will become dataframe column names
Events_JL_dict = {'Name':Events_Names_JL_M, 'Date':Events_Dates_JL_M, 'Price':Events_Prices_JL_M, 'Links':Events_Links_JL_M}

# Convert dictionary to Pandas dataframe
Events_July_M_df = pd.DataFrame(Events_JL_dict)
Events_July_M_df.index = Events_July_M_df.index + 1

Events_July_M_df['Date'] = Events_July_M_df['Date'].astype(str)+'.07'
Events_July_M_df['Date'] = Events_July_M_df['Date'].str.replace(',','')
Events_July_M_df['Date'] = Events_July_M_df['Date'].str.replace('8:.07','Tomorrow')
Events_July_M_df['Date'] = Events_July_M_df['Date'].str.replace('7:.07','Tomorrow')
Events_July_M_df['Date'] = Events_July_M_df['Date'].str.replace('at.07','Tomorrow')
Events_July_M_df['Price'] = Events_July_M_df['Price'].str.replace('€',' ')
Events_July_M_df['Price'] = Events_July_M_df['Price'].str.replace('$',' ')
Events_July_M_df['Price'] = Events_July_M_df['Price'].str.replace('£',' ')

Events_July_M_df.drop(Events_July_M_df.loc[Events_July_M_df['Price']== 'Free'].index, inplace=True)
Events_July_M_df.drop(Events_July_M_df.loc[Events_July_M_df['Price']== 'Kostenlos'].index, inplace=True)

Events_July_M_df.columns = Events_July_M_df.columns.str.strip().str.lower()


Events_July_M_df
# Out:
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/2349092864.py:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_July_M_df['Date'] = Events_July_M_df['Date'].str.replace('8:.07','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/2349092864.py:11: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_July_M_df['Date'] = Events_July_M_df['Date'].str.replace('7:.07','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/2349092864.py:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_July_M_df['Date'] = Events_July_M_df['Date'].str.replace('at.07','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/2349092864.py:14: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Events_July_M_df['Price'] = Events_July_M_df['Price'].str.replace('$',' ')
#                                                  name   date   price  \
# 1                torture garden berlin midsummer ball   9.07  22,05
# 3   zulu (usa), nervöus, eat my fear & deutsche la...   2.07   17.17
# 4                              c4 - open air festival   9.07  11,83
# 5                          techno back to the root ́s  23.07  23,15
# 6   ark white / prismala / rosa lee luna @ badehau...  28.07      12
# 7                               dirty fences • berlin  29.07  18,19
# 8           kaurna cronin & band – european tour 2022  21.07  15,99
# 9                         30 waschhaus - das festival  23.07     30
# 10  oriel quartett: in kollaboration 2 mit schulz ...  10.07      10
#
#                                                 links
# 1   https://www.eventbrite.co.uk/e/torture-garden-...
# 3   https://www.eventbrite.de/e/zulu-usa-nervous-e...
# 4   https://www.eventbrite.de/e/c4-open-air-festiv...
# 5   https://www.eventbrite.de/e/techno-back-to-the...
# 6   https://www.eventbrite.com/e/ark-white-prismal...
# 7   https://www.eventbrite.de/e/dirty-fences-berli...
# 8   https://www.eventbrite.de/e/kaurna-cronin-band...
# 9   https://www.eventbrite.de/e/30-waschhaus-das-f...
# 10  https://www.eventbrite.de/e/oriel-quartett-in-...

# %% [markdown]
# #### NO-FREE Events from Eventbrite in Berlin;
# #### Month: August (A);
# #### Category: MUSIC.
# Link from eventbrite selecting the not-free events in May_Category: MUSIC (M)

# %%
url = 'https://www.eventbrite.com/d/germany--berlin/paid--music--events/?end_date=2022-08-31&page=1&start_date=2022-08-01'

# %%
# A list with all the Event Names in August

Events_Names_A_M = []
Events_Dates_A_M = []
Events_Links_A_M = []
Events_Prices_A_M = []

for i in range(1,28):
    url = 'https://www.eventbrite.com/d/germany--berlin/paid--music--events/?end_date=2022-08-31&page='
    url = url + str(i) + '&start_date=2022-08-01'
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    names = soup.select('div.eds-is-hidden-accessible')[1::2]
    dates = soup.select('.eds-event-card-content__sub-title')[1::2]
    links = soup.select('.eds-event-card-content__action-link')[1::4]
    for name in names:
        Events_Names_A_M.append(name.get_text(strip=True).lower())
    for date in dates:
        Events_Dates_A_M.append(date.get_text(strip=True)[9:11].lower())
    for link in links:
        Events_Links_A_M.append(link['href'])

        
    # EVENTS PRICES
    price_links = soup.select('.eds-event-card-content__primary-content a')[1::2]

    for price in price_links:
        response = requests.get(price['href'])
        soup = BeautifulSoup(response.content, 'html.parser')
        eprice = soup.select('.js-display-price')
    # print(price[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0])
        Events_Prices_A_M.append(eprice[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0]) 
    

print(len(Events_Names_A_M))
print(len(Events_Dates_A_M))
print(len(Events_Links_A_M))
print(len(Events_Prices_A_M))
# Out:
# 30
# 30
# 30
# 30

# %%
# Make dictionary, keys that will become dataframe column names
Events_A_dict = {'Name':Events_Names_A_M, 'Date':Events_Dates_A_M, 'Price': Events_Prices_A_M, 'Links':Events_Links_A_M}

# Convert dictionary to Pandas dataframe
Events_Aug_M_df = pd.DataFrame(Events_A_dict)

# Data Cleaning
Events_Aug_M_df.index = Events_Aug_M_df.index + 1

Events_Aug_M_df['Date'] = Events_Aug_M_df['Date'].astype(str)+'.08'
Events_Aug_M_df['Date'] = Events_Aug_M_df['Date'].str.replace(',','')
Events_Aug_M_df['Date'] = Events_Aug_M_df['Date'].str.replace('8:.08','Tomorrow')
Events_Aug_M_df['Date'] = Events_Aug_M_df['Date'].str.replace('7:.08','Tomorrow')
Events_Aug_M_df['Date'] = Events_Aug_M_df['Date'].str.replace('at.08','Tomorrow')
Events_Aug_M_df['Price'] = Events_Aug_M_df['Price'].str.replace('€',' ')
Events_Aug_M_df['Price'] = Events_Aug_M_df['Price'].str.replace('$',' ')
Events_Aug_M_df['Price'] = Events_Aug_M_df['Price'].str.replace('£',' ')
Events_Aug_M_df['Price'] = Events_Aug_M_df['Price'].str.replace('FreiwilligeSpende','Donation')

Events_Aug_M_df.drop(Events_Aug_M_df.loc[Events_Aug_M_df['Price']== 'Free'].index, inplace=True)
Events_Aug_M_df.drop(Events_Aug_M_df.loc[Events_Aug_M_df['Price']== 'Kostenlos'].index, inplace=True)

Events_Aug_M_df.columns = Events_Aug_M_df.columns.str.strip().str.lower()


Events_Aug_M_df
# Out:
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/139529791.py:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_Aug_M_df['Date'] = Events_Aug_M_df['Date'].str.replace('8:.08','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/139529791.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_Aug_M_df['Date'] = Events_Aug_M_df['Date'].str.replace('7:.08','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/139529791.py:14: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_Aug_M_df['Date'] = Events_Aug_M_df['Date'].str.replace('at.08','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/139529791.py:16: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Events_Aug_M_df['Price'] = Events_Aug_M_df['Price'].str.replace('$',' ')
#                                                  name   date     price  \
# 1                holi festival of colours berlin 2022  20.08    10,36
# 2                                   natiruts @ berlin  18.08     32.99
# 3     kiezsalon w/ microcorps and maja ratkje & more.  27.08    22,58
# 4               festival son cubano - ecos de siboney   6.08    17,17
# 5                           schalala, das mitsingding  13.08    13,96
# 6                                       lord zeppelin   5.08    13,96
# 7                        basta - eure liebsten lieder  19.08    19,30
# 8                 tixǝ - rock, blues + special guests  11.08    10,65
# 9                    farbgefühle festival berlin 2022  20.08    10,36
# 10                      birds of a feather - folk-pop   4.08    10,65
# 11          eagel slam open air - best of poetry slam  12.08    11,83
# 12  fisch sucht fahrrad | single party in berlin |...  12.08       12
# 13            the teens -core- live! + aftershowparty   5.08    38,12
# 14                                        groundation   3.08    32,08
# 15                                       umweltmagier  11.08    15,03
# 16                                       ⬽ ꐠ rise ꐠ ⤘  13.08     43.80
# 17                        sarah shook & the disarmers  31.08    22,49
# 18                 prettyboys - indie-rap/alternative  18.08    15,99
# 19                         jam-session @beyond limits    .08  Donation
# 20  faiths in tune - 5. berliner festival der reli...  28.08
# 21               robert becker - k(creator) tour 2022  26.08    10,90
# 22                       kesselhaus summer stage 2022  30.08    11,43
# 23                          das lumpenpack - open air  27.08    32,36
# 24         magic silence  -  kopfhörer auf, welt aus!  20.08    38,47
# 25  klein aber fein open air 2022 w/ thomas lizzar...   5.08    17,17
# 26        halli-galli-party in fürstenberg * open air  27.08     8,79
# 27                                      ü33 1/3 party   6.08    31,96
# 28                     dance baby (black meets house)  20.08    31,96
# 29  dancing with myself | 80er party • factory mag...  27.08     9,70
# 30                         summer dream festival 2022   5.08    62,70
#
#                                                 links
# 1   https://www.eventbrite.de/e/holi-festival-of-c...
# 2   https://www.eventbrite.com/e/natiruts-berlin-t...
# 3   https://www.eventbrite.de/e/kiezsalon-w-microc...
# 4   https://www.eventbrite.de/e/festival-son-cuban...
# 5   https://www.eventbrite.de/e/schalala-das-mitsi...
# 6   https://www.eventbrite.de/e/lord-zeppelin-tick...
# 7   https://www.eventbrite.de/e/basta-eure-liebste...
# 8   https://www.eventbrite.de/e/tix-rock-blues-spe...
# 9   https://www.eventbrite.de/e/farbgefuhle-festiv...
# 10  https://www.eventbrite.de/e/birds-of-a-feather...
# 11  https://www.eventbrite.de/e/eagel-slam-open-ai...
# 12  https://www.eventbrite.de/e/fisch-sucht-fahrra...
# 13  https://www.eventbrite.de/e/the-teens-core-liv...
# 14  https://www.eventbrite.de/e/groundation-ticket...
# 15  https://www.eventbrite.de/e/umweltmagier-ticke...
# 16  https://www.eventbrite.com/e/rise-tickets-3406...
# 17  https://www.eventbrite.de/e/sarah-shook-the-di...
# 18  https://www.eventbrite.de/e/prettyboys-indie-r...
# 19  https://www.eventbrite.de/e/jam-session-beyond...
# 20  https://www.eventbrite.co.uk/e/faiths-in-tune-...
# 21  https://www.eventbrite.de/e/robert-becker-kcre...
# 22  https://www.eventbrite.de/e/kesselhaus-summer-...
# 23  https://www.eventbrite.de/e/das-lumpenpack-ope...
# 24  https://www.eventbrite.de/e/magic-silence-kopf...
# 25  https://www.eventbrite.de/e/klein-aber-fein-op...
# 26  https://www.eventbrite.de/e/halli-galli-party-...
# 27  https://www.eventbrite.com/e/u33-13-party-tick...
# 28  https://www.eventbrite.com/e/dance-baby-black-...
# 29  https://www.eventbrite.de/e/dancing-with-mysel...
# 30  https://www.eventbrite.de/e/summer-dream-festi...

# %% [markdown]
# #### NO-FREE Events from Eventbrite in Berlin;
# #### Month: May;
# #### Category: Community.

# %%
# A list with all the Event Names in May

Events_Names_M_C = []
Events_Dates_M_C = []
Events_Links_M_C = []
Events_Prices_M_C = []


for i in range(1,28):
    url = 'https://www.eventbrite.com/d/germany--berlin/paid--community--events--this-month/?page='
    url = url + str(i) 
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    names = soup.select('div.eds-is-hidden-accessible')[1::2]
    dates = soup.select('.eds-event-card-content__sub-title')[1::2]
    links = soup.select('.eds-event-card-content__action-link')[1::4]
    for name in names:
        Events_Names_M_C.append(name.get_text(strip=True).lower())
    for date in dates:
        Events_Dates_M_C.append(date.get_text(strip=True)[9:11].lower())
    for link in links:
        Events_Links_M_C.append(link['href'])

    # EVENTS PRICES
    price_links = soup.select('.eds-event-card-content__primary-content a')[1::2]

    for price in price_links:
        response = requests.get(price['href'])
        soup = BeautifulSoup(response.content, 'html.parser')
        eprice = soup.select('.js-display-price')
    # print(price[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0])
        Events_Prices_M_C.append(eprice[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0]) 
    
        

print(len(Events_Names_M_C))
print(len(Events_Dates_M_C))
print(len(Events_Links_M_C))
print(len(Events_Prices_M_C))
# Out:
# 18
# 18
# 18
# 18

# %%
# Make dictionary, keys that will become dataframe column names
Events_M_dict = {'Name':Events_Names_M_C, 'Date':Events_Dates_M_C, 'Price':Events_Prices_M_C, 'Links':Events_Links_M_C}

# Convert dictionary to Pandas dataframe
Events_M_C_df = pd.DataFrame(Events_M_dict)
Events_M_C_df.index = Events_M_C_df.index + 1

Events_M_C_df['Date'] = Events_M_C_df['Date'].astype(str)+'.05'
Events_M_C_df['Date'] = Events_M_C_df['Date'].str.replace(',','')
Events_M_C_df['Date'] = Events_M_C_df['Date'].str.replace('8:.05','Tomorrow')
Events_M_C_df['Date'] = Events_M_C_df['Date'].str.replace('7:.05','Tomorrow')
Events_M_C_df['Date'] = Events_M_C_df['Date'].str.replace('at.05','Tomorrow')
Events_M_C_df['Price'] = Events_M_C_df['Price'].str.replace('€',' ')
Events_M_C_df['Price'] = Events_M_C_df['Price'].str.replace('$',' ')
Events_M_C_df['Price'] = Events_M_C_df['Price'].str.replace('£',' ')
Events_M_C_df['Price'] = Events_M_C_df['Price'].str.replace('FreiwilligeSpende','Donation')

Events_M_C_df.drop(Events_M_C_df.loc[Events_M_C_df['Price']== 'Free'].index, inplace=True)
Events_M_C_df.drop(Events_M_C_df.loc[Events_M_C_df['Price']== 'Kostenlos'].index, inplace=True)

Events_M_C_df.columns = Events_M_C_df.columns.str.strip().str.lower()


Events_M_C_df
# Out:
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/1766370418.py:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_M_C_df['Date'] = Events_M_C_df['Date'].str.replace('8:.05','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/1766370418.py:11: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_M_C_df['Date'] = Events_M_C_df['Date'].str.replace('7:.05','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/1766370418.py:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_M_C_df['Date'] = Events_M_C_df['Date'].str.replace('at.05','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/1766370418.py:14: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Events_M_C_df['Price'] = Events_M_C_df['Price'].str.replace('$',' ')
#                                                  name      date     price  \
# 1                                  gypsy tales berlin     28.05     22.49
# 2      silent.move walk'n'dance disco tour // berlin.  Tomorrow    11,90
# 3           "act out!" - die geister, die uns riefen!     11.05  Donation
# 4                                     iwb may meet-up     25.05     11.83
# 5                                       sunday slips!     22.05  Donation
# 6                     black aspiring creators meet up     5:.05        10
# 7                   slam des westens #114 in the dark     25.05     7,57
# 8   noite cabo-verdiana/ stand up comedy com carlo...     28.05       25
# 9   fundraising im chor | das 1x1 der antragsstellung  Tomorrow       25
# 10      germania, berygtede bunkere og naziarkitektur     28.05     11.83
# 11                            dichterasse poetry slam     28.05     7,57
# 12  the 'pathology of freedom': colonialism and ps...     26.05     11.83
# 13  city walking tour - das afrikanische viertel i...  Tomorrow        0
# 14  hip berlin underground tour - street art, club...     10.05     81.09
# 15        freddy fischer and his cosmic rocktime band  Tomorrow    14,61
# 16  frauen schreiben anders – begegnung mit irakis...  Tomorrow        0
# 17                                      help with art     12.05  Donation
# 18                 konzert blue side park & kawa kawa     26.05       10
#
#                                                 links
# 1   https://www.eventbrite.co.uk/e/gypsy-tales-ber...
# 2   https://www.eventbrite.de/e/silentmove-walknda...
# 3   https://www.eventbrite.de/e/act-out-die-geiste...
# 4   https://www.eventbrite.de/e/iwb-may-meet-up-ti...
# 5   https://www.eventbrite.de/e/sunday-slips-ticke...
# 6   https://www.eventbrite.ca/e/black-aspiring-cre...
# 7   https://www.eventbrite.de/e/slam-des-westens-1...
# 8   https://www.eventbrite.de/e/bilhetes-noite-cab...
# 9   https://www.eventbrite.de/e/fundraising-im-cho...
# 10  https://www.eventbrite.de/e/germania-berygtede...
# 11  https://www.eventbrite.de/e/dichterasse-poetry...
# 12  https://www.eventbrite.co.uk/e/the-pathology-o...
# 13  https://www.eventbrite.de/e/city-walking-tour-...
# 14  https://www.eventbrite.de/e/hip-berlin-undergr...
# 15  https://www.eventbrite.de/e/freddy-fischer-and...
# 16  https://www.eventbrite.de/e/frauen-schreiben-a...
# 17  https://www.eventbrite.de/e/help-with-art-tick...
# 18  https://www.eventbrite.de/e/konzert-blue-side-...

# %% [markdown]
# #### NO-FREE Events from Eventbrite in Berlin;
# #### Month: June (J);
# #### Category: Community.

# %%
# A list with all the Event Names in June

Events_Names_J_C = []
Events_Dates_J_C = []
Events_Links_J_C = []
Events_Prices_J_C = []


for i in range(1,28):
    url = 'https://www.eventbrite.com/d/germany--berlin/community--events--next-month/paid-events/?page='
    url = url + str(i) 
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    names = soup.select('div.eds-is-hidden-accessible')[1::2]
    dates = soup.select('.eds-event-card-content__sub-title')[1::2]
    links = soup.select('.eds-event-card-content__action-link')[1::4]
    for name in names:
        Events_Names_J_C.append(name.get_text(strip=True).lower())
    for date in dates:
        Events_Dates_J_C.append(date.get_text(strip=True)[9:11].lower())
    for link in links:
        Events_Links_J_C.append(link['href'])

        
        
    # EVENTS PRICES
    price_links = soup.select('.eds-event-card-content__primary-content a')[1::2]

    for price in price_links:
        response = requests.get(price['href'])
        soup = BeautifulSoup(response.content, 'html.parser')
        eprice = soup.select('.js-display-price')
    # print(price[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0])
        Events_Prices_J_C.append(eprice[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0]) 
    
    

print(len(Events_Names_J_C))
print(len(Events_Dates_J_C))
print(len(Events_Links_J_C))
print(len(Events_Prices_J_C))
# Out:
# 19
# 19
# 19
# 19

# %%
# Make dictionary, keys that will become dataframe column names
Events_J_dict = {'Name':Events_Names_J_C, 'Date':Events_Dates_J_C, 'Price': Events_Prices_J_C, 'Links':Events_Links_J_C}

# Convert dictionary to Pandas dataframe
Events_J_C_df = pd.DataFrame(Events_J_dict)
Events_J_C_df.index = Events_J_C_df.index + 1

Events_J_C_df['Date'] = Events_J_C_df['Date'].astype(str)+'.06'
Events_J_C_df['Date'] = Events_J_C_df['Date'].str.replace(',','')
Events_J_C_df['Date'] = Events_J_C_df['Date'].str.replace('8:.06','Tomorrow')
Events_J_C_df['Date'] = Events_J_C_df['Date'].str.replace('7:.06','Tomorrow')
Events_J_C_df['Date'] = Events_J_C_df['Date'].str.replace('at.06','Tomorrow')
Events_J_C_df.drop(Events_J_C_df.loc[Events_J_C_df['Price']== '0€'].index, inplace=True)
Events_J_C_df['Price'] = Events_J_C_df['Price'].str.replace('FreiwilligeSpende','Donation')

Events_J_C_df['Price'] = Events_J_C_df['Price'].str.replace('€',' ')
Events_J_C_df['Price'] = Events_J_C_df['Price'].str.replace('$',' ')
Events_J_C_df['Price'] = Events_J_C_df['Price'].str.replace('£',' ')

Events_J_C_df.drop(Events_J_C_df.loc[Events_J_C_df['Price']== 'Free'].index, inplace=True)
Events_J_C_df.drop(Events_J_C_df.loc[Events_J_C_df['Price']== 'Kostenlos'].index, inplace=True)

Events_J_C_df.columns = Events_J_C_df.columns.str.strip().str.lower()


Events_J_C_df
# Out:
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/3668555028.py:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_J_C_df['Date'] = Events_J_C_df['Date'].str.replace('8:.06','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/3668555028.py:11: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_J_C_df['Date'] = Events_J_C_df['Date'].str.replace('7:.06','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/3668555028.py:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_J_C_df['Date'] = Events_J_C_df['Date'].str.replace('at.06','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/3668555028.py:17: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Events_J_C_df['Price'] = Events_J_C_df['Price'].str.replace('$',' ')
#                                                  name   date     price  \
# 2                                       sunday slips!   5.06  Donation
# 6            unshaved bear summer berlin edition 2022  25.06    12,79
# 7                 date deficient - vegan dating night   2.06       15
# 8                            bearground - leider geil   5.06    21,43
# 9      silent.move walk'n'dance disco tour // berlin.   3.06    11,90
# 10       juneteenth unity festival picnic in the park  19.06     15.25
# 11                           zim community summer bbq   4.06         5
# 12                        kopftuchmädchen b-day event   4.06    29,99
# 13                    liliana velásquez & chris davis   1.06     11.68
# 14                                dinner confidential  29.06     17.17
# 17  hip berlin underground tour - street art, club...   2.06     81.09
# 18                             freiland festival 2022   3.06       99
# 19  1st global local guide & content creator conve...   3.06  Donation
#
#                                                 links
# 2   https://www.eventbrite.de/e/sunday-slips-ticke...
# 6   https://www.eventbrite.de/e/unshaved-bear-summ...
# 7   https://www.eventbrite.de/e/date-deficient-veg...
# 8   https://www.eventbrite.de/e/bearground-leider-...
# 9   https://www.eventbrite.de/e/silentmove-walknda...
# 10  https://www.eventbrite.de/e/juneteenth-unity-f...
# 11  https://www.eventbrite.com/e/zim-community-sum...
# 12  https://www.eventbrite.com/e/kopftuchmadchen-b...
# 13  https://www.eventbrite.de/e/liliana-velasquez-...
# 14  https://www.eventbrite.com/e/dinner-confidenti...
# 17  https://www.eventbrite.de/e/hip-berlin-undergr...
# 18  https://www.eventbrite.de/e/freiland-festival-...
# 19  https://www.eventbrite.de/e/1st-global-local-g...

# %% [markdown]
# #### NO-FREE Events from Eventbrite in Berlin;
# #### Month: July (JL);
# #### Category: Community (C).

# %%
# A list with all the Event Names in July

Events_Names_JL_C = []
Events_Dates_JL_C = []
Events_Links_JL_C = []
Events_Prices_JL_C = []


for i in range(1,28):
    url = 'https://www.eventbrite.com/d/germany--berlin/community--events/paid-events/?page='
    url = url + str(i) + '&start_date=2022-07-01&end_date=2022-07-31'
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    names = soup.select('div.eds-is-hidden-accessible')[1::2]
    dates = soup.select('.eds-event-card-content__sub-title')[1::2]
    links = soup.select('.eds-event-card-content__action-link')[1::4]
    for name in names:
        Events_Names_JL_C.append(name.get_text(strip=True).lower())
    for date in dates:
        Events_Dates_JL_C.append(date.get_text(strip=True)[9:11].lower())
    for link in links:
        Events_Links_JL_C.append(link['href'])


        # EVENTS PRICES
    price_links = soup.select('.eds-event-card-content__primary-content a')[1::2]

    for price in price_links:
        response = requests.get(price['href'])
        soup = BeautifulSoup(response.content, 'html.parser')
        eprice = soup.select('.js-display-price')
    # print(price[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0])
        Events_Prices_JL_C.append(eprice[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0]) 
    
        
print(len(Events_Names_JL_C))
print(len(Events_Dates_JL_C))
print(len(Events_Links_JL_C))
print(len(Events_Prices_JL_C))
# Out:
# 5
# 5
# 5
# 5

# %%
# Make dictionary, keys that will become dataframe column names
Events_JL_dict = {'Name':Events_Names_JL_C, 'Date':Events_Dates_JL_C, 'Price': Events_Prices_JL_C, 'Links':Events_Links_JL_C}

# Convert dictionary to Pandas dataframe
Events_JL_C_df = pd.DataFrame(Events_JL_dict)
Events_JL_C_df.index = Events_JL_C_df.index + 1

Events_JL_C_df['Date'] = Events_JL_C_df['Date'].astype(str)+'.07'
Events_JL_C_df['Date'] = Events_JL_C_df['Date'].str.replace(',','')
Events_JL_C_df['Date'] = Events_JL_C_df['Date'].str.replace('8:.07','Tomorrow')
Events_JL_C_df['Date'] = Events_JL_C_df['Date'].str.replace('7:.07','Tomorrow')
Events_JL_C_df['Date'] = Events_JL_C_df['Date'].str.replace('at.07','Tomorrow')
Events_JL_C_df.drop(Events_JL_C_df.loc[Events_JL_C_df['Price']== '0€'].index, inplace=True)
Events_JL_C_df['Price'] = Events_JL_C_df['Price'].str.replace('€',' ')
Events_JL_C_df['Price'] = Events_JL_C_df['Price'].str.replace('$',' ')
Events_JL_C_df['Price'] = Events_JL_C_df['Price'].str.replace('£',' ')

Events_JL_C_df.drop(Events_JL_C_df.loc[Events_JL_C_df['Price']== 'Free'].index, inplace=True)
Events_JL_C_df.drop(Events_JL_C_df.loc[Events_JL_C_df['Price']== 'Kostenlos'].index, inplace=True)


Events_JL_C_df.columns = Events_JL_C_df.columns.str.strip().str.lower()


Events_JL_C_df
# Out:
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/3845539481.py:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_JL_C_df['Date'] = Events_JL_C_df['Date'].str.replace('8:.07','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/3845539481.py:11: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_JL_C_df['Date'] = Events_JL_C_df['Date'].str.replace('7:.07','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/3845539481.py:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_JL_C_df['Date'] = Events_JL_C_df['Date'].str.replace('at.07','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/3845539481.py:15: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Events_JL_C_df['Price'] = Events_JL_C_df['Price'].str.replace('$',' ')
#                                                 name  date     price  \
# 1                                      sunday slips!  3.07  Donation
# 2                         the black wall street gala  9.07    49,13
# 3     silent.move walk'n'dance disco tour // berlin.  1.07    11,90
# 5  hip berlin underground tour - street art, club...  1.07     81.09
#
#                                                links
# 1  https://www.eventbrite.de/e/sunday-slips-ticke...
# 2  https://www.eventbrite.de/e/the-black-wall-str...
# 3  https://www.eventbrite.de/e/silentmove-walknda...
# 5  https://www.eventbrite.de/e/hip-berlin-undergr...

# %% [markdown]
# #### NO-FREE Events from Eventbrite in Berlin;
# #### Month: August (A);
# #### Category: Community.

# %%
# A list with all the Event Names in August

Events_Names_A_C = []
Events_Dates_A_C = []
Events_Links_A_C = []
Events_Prices_A_C = []


for i in range(1,28):
    url = 'https://www.eventbrite.com/d/germany--berlin/community--events/paid-events/?end_date=2022-08-31&page='
    url = url + str(i) + '&start_date=2022-08-01'
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    names = soup.select('div.eds-is-hidden-accessible')[1::2]
    dates = soup.select('.eds-event-card-content__sub-title')[1::2]
    links = soup.select('.eds-event-card-content__action-link')[1::4]
    for name in names:
        Events_Names_A_C.append(name.get_text(strip=True).lower())
    for date in dates:
        Events_Dates_A_C.append(date.get_text(strip=True)[9:11].lower())
    for link in links:
        Events_Links_A_C.append(link['href'])

        # EVENTS PRICES
    price_links = soup.select('.eds-event-card-content__primary-content a')[1::2]

    for price in price_links:
        response = requests.get(price['href'])
        soup = BeautifulSoup(response.content, 'html.parser')
        eprice = soup.select('.js-display-price')
    # print(price[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0])
        Events_Prices_A_C.append(eprice[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0]) 
    

print(len(Events_Names_A_C))
print(len(Events_Dates_A_C))
print(len(Events_Links_A_C))
print(len(Events_Prices_A_C))
# Out:
# 5
# 5
# 5
# 5

# %%
# Make dictionary, keys that will become dataframe column names
Events_A_dict = {'Name':Events_Names_A_C, 'Date':Events_Dates_A_C, 'Price':Events_Prices_A_C, 'Links':Events_Links_A_C}

# Convert dictionary to Pandas dataframe
Events_A_C_df = pd.DataFrame(Events_A_dict)
Events_A_C_df.index = Events_A_C_df.index + 1

Events_A_C_df['Date'] = Events_A_C_df['Date'].astype(str)+'.08'
Events_A_C_df['Date'] = Events_A_C_df['Date'].str.replace(',','')
Events_A_C_df['Date'] = Events_A_C_df['Date'].str.replace('8:.08','Tomorrow')
Events_A_C_df['Date'] = Events_A_C_df['Date'].str.replace('7:.08','Tomorrow')
Events_A_C_df['Date'] = Events_A_C_df['Date'].str.replace('at.08','Tomorrow')
Events_A_C_df.drop(Events_A_C_df.loc[Events_A_C_df['Price']== '0€'].index, inplace=True)
Events_A_C_df['Price'] = Events_A_C_df['Price'].str.replace('€',' ')
Events_A_C_df['Price'] = Events_A_C_df['Price'].str.replace('$',' ')
Events_A_C_df['Price'] = Events_A_C_df['Price'].str.replace('£',' ')

Events_A_C_df.drop(Events_A_C_df.loc[Events_A_C_df['Price']== 'Free'].index, inplace=True)
Events_A_C_df.drop(Events_A_C_df.loc[Events_A_C_df['Price']== 'Kostenlos'].index, inplace=True)



Events_A_C_df.columns = Events_A_C_df.columns.str.strip().str.lower()


Events_A_C_df
# Out:
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/3901241360.py:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_A_C_df['Date'] = Events_A_C_df['Date'].str.replace('8:.08','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/3901241360.py:11: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_A_C_df['Date'] = Events_A_C_df['Date'].str.replace('7:.08','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/3901241360.py:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_A_C_df['Date'] = Events_A_C_df['Date'].str.replace('at.08','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/3901241360.py:15: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Events_A_C_df['Price'] = Events_A_C_df['Price'].str.replace('$',' ')
#                                                 name   date     price  \
# 1                                      sunday slips!   7.08  Donation
# 2     silent.move walk'n'dance disco tour // berlin.   5.08    11,90
# 3                   whipped cream - untertage berlin  27.08       19
# 5  hip berlin underground tour - street art, club...   4.08     81.09
#
#                                                links
# 1  https://www.eventbrite.de/e/sunday-slips-ticke...
# 2  https://www.eventbrite.de/e/silentmove-walknda...
# 3  https://www.eventbrite.de/e/whipped-cream-unte...
# 5  https://www.eventbrite.de/e/hip-berlin-undergr...

# %% [markdown]
# #### NO-FREE Events from Eventbrite in Berlin;
# #### Month: May (M);
# #### Category: Cinema (Cin).

# %%
# A list with all the Event Names in May

Events_Names_M_Cin = []
Events_Dates_M_Cin = []
Events_Links_M_Cin = []
Events_Prices_M_Cin = []


for i in range(1,28):
    url = 'https://www.eventbrite.com/d/germany--berlin/film-and-media--events--this-month/paid-events/?page='
    url = url + str(i) 
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    names = soup.select('div.eds-is-hidden-accessible')[1::2]
    dates = soup.select('.eds-event-card-content__sub-title')[1::2]
    links = soup.select('.eds-event-card-content__action-link')[1::4]
    for name in names:
        Events_Names_M_Cin.append(name.get_text(strip=True).lower())
    for date in dates:
        Events_Dates_M_Cin.append(date.get_text(strip=True)[9:11].lower())
    for link in links:
        Events_Links_M_Cin.append(link['href'])

         # EVENTS PRICES
    price_links = soup.select('.eds-event-card-content__primary-content a')[1::2]

    for price in price_links:
        response = requests.get(price['href'])
        soup = BeautifulSoup(response.content, 'html.parser')
        eprice = soup.select('.js-display-price')
    # print(price[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0])
        Events_Prices_M_Cin.append(eprice[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0]) 
    

print(len(Events_Names_M_Cin))
print(len(Events_Dates_M_Cin))
print(len(Events_Links_M_Cin))
print(len(Events_Prices_M_Cin))
# Out:
# 26
# 26
# 26
# 26

# %%
# Make dictionary, keys that will become dataframe column names
Events_M_dict = {'Name':Events_Names_M_Cin, 'Date':Events_Dates_M_Cin, 'Price':Events_Prices_M_Cin, 'Links':Events_Links_M_Cin}

# Convert dictionary to Pandas dataframe
Events_M_Cin_df = pd.DataFrame(Events_M_dict)
Events_M_Cin_df.index = Events_M_Cin_df.index + 1

Events_M_Cin_df['Date'] = Events_M_Cin_df['Date'].astype(str)+'.05'
Events_M_Cin_df['Date'] = Events_M_Cin_df['Date'].str.replace(',','')
Events_M_Cin_df['Date'] = Events_M_Cin_df['Date'].str.replace('8:.05','Tomorrow')
Events_M_Cin_df['Date'] = Events_M_Cin_df['Date'].str.replace('7:.05','Tomorrow')
Events_M_Cin_df['Date'] = Events_M_Cin_df['Date'].str.replace('at.05','Tomorrow')
Events_M_Cin_df.drop(Events_M_Cin_df.loc[Events_M_Cin_df['Price']== '0€'].index, inplace=True)
Events_M_Cin_df['Price'] = Events_M_Cin_df['Price'].str.replace('€',' ')
Events_M_Cin_df['Price'] = Events_M_Cin_df['Price'].str.replace('$',' ')
Events_M_Cin_df['Price'] = Events_M_Cin_df['Price'].str.replace('£',' ')

Events_M_Cin_df.drop(Events_M_Cin_df.loc[Events_M_Cin_df['Price']== 'Free'].index, inplace=True)
Events_M_Cin_df.drop(Events_M_Cin_df.loc[Events_M_Cin_df['Price']== 'Kostenlos'].index, inplace=True)
Events_M_Cin_df.drop(Events_M_Cin_df.loc[Events_M_Cin_df['Price']== '0'].index, inplace=True)


Events_M_Cin_df.columns = Events_M_Cin_df.columns.str.strip().str.lower()



Events_M_Cin_df
# Out:
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/3078275205.py:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_M_Cin_df['Date'] = Events_M_Cin_df['Date'].str.replace('8:.05','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/3078275205.py:11: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_M_Cin_df['Date'] = Events_M_Cin_df['Date'].str.replace('7:.05','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/3078275205.py:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_M_Cin_df['Date'] = Events_M_Cin_df['Date'].str.replace('at.05','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/3078275205.py:15: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Events_M_Cin_df['Price'] = Events_M_Cin_df['Price'].str.replace('$',' ')
#                                                  name      date   price  \
# 1          english comedy berlin with pizza and shots  Tomorrow  22,51
# 2   english stand up comedy - culture shock specia...  Tomorrow   12.54
# 3           that's what she said - womxn comedy night  Tomorrow      16
# 7            new york comedy club - berlin: main show     23.05    2.14
# 8     comedy roulette | the ultimate comedy game show  Tomorrow      13
# 9   laughing spree: english comedy on a boat (free...     24.05    2.13
# 12        expats in berlin #35  - english comedy show     26.05    8.55
# 15  new york comedy club - berlin: late show - dar...     23.05    2.14
# 17  high bars & low morals. english comedy special...     22.05      10
# 20  hook, value and emotions. video content in 202...     25.05       0
# 22  tati comedy - die stand up comedy show in berl...     28.05  14,90
# 26                movie: mee vasantrao  -  मी वसंतराव  Tomorrow   13.86
#
#                                                 links
# 1   https://www.eventbrite.de/e/english-comedy-ber...
# 2   https://www.eventbrite.co.uk/e/english-stand-u...
# 3   https://www.eventbrite.de/e/thats-what-she-sai...
# 7   https://www.eventbrite.com/e/new-york-comedy-c...
# 8   https://www.eventbrite.de/e/comedy-roulette-th...
# 9   https://www.eventbrite.de/e/laughing-spree-eng...
# 12  https://www.eventbrite.co.uk/e/expats-in-berli...
# 15  https://www.eventbrite.com/e/new-york-comedy-c...
# 17  https://www.eventbrite.com/e/high-bars-low-mor...
# 20  https://www.eventbrite.de/e/hook-value-and-emo...
# 22  https://www.eventbrite.de/e/tati-comedy-die-st...
# 26  https://www.eventbrite.de/e/movie-mee-vasantra...

# %% [markdown]
# #### NO-FREE Events from Eventbrite in Berlin;
# #### Month: June (J);
# #### Category: Cinema.

# %%
# A list with all the Event Names in June

Events_Names_J_Cin = []
Events_Dates_J_Cin = []
Events_Links_J_Cin = []
Events_Prices_J_Cin = []


for i in range(1,28):
    url = 'https://www.eventbrite.com/d/germany--berlin/film-and-media--events--next-month/paid-events/?page='
    url = url + str(i) 
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    names = soup.select('div.eds-is-hidden-accessible')[1::2]
    dates = soup.select('.eds-event-card-content__sub-title')[1::2]
    links = soup.select('.eds-event-card-content__action-link')[1::4]
    for name in names:
        Events_Names_J_Cin.append(name.get_text(strip=True).lower())
    for date in dates:
        Events_Dates_J_Cin.append(date.get_text(strip=True)[9:11].lower())
    for link in links:
        Events_Links_J_Cin.append(link['href'])

        
        # EVENTS PRICES
    price_links = soup.select('.eds-event-card-content__primary-content a')[1::2]

    for price in price_links:
        response = requests.get(price['href'])
        soup = BeautifulSoup(response.content, 'html.parser')
        eprice = soup.select('.js-display-price')
    # print(price[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0])
        Events_Prices_J_Cin.append(eprice[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0]) 
    

print(len(Events_Names_J_Cin))
print(len(Events_Dates_J_Cin))
print(len(Events_Links_J_Cin))
print(len(Events_Prices_J_Cin))
# Out:
# 23
# 23
# 23
# 23

# %%
# Make dictionary, keys that will become dataframe column names
Events_J_dict = {'Name':Events_Links_J_Cin, 'Date':Events_Dates_J_Cin, 'Price':Events_Prices_J_Cin, 'Links':Events_Links_J_Cin}

# Convert dictionary to Pandas dataframe
Events_J_Cin_df = pd.DataFrame(Events_J_dict)
Events_J_Cin_df.index = Events_J_Cin_df.index + 1

Events_J_Cin_df['Date'] = Events_J_Cin_df['Date'].astype(str)+'.06'
Events_J_Cin_df['Date'] = Events_J_Cin_df['Date'].str.replace(',','')
Events_J_Cin_df['Date'] = Events_J_Cin_df['Date'].str.replace('8:.06','Tomorrow')
Events_J_Cin_df['Date'] = Events_J_Cin_df['Date'].str.replace('7:.06','Tomorrow')
Events_J_Cin_df['Date'] = Events_J_Cin_df['Date'].str.replace('at.06','Tomorrow')
Events_J_Cin_df.drop(Events_J_Cin_df.loc[Events_J_Cin_df['Price']== '0€'].index, inplace=True)
Events_J_Cin_df['Price'] = Events_J_Cin_df['Price'].str.replace('€',' ')
Events_J_Cin_df['Price'] = Events_J_Cin_df['Price'].str.replace('$',' ')
Events_J_Cin_df['Price'] = Events_J_Cin_df['Price'].str.replace('£',' ')

Events_J_Cin_df.drop(Events_J_Cin_df.loc[Events_J_Cin_df['Price']== 'Free'].index, inplace=True)
Events_J_Cin_df.drop(Events_J_Cin_df.loc[Events_J_Cin_df['Price']== 'Kostenlos'].index, inplace=True)

Events_J_Cin_df.columns = Events_J_Cin_df.columns.str.strip().str.lower()


Events_J_Cin_df
# Out:
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/417983428.py:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_J_Cin_df['Date'] = Events_J_Cin_df['Date'].str.replace('8:.06','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/417983428.py:11: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_J_Cin_df['Date'] = Events_J_Cin_df['Date'].str.replace('7:.06','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/417983428.py:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_J_Cin_df['Date'] = Events_J_Cin_df['Date'].str.replace('at.06','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/417983428.py:15: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Events_J_Cin_df['Price'] = Events_J_Cin_df['Price'].str.replace('$',' ')
#                                                  name   date     price  \
# 1   https://www.eventbrite.de/e/english-comedy-ber...   3.06    22,51
# 2   https://www.eventbrite.co.uk/e/english-stand-u...  18.06     11.77
# 3   https://www.eventbrite.de/e/berlin-music-video...   8.06     22.49
# 4   https://www.eventbrite.de/e/berlin-freak-burle...  10.06       30
# 6   https://www.eventbrite.de/e/yaaas-queen-womxn-...   8.06        14
# 7   https://www.eventbrite.com/e/new-york-comedy-c...  27.06      2.14
# 8   https://www.eventbrite.co.uk/e/english-stand-u...   4.06     12.54
# 9   https://www.eventbrite.de/e/thats-what-she-sai...  25.06        16
# 10  https://www.eventbrite.de/e/three-way-show-ele...  17.06        13
# 11  https://www.eventbrite.de/e/laughing-spree-eng...  12.06      2.26
# 13  https://www.eventbrite.com/e/new-york-comedy-c...   6.06      2.14
# 15  https://www.eventbrite.com/e/the-witching-hour...   4.06  Donation
# 18  https://www.eventbrite.co.uk/e/expats-in-berli...   2.06      2.28
# 19  https://www.eventbrite.de/e/kat-nip-presents-l...  24.06        10
# 20  https://www.eventbrite.co.uk/e/gamesforum-berl...  15.06       240
# 21  https://www.eventbrite.de/e/boys-do-cry-standu...  26.06         8
#
#                                                 links
# 1   https://www.eventbrite.de/e/english-comedy-ber...
# 2   https://www.eventbrite.co.uk/e/english-stand-u...
# 3   https://www.eventbrite.de/e/berlin-music-video...
# 4   https://www.eventbrite.de/e/berlin-freak-burle...
# 6   https://www.eventbrite.de/e/yaaas-queen-womxn-...
# 7   https://www.eventbrite.com/e/new-york-comedy-c...
# 8   https://www.eventbrite.co.uk/e/english-stand-u...
# 9   https://www.eventbrite.de/e/thats-what-she-sai...
# 10  https://www.eventbrite.de/e/three-way-show-ele...
# 11  https://www.eventbrite.de/e/laughing-spree-eng...
# 13  https://www.eventbrite.com/e/new-york-comedy-c...
# 15  https://www.eventbrite.com/e/the-witching-hour...
# 18  https://www.eventbrite.co.uk/e/expats-in-berli...
# 19  https://www.eventbrite.de/e/kat-nip-presents-l...
# 20  https://www.eventbrite.co.uk/e/gamesforum-berl...
# 21  https://www.eventbrite.de/e/boys-do-cry-standu...

# %% [markdown]
# #### NO-FREE Events from Eventbrite in Berlin;
# #### Month: July (JL);
# #### Category: Cinema.

# %%
# A list with all the Event Names in July

Events_Names_JL_Cin = []
Events_Dates_JL_Cin = []
Events_Links_JL_Cin = []
Events_Prices_JL_Cin = []


for i in range(1,28):
    url = 'https://www.eventbrite.com/d/germany--berlin/film-and-media--events/paid-events/?page='
    url = url + str(i) + '&start_date=2022-07-01&end_date=2022-07-31'
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    names = soup.select('div.eds-is-hidden-accessible')[1::2]
    dates = soup.select('.eds-event-card-content__sub-title')[1::2]
    links = soup.select('.eds-event-card-content__action-link')[1::4]
    for name in names:
        Events_Names_JL_Cin.append(name.get_text(strip=True).lower())
    for date in dates:
        Events_Dates_JL_Cin.append(date.get_text(strip=True)[9:11].lower())
    for link in links:
        Events_Links_JL_Cin.append(link['href'])

        
        
        # EVENTS PRICES
    price_links = soup.select('.eds-event-card-content__primary-content a')[1::2]

    for price in price_links:
        response = requests.get(price['href'])
        soup = BeautifulSoup(response.content, 'html.parser')
        eprice = soup.select('.js-display-price')
    # print(price[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0])
        Events_Prices_JL_Cin.append(eprice[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0]) 
    

    
print(len(Events_Names_JL_Cin))
print(len(Events_Dates_JL_Cin))
print(len(Events_Links_JL_Cin))
print(len(Events_Prices_JL_Cin))
# Out:
# 5
# 5
# 5
# 5

# %%
# Make dictionary, keys that will become dataframe column names
Events_JL_dict = {'Name':Events_Names_JL_Cin, 'Date':Events_Dates_JL_Cin, 'Price': Events_Prices_JL_Cin, 'Links':Events_Links_JL_Cin}

# Convert dictionary to Pandas dataframe
Events_JL_Cin_df = pd.DataFrame(Events_JL_dict)
Events_JL_Cin_df.index = Events_JL_Cin_df.index + 1

Events_JL_Cin_df['Date'] = Events_JL_Cin_df['Date'].astype(str)+'.07'
Events_JL_Cin_df['Date'] = Events_JL_Cin_df['Date'].str.replace(',','')
Events_JL_Cin_df['Date'] = Events_JL_Cin_df['Date'].str.replace('8:.07','Tomorrow')
Events_JL_Cin_df['Date'] = Events_JL_Cin_df['Date'].str.replace('7:.07','Tomorrow')
Events_JL_Cin_df['Date'] = Events_JL_Cin_df['Date'].str.replace('at.07','Tomorrow')
Events_JL_Cin_df.drop(Events_JL_Cin_df.loc[Events_JL_Cin_df['Price']== '0€'].index, inplace=True)
Events_JL_Cin_df['Price'] = Events_JL_Cin_df['Price'].str.replace('€',' ')
Events_JL_Cin_df['Price'] = Events_JL_Cin_df['Price'].str.replace('$',' ')
Events_JL_Cin_df['Price'] = Events_JL_Cin_df['Price'].str.replace('£',' ')

Events_JL_Cin_df.drop(Events_JL_Cin_df.loc[Events_JL_Cin_df['Price']== 'Free'].index, inplace=True)
Events_JL_Cin_df.drop(Events_JL_Cin_df.loc[Events_JL_Cin_df['Price']== 'Kostenlos'].index, inplace=True)

Events_JL_Cin_df.columns = Events_JL_Cin_df.columns.str.strip().str.lower()


Events_JL_Cin_df
# Out:
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/3849581854.py:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_JL_Cin_df['Date'] = Events_JL_Cin_df['Date'].str.replace('8:.07','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/3849581854.py:11: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_JL_Cin_df['Date'] = Events_JL_Cin_df['Date'].str.replace('7:.07','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/3849581854.py:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_JL_Cin_df['Date'] = Events_JL_Cin_df['Date'].str.replace('at.07','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/3849581854.py:15: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Events_JL_Cin_df['Price'] = Events_JL_Cin_df['Price'].str.replace('$',' ')
#                                          name   date     price  \
# 1  english comedy berlin with pizza and shots   1.07    22,51
# 2  yaaas queen! | womxn & lgbtq+ comedy night  13.07        14
# 3                           the witching hour   2.07  Donation
# 5                       movie campout weekend   1.07        10
#
#                                                links
# 1  https://www.eventbrite.de/e/english-comedy-ber...
# 2  https://www.eventbrite.de/e/yaaas-queen-womxn-...
# 3  https://www.eventbrite.com/e/the-witching-hour...
# 5  https://www.eventbrite.com/e/movie-campout-wee...

# %% [markdown]
# #### NO-FREE Events from Eventbrite in Berlin;
# #### Month: August (A);
# #### Category: Cinema.

# %%
# A list with all the Event Names in June

Events_Names_A_Cin = []
Events_Dates_A_Cin = []
Events_Links_A_Cin = []
Events_Prices_A_Cin = []


for i in range(1,28):
    url = 'https://www.eventbrite.com/d/germany--berlin/paid--film-and-media--events/paid-events/?end_date=2022-08-31&page='
    url = url + str(i) + '&start_date=2022-08-01'
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    names = soup.select('div.eds-is-hidden-accessible')[1::2]
    dates = soup.select('.eds-event-card-content__sub-title')[1::2]
    links = soup.select('.eds-event-card-content__action-link')[1::4]
    for name in names:
        Events_Names_A_Cin.append(name.get_text(strip=True).lower())
    for date in dates:
        Events_Dates_A_Cin.append(date.get_text(strip=True)[9:11].lower())
    for link in links:
        Events_Links_A_Cin.append(link['href'])

        
        # EVENTS PRICES
    price_links = soup.select('.eds-event-card-content__primary-content a')[1::2]

    for price in price_links:
        response = requests.get(price['href'])
        soup = BeautifulSoup(response.content, 'html.parser')
        eprice = soup.select('.js-display-price')
    # print(price[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0])
        Events_Prices_A_Cin.append(eprice[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0]) 
    

print(len(Events_Names_A_Cin))
print(len(Events_Dates_A_Cin))
print(len(Events_Links_A_Cin))
print(len(Events_Prices_A_Cin))
# Out:
# 1
# 1
# 1
# 1

# %%
# Make dictionary, keys that will become dataframe column names
Events_A_dict = {'Name':Events_Names_A_Cin, 'Date':Events_Dates_A_Cin, 'Price':Events_Prices_A_Cin, 'Links':Events_Links_A_Cin}

# Convert dictionary to Pandas dataframe
Events_A_Cin_df = pd.DataFrame(Events_A_dict)
Events_A_Cin_df.index = Events_A_Cin_df.index + 1

Events_A_Cin_df['Date'] = Events_A_Cin_df['Date'].astype(str)+'.08'
Events_A_Cin_df['Date'] = Events_A_Cin_df['Date'].str.replace(',','')
Events_A_Cin_df['Date'] = Events_A_Cin_df['Date'].str.replace('8:.08','Tomorrow')
Events_A_Cin_df['Date'] = Events_A_Cin_df['Date'].str.replace('7:.08','Tomorrow')
Events_A_Cin_df['Date'] = Events_A_Cin_df['Date'].str.replace('at.08','Tomorrow')
Events_A_Cin_df.drop(Events_A_Cin_df.loc[Events_A_Cin_df['Price']== '0€'].index, inplace=True)
Events_A_Cin_df['Price'] = Events_A_Cin_df['Price'].str.replace('€',' ')
Events_A_Cin_df['Price'] = Events_A_Cin_df['Price'].str.replace('$',' ')
Events_A_Cin_df['Price'] = Events_A_Cin_df['Price'].str.replace('£',' ')

Events_A_Cin_df.drop(Events_A_Cin_df.loc[Events_A_Cin_df['Price']== 'Free'].index, inplace=True)
Events_A_Cin_df.drop(Events_A_Cin_df.loc[Events_A_Cin_df['Price']== 'Kostenlos'].index, inplace=True)

Events_A_Cin_df.columns = Events_A_Cin_df.columns.str.strip().str.lower()


Events_A_Cin_df
# Out:
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/3397666311.py:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_A_Cin_df['Date'] = Events_A_Cin_df['Date'].str.replace('8:.08','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/3397666311.py:11: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_A_Cin_df['Date'] = Events_A_Cin_df['Date'].str.replace('7:.08','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/3397666311.py:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_A_Cin_df['Date'] = Events_A_Cin_df['Date'].str.replace('at.08','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/3397666311.py:15: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Events_A_Cin_df['Price'] = Events_A_Cin_df['Price'].str.replace('$',' ')
#                 name  date     price  \
# 1  the witching hour  6.08  Donation
#
#                                                links
# 1  https://www.eventbrite.com/e/the-witching-hour...

# %% [markdown]
# #### NO-FREE Events from Eventbrite in Berlin;
# #### Month: May (M);
# #### Category: Science (S).

# %%
# A list with all the Event Names in May

Events_Names_M_S = []
Events_Dates_M_S = []
Events_Links_M_S = []
Events_Prices_M_S = []


for i in range(1,28):
    url = 'https://www.eventbrite.com/d/germany--berlin/science-and-tech--events--this-month/paid-events/?page='
    url = url + str(i) 
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    names = soup.select('div.eds-is-hidden-accessible')[1::2]
    dates = soup.select('.eds-event-card-content__sub-title')[1::2]
    links = soup.select('.eds-event-card-content__action-link')[1::4]
    for name in names:
        Events_Names_M_S.append(name.get_text(strip=True).lower())
    for date in dates:
        Events_Dates_M_S.append(date.get_text(strip=True)[9:11].lower())
    for link in links:
        Events_Links_M_S.append(link['href'])

        
        # EVENTS PRICES
    price_links = soup.select('.eds-event-card-content__primary-content a')[1::2]

    for price in price_links:
        response = requests.get(price['href'])
        soup = BeautifulSoup(response.content, 'html.parser')
        eprice = soup.select('.js-display-price')
    # print(price[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0])
        Events_Prices_M_S.append(eprice[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0]) 
    

print(len(Events_Names_M_S))
print(len(Events_Dates_M_S))
print(len(Events_Links_M_S))
print(len(Events_Prices_M_S))
# Out:
# 1
# 1
# 1
# 1

# %%
# Make dictionary, keys that will become dataframe column names
Events_M_dict = {'Name':Events_Names_M_S, 'Date':Events_Dates_M_S, 'Price': Events_Prices_M_S,'Links':Events_Links_M_S}

# Convert dictionary to Pandas dataframe
Events_M_S_df = pd.DataFrame(Events_M_dict)
Events_M_S_df.index = Events_M_S_df.index + 1

Events_M_S_df['Date'] = Events_M_S_df['Date'].astype(str)+'.05'
Events_M_S_df['Date'] = Events_M_S_df['Date'].str.replace(',','')
Events_M_S_df['Date'] = Events_M_S_df['Date'].str.replace('8:.05','Tomorrow')
Events_M_S_df['Date'] = Events_M_S_df['Date'].str.replace('7:.05','Tomorrow')
Events_M_S_df['Date'] = Events_M_S_df['Date'].str.replace('at.05','Tomorrow')
Events_M_S_df.drop(Events_M_S_df.loc[Events_M_S_df['Price']== '0€'].index, inplace=True)
Events_M_S_df['Price'] = Events_M_S_df['Price'].str.replace('€',' ')
Events_M_S_df['Price'] = Events_M_S_df['Price'].str.replace('$',' ')
Events_M_S_df['Price'] = Events_M_S_df['Price'].str.replace('£',' ')

Events_M_S_df.drop(Events_M_S_df.loc[Events_M_S_df['Price']== 'Free'].index, inplace=True)
Events_M_S_df.drop(Events_M_S_df.loc[Events_M_S_df['Price']== 'Kostenlos'].index, inplace=True)
Events_M_S_df.drop(Events_M_S_df.loc[Events_M_S_df['Price']== '0€'].index, inplace=True)

Events_M_S_df.columns = Events_M_S_df.columns.str.strip().str.lower()


Events_M_S_df
# Out:
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/1141910689.py:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_M_S_df['Date'] = Events_M_S_df['Date'].str.replace('8:.05','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/1141910689.py:11: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_M_S_df['Date'] = Events_M_S_df['Date'].str.replace('7:.05','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/1141910689.py:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_M_S_df['Date'] = Events_M_S_df['Date'].str.replace('at.05','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/1141910689.py:15: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Events_M_S_df['Price'] = Events_M_S_df['Price'].str.replace('$',' ')
# Empty DataFrame
# Columns: [name, date, price, links]
# Index: []

# %% [markdown]
# #### NO-FREE Events from Eventbrite in Berlin;
# #### Month: June (J);
# #### Category: Science (S).

# %%
# A list with all the Event Names in June

Events_Names_J_S = []
Events_Dates_J_S = []
Events_Links_J_S = []
Events_Prices_J_S = []


for i in range(1,28):
    url = 'https://www.eventbrite.com/d/germany--berlin/science-and-tech--events--next-month/paid-events/?page='
    url = url + str(i) 
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    names = soup.select('div.eds-is-hidden-accessible')[1::2]
    dates = soup.select('.eds-event-card-content__sub-title')[1::2]
    links = soup.select('.eds-event-card-content__action-link')[1::4]
    for name in names:
        Events_Names_J_S.append(name.get_text(strip=True).lower())
    for date in dates:
        Events_Dates_J_S.append(date.get_text(strip=True)[9:11].lower())
    for link in links:
        Events_Links_J_S.append(link['href'])

        # EVENTS PRICES
    price_links = soup.select('.eds-event-card-content__primary-content a')[1::2]

    for price in price_links:
        response = requests.get(price['href'])
        soup = BeautifulSoup(response.content, 'html.parser')
        eprice = soup.select('.js-display-price')
    # print(price[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0])
        Events_Prices_J_S.append(eprice[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0]) 
    


print(len(Events_Names_J_S))
print(len(Events_Dates_J_S))
print(len(Events_Links_J_S))
print(len(Events_Prices_J_S))
# Out:
# 4
# 4
# 4
# 4

# %%
# Make dictionary, keys that will become dataframe column names
Events_J_dict = {'Name':Events_Names_J_S, 'Date':Events_Dates_J_S, 'Price':Events_Prices_J_S, 'Links':Events_Links_J_S}

# Convert dictionary to Pandas dataframe
Events_J_S_df = pd.DataFrame(Events_J_dict)
Events_J_S_df.index = Events_J_S_df.index + 1

Events_J_S_df['Date'] = Events_J_S_df['Date'].astype(str)+'.06'
Events_J_S_df['Date'] = Events_J_S_df['Date'].str.replace(',','')
Events_J_S_df['Date'] = Events_J_S_df['Date'].str.replace('8:.06','Tomorrow')
Events_J_S_df['Date'] = Events_J_S_df['Date'].str.replace('7:.06','Tomorrow')
Events_J_S_df['Date'] = Events_J_S_df['Date'].str.replace('at.06','Tomorrow')
Events_J_S_df.drop(Events_J_S_df.loc[Events_J_S_df['Price']== '0€'].index, inplace=True)
Events_J_S_df['Price'] = Events_J_S_df['Price'].str.replace('€',' ')
Events_J_S_df['Price'] = Events_J_S_df['Price'].str.replace('$',' ')
Events_J_S_df['Price'] = Events_J_S_df['Price'].str.replace('£',' ')
Events_J_S_df.drop(Events_J_S_df.loc[Events_J_S_df['Price']== '0'].index, inplace=True)
Events_J_S_df.drop(Events_J_S_df.loc[Events_J_S_df['Price']== 'Free'].index, inplace=True)
Events_J_S_df.drop(Events_J_S_df.loc[Events_J_S_df['Price']== 'Kostenlos'].index, inplace=True)


Events_J_S_df.columns = Events_J_S_df.columns.str.strip().str.lower()


Events_J_S_df
# Out:
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/2779486093.py:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_J_S_df['Date'] = Events_J_S_df['Date'].str.replace('8:.06','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/2779486093.py:11: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_J_S_df['Date'] = Events_J_S_df['Date'].str.replace('7:.06','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/2779486093.py:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_J_S_df['Date'] = Events_J_S_df['Date'].str.replace('at.06','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/2779486093.py:15: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Events_J_S_df['Price'] = Events_J_S_df['Price'].str.replace('$',' ')
#                                                 name   date   price  \
# 1                                    prisma day 2022  16.06       0
# 2                   :clojured berlin conference 2022  11.06      79
# 3                       openinfra summit berlin 2022   7.06   1,199
# 4  workshop - introduction to laser cutting and e...   2.06   70.23
#
#                                                links
# 1  https://www.eventbrite.com/e/prisma-day-2022-t...
# 2  https://www.eventbrite.de/e/clojured-berlin-co...
# 3  https://www.eventbrite.com/e/openinfra-summit-...
# 4  https://www.eventbrite.de/e/workshop-introduct...

# %% [markdown]
# #### NO-FREE Events from Eventbrite in Berlin;
# #### Month: July (JL);
# #### Category: Science (S).

# %%
# A list with all the Event Names in July

Events_Names_JL_S = []
Events_Dates_JL_S = []
Events_Links_JL_S = []
Events_Prices_JL_S= []


for i in range(1,28):
    url = 'https://www.eventbrite.com/d/germany--berlin/science-and-tech--events/paid-events/?page='
    url = url + str(i) + '&start_date=2022-07-01&end_date=2022-07-31'
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    names = soup.select('div.eds-is-hidden-accessible')[1::2]
    dates = soup.select('.eds-event-card-content__sub-title')[1::2]
    links = soup.select('.eds-event-card-content__action-link')[1::4]
    for name in names:
        Events_Names_JL_S.append(name.get_text(strip=True).lower())
    for date in dates:
        Events_Dates_JL_S.append(date.get_text(strip=True)[9:11].lower())
    for link in links:
        Events_Links_JL_S.append(link['href'])

        
        
        # EVENTS PRICES
    price_links = soup.select('.eds-event-card-content__primary-content a')[1::2]

    for price in price_links:
        response = requests.get(price['href'])
        soup = BeautifulSoup(response.content, 'html.parser')
        eprice = soup.select('.js-display-price')
    # print(price[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0])
        Events_Prices_JL_S.append(eprice[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0]) 
    


print(len(Events_Names_JL_S))
print(len(Events_Dates_JL_S))
print(len(Events_Links_JL_S))
print(len(Events_Prices_JL_S))
# Out:
# 1
# 1
# 1
# 1

# %%
# Make dictionary, keys that will become dataframe column names
Events_JL_dict = {'Name':Events_Names_JL_S, 'Date':Events_Dates_JL_S, 'Price': Events_Prices_JL_S, 'Links':Events_Links_JL_S}

# Convert dictionary to Pandas dataframe
Events_JL_S_df = pd.DataFrame(Events_JL_dict)
Events_JL_S_df.index = Events_JL_S_df.index + 1

Events_JL_S_df['Date'] = Events_JL_S_df['Date'].astype(str)+'.07'
Events_JL_S_df['Date'] = Events_JL_S_df['Date'].str.replace(',','')
Events_JL_S_df['Date'] = Events_JL_S_df['Date'].str.replace('8:.07','Tomorrow')
Events_JL_S_df['Date'] = Events_JL_S_df['Date'].str.replace('7:.07','Tomorrow')
Events_JL_S_df['Date'] = Events_JL_S_df['Date'].str.replace('at.07','Tomorrow')
Events_JL_S_df.drop(Events_JL_S_df.loc[Events_JL_S_df['Price']== '0€'].index, inplace=True)
Events_JL_S_df['Price'] = Events_JL_S_df['Price'].str.replace('€',' ')
Events_JL_S_df['Price'] = Events_JL_S_df['Price'].str.replace('$',' ')
Events_JL_S_df['Price'] = Events_JL_S_df['Price'].str.replace('£',' ')

Events_JL_S_df.columns = Events_JL_S_df.columns.str.strip().str.lower()


Events_JL_S_df
# Out:
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/1462705554.py:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_JL_S_df['Date'] = Events_JL_S_df['Date'].str.replace('8:.07','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/1462705554.py:11: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_JL_S_df['Date'] = Events_JL_S_df['Date'].str.replace('7:.07','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/1462705554.py:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_JL_S_df['Date'] = Events_JL_S_df['Date'].str.replace('at.07','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/1462705554.py:15: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Events_JL_S_df['Price'] = Events_JL_S_df['Price'].str.replace('$',' ')
#                                            name   date    price  \
# 1  gophercon europe 2022 - online and in-person  28.07   126.72
#
#                                                links
# 1  https://www.eventbrite.com/e/gophercon-europe-...

# %% [markdown]
# #### NO-FREE Events from Eventbrite in Berlin;
# #### Month: August (A);
# #### Category: Science (S).

# %%
# A list with all the Event Names in August

Events_Names_A_S = []
Events_Dates_A_S = []
Events_Links_A_S = []
Events_Prices_A_S = []

for i in range(1,28):
    url = 'https://www.eventbrite.com/d/germany--berlin/science-and-tech--events/paid-events/?end_date=2022-08-31&page='
    url = url + str(i) + '&start_date=2022-08-01'
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    names = soup.select('div.eds-is-hidden-accessible')[1::2]
    dates = soup.select('.eds-event-card-content__sub-title')[1::2]
    links = soup.select('.eds-event-card-content__action-link')[1::4]
    for name in names:
        Events_Names_A_S.append(name.get_text(strip=True).lower())
    for date in dates:
        Events_Dates_A_S.append(date.get_text(strip=True)[9:11].lower())
    for link in links:
        Events_Links_A_S.append(link['href'])

         
        # EVENTS PRICES
    price_links = soup.select('.eds-event-card-content__primary-content a')[1::2]

    for price in price_links:
        response = requests.get(price['href'])
        soup = BeautifulSoup(response.content, 'html.parser')
        eprice = soup.select('.js-display-price')
    # print(price[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0])
        Events_Prices_A_S.append(eprice[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0]) 
    



print(len(Events_Names_A_S))
print(len(Events_Dates_A_S))
print(len(Events_Links_A_S))
print(len(Events_Prices_A_S))
# Out:
# 1
# 1
# 1
# 1

# %%
# Make dictionary, keys that will become dataframe column names
Events_A_dict = {'Name':Events_Names_A_S, 'Date':Events_Dates_A_S, 'Price':Events_Prices_A_S, 'Links':Events_Links_A_S}

# Convert dictionary to Pandas dataframe
Events_A_S_df = pd.DataFrame(Events_A_dict)
Events_A_S_df.index = Events_A_S_df.index + 1

Events_A_S_df['Date'] = Events_A_S_df['Date'].astype(str)+'.08'
Events_A_S_df['Date'] = Events_A_S_df['Date'].str.replace(',','')
Events_A_S_df['Date'] = Events_A_S_df['Date'].str.replace('8:.08','Tomorrow')
Events_A_S_df['Date'] = Events_A_S_df['Date'].str.replace('7:.08','Tomorrow')
Events_A_S_df['Date'] = Events_A_S_df['Date'].str.replace('at.08','Tomorrow')
Events_A_S_df.drop(Events_A_S_df.loc[Events_A_S_df['Price']== '0€'].index, inplace=True)
Events_A_S_df['Price'] = Events_A_S_df['Price'].str.replace('€',' ')
Events_A_S_df['Price'] = Events_A_S_df['Price'].str.replace('$',' ')
Events_A_S_df['Price'] = Events_A_S_df['Price'].str.replace('£',' ')

Events_A_S_df.columns = Events_A_S_df.columns.str.strip().str.lower()


Events_A_S_df
# Out:
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/149889259.py:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_A_S_df['Date'] = Events_A_S_df['Date'].str.replace('8:.08','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/149889259.py:11: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_A_S_df['Date'] = Events_A_S_df['Date'].str.replace('7:.08','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/149889259.py:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_A_S_df['Date'] = Events_A_S_df['Date'].str.replace('at.08','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/149889259.py:15: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Events_A_S_df['Price'] = Events_A_S_df['Price'].str.replace('$',' ')
#                                                 name   date   price  \
# 1  4th edition - sx tech eu conference - berlin -...  31.08   74.70
#
#                                                links
# 1  https://www.eventbrite.ie/e/4th-edition-sx-tec...

# %% [markdown]
# #### NO-FREE Events from Eventbrite in Berlin;
# #### Month: May (M);
# #### Category: Sport (Sp).

# %%
# A list with all the Event Names in May

Events_Names_M_Sp = []
Events_Dates_M_Sp = []
Events_Links_M_Sp = []
Events_Prices_M_Sp = []


for i in range(1,28):
    url = 'https://www.eventbrite.com/d/germany--berlin/sports-and-fitness--events--this-month/paid-events/?page='
    url = url + str(i) 
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    names = soup.select('div.eds-is-hidden-accessible')[1::2]
    dates = soup.select('.eds-event-card-content__sub-title')[1::2]
    links = soup.select('.eds-event-card-content__action-link')[1::4]
    for name in names:
        Events_Names_M_Sp.append(name.get_text(strip=True).lower())
    for date in dates:
        Events_Dates_M_Sp.append(date.get_text(strip=True)[9:11].lower())
    for link in links:
        Events_Links_M_Sp.append(link['href'])

         
        # EVENTS PRICES
    price_links = soup.select('.eds-event-card-content__primary-content a')[1::2]

    for price in price_links:
        response = requests.get(price['href'])
        soup = BeautifulSoup(response.content, 'html.parser')
        eprice = soup.select('.js-display-price')
    # print(price[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0])
        Events_Prices_M_Sp.append(eprice[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0]) 
    


print(len(Events_Names_M_Sp))
print(len(Events_Dates_M_Sp))
print(len(Events_Links_M_Sp))
print(len(Events_Prices_M_Sp))
# Out:
# 7
# 7
# 7
# 7

# %%
# Make dictionary, keys that will become dataframe column names
Events_M_dict = {'Name':Events_Names_M_Sp, 'Date':Events_Dates_M_Sp, 'Price':Events_Prices_M_Sp, 'Links':Events_Links_M_Sp}

# Convert dictionary to Pandas dataframe
Events_M_Sp_df = pd.DataFrame(Events_M_dict)
Events_M_Sp_df.index = Events_M_Sp_df.index + 1

Events_M_Sp_df['Date'] = Events_M_Sp_df['Date'].astype(str)+'.05'
Events_M_Sp_df['Date'] = Events_M_Sp_df['Date'].str.replace(',','')
Events_M_Sp_df['Date'] = Events_M_Sp_df['Date'].str.replace('8:.05','Tomorrow')
Events_M_Sp_df['Date'] = Events_M_Sp_df['Date'].str.replace('7:.05','Tomorrow')
Events_M_Sp_df['Date'] = Events_M_Sp_df['Date'].str.replace('at.05','Tomorrow')
Events_M_Sp_df.drop(Events_M_Sp_df.loc[Events_M_Sp_df['Price']== '0€'].index, inplace=True)
Events_M_Sp_df['Price'] = Events_M_Sp_df['Price'].str.replace('€',' ')
Events_M_Sp_df['Price'] = Events_M_Sp_df['Price'].str.replace('$',' ')
Events_M_Sp_df['Price'] = Events_M_Sp_df['Price'].str.replace('£',' ')

Events_M_Sp_df.drop(Events_M_Sp_df.loc[Events_M_Sp_df['Price']== 'Free'].index, inplace=True)
Events_M_Sp_df.drop(Events_M_Sp_df.loc[Events_M_Sp_df['Price']== 'Kostenlos'].index, inplace=True)
Events_M_Sp_df.drop(Events_M_Sp_df.loc[Events_M_Sp_df['Price']== '0€'].index, inplace=True)

Events_M_Sp_df.columns = Events_M_Sp_df.columns.str.strip().str.lower()

Events_M_Sp_df
# Out:
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/4230781201.py:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_M_Sp_df['Date'] = Events_M_Sp_df['Date'].str.replace('8:.05','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/4230781201.py:11: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_M_Sp_df['Date'] = Events_M_Sp_df['Date'].str.replace('7:.05','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/4230781201.py:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_M_Sp_df['Date'] = Events_M_Sp_df['Date'].str.replace('at.05','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/4230781201.py:15: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Events_M_Sp_df['Price'] = Events_M_Sp_df['Price'].str.replace('$',' ')
#                                                 name      date   price  \
# 1  peacock’s paradise: discover an island full of...  Tomorrow     15
# 2  nature games in grunewald: let out your inner ...  Tomorrow     15
# 3  nature cycling: explore one of the most famous...     27.05     19
# 4  hiit the road berlin by growingannanas + live ...  Tomorrow   39.99
# 5  urban foraging: discover the edible treasures ...  Tomorrow     23
# 6  spreewald canoe tour: discover the unesco bios...     28.05     27
#
#                                                links
# 1  https://www.eventbrite.de/e/peacocks-paradise-...
# 2  https://www.eventbrite.de/e/nature-games-in-gr...
# 3  https://www.eventbrite.de/e/nature-cycling-exp...
# 4  https://www.eventbrite.de/e/hiit-the-road-berl...
# 5  https://www.eventbrite.de/e/urban-foraging-dis...
# 6  https://www.eventbrite.de/e/spreewald-canoe-to...

# %% [markdown]
# #### NO-FREE Events from Eventbrite in Berlin;
# #### Month: June (J);
# #### Category: Sport (Sp).

# %%
# A list with all the Event Names in June

Events_Names_J_Sp = []
Events_Dates_J_Sp = []
Events_Links_J_Sp = []
Events_Prices_J_Sp = []

for i in range(1,28):
    url = 'https://www.eventbrite.com/d/germany--berlin/sports-and-fitness--events--next-month/paid-events/?page='
    url = url + str(i) 
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    names = soup.select('div.eds-is-hidden-accessible')[1::2]
    dates = soup.select('.eds-event-card-content__sub-title')[1::2]
    links = soup.select('.eds-event-card-content__action-link')[1::4]
    for name in names:
        Events_Names_J_Sp.append(name.get_text(strip=True).lower())
    for date in dates:
        Events_Dates_J_Sp.append(date.get_text(strip=True)[9:11].lower())
    for link in links:
        Events_Links_J_Sp.append(link['href'])

        # EVENTS PRICES
    price_links = soup.select('.eds-event-card-content__primary-content a')[1::2]

    for price in price_links:
        response = requests.get(price['href'])
        soup = BeautifulSoup(response.content, 'html.parser')
        eprice = soup.select('.js-display-price')
    # print(price[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0])
        Events_Prices_J_Sp.append(eprice[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0]) 
    



print(len(Events_Names_J_Sp))
print(len(Events_Dates_J_Sp))
print(len(Events_Links_J_Sp))
print(len(Events_Prices_J_Sp))
# Out:
# 5
# 5
# 5
# 5

# %%
# Make dictionary, keys that will become dataframe column names
Events_J_dict = {'Name':Events_Names_J_Sp, 'Date':Events_Dates_J_Sp, 'Price':Events_Prices_J_Sp, 'Links':Events_Links_J_Sp}

# Convert dictionary to Pandas dataframe
Events_J_Sp_df = pd.DataFrame(Events_J_dict)
Events_J_Sp_df.index = Events_J_Sp_df.index + 1

Events_J_Sp_df['Date'] = Events_J_Sp_df['Date'].astype(str)+'.06'
Events_J_Sp_df['Date'] = Events_J_Sp_df['Date'].str.replace(',','')
Events_J_Sp_df['Date'] = Events_J_Sp_df['Date'].str.replace('8:.06','Tomorrow')
Events_J_Sp_df['Date'] = Events_J_Sp_df['Date'].str.replace('7:.06','Tomorrow')
Events_J_Sp_df['Date'] = Events_J_Sp_df['Date'].str.replace('at.06','Tomorrow')
Events_J_Sp_df.drop(Events_J_Sp_df.loc[Events_J_Sp_df['Price']== '0€'].index, inplace=True)
Events_J_Sp_df['Price'] = Events_J_Sp_df['Price'].str.replace('€',' ')
Events_J_Sp_df['Price'] = Events_J_Sp_df['Price'].str.replace('$',' ')
Events_J_Sp_df['Price'] = Events_J_Sp_df['Price'].str.replace('£',' ')


Events_J_Sp_df.drop(Events_J_Sp_df.loc[Events_J_Sp_df['Price']== 'Free'].index, inplace=True)
Events_J_Sp_df.drop(Events_J_Sp_df.loc[Events_J_Sp_df['Price']== 'Kostenlos'].index, inplace=True)
Events_J_Sp_df.drop(Events_J_Sp_df.loc[Events_J_Sp_df['Price']== '0€'].index, inplace=True)


Events_J_Sp_df.columns = Events_J_Sp_df.columns.str.strip().str.lower()

Events_J_Sp_df
# Out:
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/3857530586.py:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_J_Sp_df['Date'] = Events_J_Sp_df['Date'].str.replace('8:.06','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/3857530586.py:11: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_J_Sp_df['Date'] = Events_J_Sp_df['Date'].str.replace('7:.06','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/3857530586.py:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_J_Sp_df['Date'] = Events_J_Sp_df['Date'].str.replace('at.06','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/3857530586.py:15: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Events_J_Sp_df['Price'] = Events_J_Sp_df['Price'].str.replace('$',' ')
#                                                 name   date price  \
# 1  peacock’s paradise: discover an island full of...  11.06   15
# 2  fairytale forest: hike through the mystical la...   5.06    16
# 3  water world: enjoy a day in the gorgeous river...   4.06   15
# 4  spreewald canoe tour: discover the unesco bios...  12.06   27
#
#                                                links
# 1  https://www.eventbrite.de/e/peacocks-paradise-...
# 2  https://www.eventbrite.de/e/fairytale-forest-h...
# 3  https://www.eventbrite.de/e/water-world-enjoy-...
# 4  https://www.eventbrite.de/e/spreewald-canoe-to...

# %% [markdown]
# #### NO-FREE Events from Eventbrite in Berlin;
# #### Month: July (JL);
# #### Category: Sport (Sp).

# %%
# A list with all the Event Names in July

Events_Names_JL_Sp = []
Events_Dates_JL_Sp = []
Events_Links_JL_Sp = []
Events_Prices_JL_Sp = []


for i in range(1,28):
    url = 'https://www.eventbrite.com/d/germany--berlin/sports-and-fitness--events/paid-events/?page='
    url = url + str(i) + '&start_date=2022-07-01&end_date=2022-07-31'
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    names = soup.select('div.eds-is-hidden-accessible')[1::2]
    dates = soup.select('.eds-event-card-content__sub-title')[1::2]
    links = soup.select('.eds-event-card-content__action-link')[1::4]
    for name in names:
        Events_Names_JL_Sp.append(name.get_text(strip=True).lower())
    for date in dates:
        Events_Dates_JL_Sp.append(date.get_text(strip=True)[9:11].lower())
    for link in links:
        Events_Links_JL_Sp.append(link['href'])

    # EVENTS PRICES
    price_links = soup.select('.eds-event-card-content__primary-content a')[1::2]

    for price in price_links:
        response = requests.get(price['href'])
        soup = BeautifulSoup(response.content, 'html.parser')
        eprice = soup.select('.js-display-price')
    # print(price[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0])
        Events_Prices_JL_Sp.append(eprice[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0]) 
    
    
print(len(Events_Names_JL_Sp))
print(len(Events_Dates_JL_Sp))
print(len(Events_Links_JL_Sp))
print(len(Events_Prices_JL_Sp))

# NOTEs: NO Events
# Out:
# 0
# 0
# 0
# 0

# %%
# Make dictionary, keys that will become dataframe column names
#Events_JL_dict = {'Name':Events_Names_JL_Sp, 'Date':Events_Dates_JL_Sp, 'Links':Events_Links_JL_Sp}

# Convert dictionary to Pandas dataframe
#Events_JL_Sp_df = pd.DataFrame(Events_JL_dict)
#Events_JL_Sp_df.index = Events_JL_Sp_df.index + 1
#Events_JL_Sp_df['Date'] = Events_JL_Sp_df['Date'].str.replace('at','Tomorrow')
#Events_JL_Sp_df['Date'] = Events_JL_Sp_df['Date'].str.replace(',','')
#Events_JL_Sp_df

# %% [markdown]
# #### NO-FREE Events from Eventbrite in Berlin;
# #### Month: August (A);
# #### Category: Sport (Sp).

# %%
# A list with all the Event Names in August

Events_Names_A_Sp = []
Events_Dates_A_Sp = []
Events_Links_A_Sp = []
Events_Prices_A_Sp = []


for i in range(1,28):
    url = 'https://www.eventbrite.com/d/germany--berlin/sports-and-fitness--events/paid-events/?end_date=2022-08-31&page='
    url = url + str(i) + '&start_date=2022-08-01'
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    names = soup.select('div.eds-is-hidden-accessible')[1::2]
    dates = soup.select('.eds-event-card-content__sub-title')[1::2]
    links = soup.select('.eds-event-card-content__action-link')[1::4]
    for name in names:
        Events_Names_A_Sp.append(name.get_text(strip=True).lower())
    for date in dates:
        Events_Dates_A_Sp.append(date.get_text(strip=True)[9:11].lower())
    for link in links:
        Events_Links_A_Sp.append(link['href'])

        
         # EVENTS PRICES
    price_links = soup.select('.eds-event-card-content__primary-content a')[1::2]

    for price in price_links:
        response = requests.get(price['href'])
        soup = BeautifulSoup(response.content, 'html.parser')
        eprice = soup.select('.js-display-price')
    # print(price[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0])
        Events_Prices_A_Sp.append(eprice[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0]) 
    

print(len(Events_Names_A_Sp))
print(len(Events_Dates_A_Sp))
print(len(Events_Links_A_Sp))
print(len(Events_Prices_A_Sp))

# NOTEs: NO Events
# Out:
# 0
# 0
# 0
# 0

# %%
# Make dictionary, keys that will become dataframe column names
#Events_A_dict = {'Name':Events_Names_A_Sp, 'Date':Events_Dates_A_Sp, 'Links':Events_Links_A_Sp}

# Convert dictionary to Pandas dataframe
#Events_A_Sp_df = pd.DataFrame(Events_A_dict)
#Events_A_Sp_df.index = Events_A_Sp_df.index + 1
#Events_A_Sp_df['Date'] = Events_A_Sp_df['Date'].str.replace('at','Tomorrow')
#Events_A_Sp_df['Date'] = Events_A_Sp_df['Date'].str.replace(',','')
#Events_A_Sp_df

# %% [markdown]
# #### NO-FREE Events from Eventbrite in Berlin;
# #### Month: May (M);
# #### Category: Outdoor (Out).

# %%
# A list with all the Event Names in May

Events_Names_M_Out = []
Events_Dates_M_Out = []
Events_Links_M_Out = []
Events_Prices_M_Out = []


for i in range(1,28):
    url = 'https://www.eventbrite.com/d/germany--berlin/travel-and-outdoor--events--this-month/paid-events/?page='
    url = url + str(i) 
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    names = soup.select('div.eds-is-hidden-accessible')[1::2]
    dates = soup.select('.eds-event-card-content__sub-title')[1::2]
    links = soup.select('.eds-event-card-content__action-link')[1::4]
    for name in names:
        Events_Names_M_Out.append(name.get_text(strip=True).lower())
    for date in dates:
        Events_Dates_M_Out.append(date.get_text(strip=True)[9:11].lower())
    for link in links:
        Events_Links_M_Out.append(link['href'])

 # EVENTS PRICES
    price_links = soup.select('.eds-event-card-content__primary-content a')[1::2]

    for price in price_links:
        response = requests.get(price['href'])
        soup = BeautifulSoup(response.content, 'html.parser')
        eprice = soup.select('.js-display-price')
    # print(price[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0])
        Events_Prices_M_Out.append(eprice[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0]) 
    
    
print(len(Events_Names_M_Out))
print(len(Events_Dates_M_Out))
print(len(Events_Links_M_Out))
print(len(Events_Prices_M_Out))
# Out:
# 3
# 3
# 3
# 3

# %%
# Make dictionary, keys that will become dataframe column names
Events_M_dict = {'Name':Events_Names_M_Out, 'Date':Events_Dates_M_Out, 'Price': Events_Prices_M_Out, 'Links':Events_Links_M_Out}

# Convert dictionary to Pandas dataframe
Events_M_Out_df = pd.DataFrame(Events_M_dict)
Events_M_Out_df.index = Events_M_Out_df.index + 1

Events_M_Out_df['Date'] = Events_M_Out_df['Date'].astype(str)+'.05'
Events_M_Out_df['Date'] = Events_M_Out_df['Date'].str.replace(',','')
Events_M_Out_df['Date'] = Events_M_Out_df['Date'].str.replace('8:.05','Tomorrow')
Events_M_Out_df['Date'] = Events_M_Out_df['Date'].str.replace('7:.05','Tomorrow')
Events_M_Out_df['Date'] = Events_M_Out_df['Date'].str.replace('at.05','Tomorrow')
Events_M_Out_df.drop(Events_M_Out_df.loc[Events_M_Out_df['Price']== '0€'].index, inplace=True)
Events_M_Out_df['Price'] = Events_M_Out_df['Price'].str.replace('€',' ')
Events_M_Out_df['Price'] = Events_M_Out_df['Price'].str.replace('$',' ')
Events_M_Out_df['Price'] = Events_M_Out_df['Price'].str.replace('£',' ')

Events_M_Out_df.drop(Events_M_Out_df.loc[Events_M_Out_df['Price']== 'Free'].index, inplace=True)
Events_M_Out_df.drop(Events_M_Out_df.loc[Events_M_Out_df['Price']== 'Kostenlos'].index, inplace=True)
Events_M_Out_df.drop(Events_M_Out_df.loc[Events_M_Out_df['Price']== '0€'].index, inplace=True)

Events_M_Out_df.columns = Events_M_Out_df.columns.str.strip().str.lower()

Events_M_Out_df
# Out:
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/688641035.py:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_M_Out_df['Date'] = Events_M_Out_df['Date'].str.replace('8:.05','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/688641035.py:11: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_M_Out_df['Date'] = Events_M_Out_df['Date'].str.replace('7:.05','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/688641035.py:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_M_Out_df['Date'] = Events_M_Out_df['Date'].str.replace('at.05','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/688641035.py:15: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Events_M_Out_df['Price'] = Events_M_Out_df['Price'].str.replace('$',' ')
#                                                 name      date price  \
# 1  swedish lake: join us on an idyllic hike aroun...  Tomorrow    15
# 2  mystic river: venture into haunted forests and...     28.05   14
#
#                                                links
# 1  https://www.eventbrite.de/e/swedish-lake-join-...
# 2  https://www.eventbrite.de/e/mystic-river-ventu...

# %% [markdown]
# #### NO-FREE Events from Eventbrite in Berlin;
# #### Month: June (J);
# #### Category: Outdoor (Out).

# %%
# A list with all the Event Names in June

Events_Names_J_Out = []
Events_Dates_J_Out = []
Events_Links_J_Out = []
Events_Preices_J_Out = []


for i in range(1,28):
    url = 'https://www.eventbrite.com/d/germany--berlin/travel-and-outdoor--events--next-month/paid-events/?page='
    url = url + str(i) 
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    names = soup.select('div.eds-is-hidden-accessible')[1::2]
    dates = soup.select('.eds-event-card-content__sub-title')[1::2]
    links = soup.select('.eds-event-card-content__action-link')[1::4]
    for name in names:
        Events_Names_J_Out.append(name.get_text(strip=True).lower())
    for date in dates:
        Events_Dates_J_Out.append(date.get_text(strip=True)[9:11].lower())
    for link in links:
        Events_Links_J_Out.append(link['href'])

        # EVENTS PRICES
    price_links = soup.select('.eds-event-card-content__primary-content a')[1::2]

    for price in price_links:
        response = requests.get(price['href'])
        soup = BeautifulSoup(response.content, 'html.parser')
        eprice = soup.select('.js-display-price')
    # print(price[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0])
        Events_Preices_J_Out.append(eprice[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0]) 
    

print(len(Events_Names_J_Out))
print(len(Events_Dates_J_Out))
print(len(Events_Links_J_Out))
print(len(Events_Preices_J_Out))
# Out:
# 3
# 3
# 3
# 3

# %%
# Make dictionary, keys that will become dataframe column names
Events_J_dict = {'Name':Events_Names_J_Out, 'Date':Events_Dates_J_Out, 'Price':Events_Preices_J_Out, 'Links':Events_Links_J_Out}

# Convert dictionary to Pandas dataframe
Events_J_Out_df = pd.DataFrame(Events_J_dict)
Events_J_Out_df.index = Events_J_Out_df.index + 1

Events_J_Out_df['Date'] = Events_J_Out_df['Date'].astype(str)+'.06'
Events_J_Out_df['Date'] = Events_J_Out_df['Date'].str.replace(',','')
Events_J_Out_df['Date'] = Events_J_Out_df['Date'].str.replace('8:.06','Tomorrow')
Events_J_Out_df['Date'] = Events_J_Out_df['Date'].str.replace('7:.06','Tomorrow')
Events_J_Out_df['Date'] = Events_J_Out_df['Date'].str.replace('at.06','Tomorrow')
Events_J_Out_df.drop(Events_J_Out_df.loc[Events_J_Out_df['Price']== '0€'].index, inplace=True)
Events_J_Out_df['Price'] = Events_J_Out_df['Price'].str.replace('€',' ')
Events_J_Out_df['Price'] = Events_J_Out_df['Price'].str.replace('$',' ')
Events_J_Out_df['Price'] = Events_J_Out_df['Price'].str.replace('£',' ')


Events_J_Out_df.drop(Events_J_Out_df.loc[Events_J_Out_df['Price']== 'Free'].index, inplace=True)
Events_J_Out_df.drop(Events_J_Out_df.loc[Events_J_Out_df['Price']== 'Kostenlos'].index, inplace=True)
Events_J_Out_df.drop(Events_J_Out_df.loc[Events_J_Out_df['Price']== '0'].index, inplace=True)

Events_J_Out_df.columns = Events_J_Out_df.columns.str.strip().str.lower()

Events_J_Out_df
# Out:
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/2558427280.py:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_J_Out_df['Date'] = Events_J_Out_df['Date'].str.replace('8:.06','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/2558427280.py:11: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_J_Out_df['Date'] = Events_J_Out_df['Date'].str.replace('7:.06','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/2558427280.py:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   Events_J_Out_df['Date'] = Events_J_Out_df['Date'].str.replace('at.06','Tomorrow')
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/2558427280.py:15: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Events_J_Out_df['Price'] = Events_J_Out_df['Price'].str.replace('$',' ')
#                                                 name   date price  \
# 1  swedish lake: join us on an idyllic hike aroun...  19.06    15
# 2  mystic river: venture into haunted forests and...  26.06   14
#
#                                                links
# 1  https://www.eventbrite.de/e/swedish-lake-join-...
# 2  https://www.eventbrite.de/e/mystic-river-ventu...

# %% [markdown]
# #### NO-FREE Events from Eventbrite in Berlin;
# #### Month: July (JL);
# #### Category: Outdoor (Out).

# %%
# A list with all the Event Names in July

Events_Names_JL_Out = []
Events_Dates_JL_Out = []
Events_Links_JL_Out = []
Events_Prices_JL_Out = []

for i in range(1,28):
    url = 'https://www.eventbrite.com/d/germany--berlin/travel-and-outdoor--events/paid-events/?page='
    url = url + str(i) + '&start_date=2022-07-01&end_date=2022-07-31'
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    names = soup.select('div.eds-is-hidden-accessible')[1::2]
    dates = soup.select('.eds-event-card-content__sub-title')[1::2]
    links = soup.select('.eds-event-card-content__action-link')[1::4]
    for name in names:
        Events_Names_JL_Out.append(name.get_text(strip=True).lower())
    for date in dates:
        Events_Dates_JL_Out.append(date.get_text(strip=True)[9:11].lower())
    for link in links:
        Events_Links_JL_Out.append(link['href'])

        
# EVENTS PRICES
    price_links = soup.select('.eds-event-card-content__primary-content a')[1::2]

    for price in price_links:
        response = requests.get(price['href'])
        soup = BeautifulSoup(response.content, 'html.parser')
        eprice = soup.select('.js-display-price')
    # print(price[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0])
        Events_Prices_JL_Out.append(eprice[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0]) 
    
    
print(len(Events_Names_JL_Out))
print(len(Events_Dates_JL_Out))
print(len(Events_Links_JL_Out))
print(len(Events_Prices_JL_Out))
# Out:
# 1
# 1
# 1
# 1

# %%
# Make dictionary, keys that will become dataframe column names
Events_JL_dict = {'Name':Events_Names_JL_Out, 'Date':Events_Dates_JL_Out, 'Price': Events_Prices_JL_Out, 'Links':Events_Links_JL_Out}

# Convert dictionary to Pandas dataframe
Events_JL_Out_df = pd.DataFrame(Events_JL_dict)
Events_JL_Out_df.index = Events_JL_Out_df.index + 1
Events_JL_Out_df['Date'] = Events_JL_Out_df['Date'].str.replace('at','Tomorrow')
Events_JL_Out_df['Date'] = Events_JL_Out_df['Date'].str.replace(',','')

Events_JL_Out_df.drop(Events_JL_Out_df.loc[Events_JL_Out_df['Price']== 'Free'].index, inplace=True)
Events_JL_Out_df.drop(Events_JL_Out_df.loc[Events_JL_Out_df['Price']== 'Kostenlos'].index, inplace=True)
Events_JL_Out_df.drop(Events_JL_Out_df.loc[Events_JL_Out_df['Price']== '0€'].index, inplace=True)

Events_JL_Out_df.columns = Events_JL_Out_df.columns.str.strip().str.lower()

Events_JL_Out_df
# Out:
# Empty DataFrame
# Columns: [name, date, price, links]
# Index: []

# %% [markdown]
# #### NO-FREE Events from Eventbrite in Berlin;
# #### Month: August (A);
# #### Category: Outdoor (Out).

# %%
# A list with all the Event Names in August

Events_Names_A_Out = []
Events_Dates_A_Out = []
Events_Links_A_Out = []
Events_Price_A_Out = []

for i in range(1,28):
    url = 'https://www.eventbrite.com/d/germany--berlin/travel-and-outdoor--events/paid-events/?end_date=2022-08-31&page='
    url = url + str(i) + '&start_date=2022-08-01'
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    names = soup.select('div.eds-is-hidden-accessible')[1::2]
    dates = soup.select('.eds-event-card-content__sub-title')[1::2]
    links = soup.select('.eds-event-card-content__action-link')[1::4]
    
    for name in names:
        Events_Names_A_Out.append(name.get_text(strip=True).lower())
    for date in dates:
        Events_Dates_A_Out.append(date.get_text(strip=True)[9:11].lower())
    for link in links:
        Events_Links_A_Out.append(link['href'])

        
        # EVENTS PRICES
    price_links = soup.select('.eds-event-card-content__primary-content a')[1::2]

    for price in price_links:
        response = requests.get(price['href'])
        soup = BeautifulSoup(response.content, 'html.parser')
        eprice = soup.select('.js-display-price')
    # print(price[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0])
        Events_Price_A_Out.append(eprice[0].get_text(strip=True).replace(u'\xa0', ' ').replace(' ', '').split('–')[0]) 
    
    
    
print(len(Events_Names_A_Out))
print(len(Events_Dates_A_Out))
print(len(Events_Links_A_Out))
print(len(Events_Price_A_Out))
# Out:
# 1
# 1
# 1
# 1

# %%
# Make dictionary, keys that will become dataframe column names
Events_A_dict = {'Name':Events_Names_A_Out, 'Date':Events_Dates_A_Out, 'Price': Events_Price_A_Out, 'Links':Events_Links_A_Out}

# Convert dictionary to Pandas dataframe
Events_A_Out_df = pd.DataFrame(Events_A_dict)
Events_A_Out_df.index = Events_A_Out_df.index + 1
Events_A_Out_df['Date'] = Events_A_Out_df['Date'].str.replace('at','Tomorrow')
Events_A_Out_df['Date'] = Events_A_Out_df['Date'].str.replace(',','')

Events_A_Out_df.drop(Events_A_Out_df.loc[Events_A_Out_df['Price']== 'Free'].index, inplace=True)
Events_A_Out_df.drop(Events_A_Out_df.loc[Events_A_Out_df['Price']== 'Kostenlos'].index, inplace=True)
Events_A_Out_df.drop(Events_A_Out_df.loc[Events_A_Out_df['Price']== '0€'].index, inplace=True)

Events_A_Out_df.columns = Events_A_Out_df.columns.str.strip().str.lower()

Events_A_Out_df
# Out:
# Empty DataFrame
# Columns: [name, date, price, links]
# Index: []

# %% [markdown]
# ### All Music Events

# %%
paid_music_events = pd.concat([Events_May_M_df, Events_July_M_df, Events_June_M_df, Events_Aug_M_df], ignore_index=True)
paid_music_events.index +=1
paid_music_events
# Out:
#                                                  name      date   price  \
# 1   kiezsalon opening w/ tarta relena and jason sharp  Tomorrow  11,29
# 2   kiezsalon opening w/ richard skelton and booke...  Tomorrow  11,29
# 3                                        banana party     10.05     15
# 4                         cdc festival boatride party     28.05   43.80
# 5              wahn: music, words, dance, performance     27.05   11.83
# ..                                                ...       ...     ...
# 91        halli-galli-party in fürstenberg * open air     27.08   8,79
# 92                                      ü33 1/3 party      6.08  31,96
# 93                     dance baby (black meets house)     20.08  31,96
# 94  dancing with myself | 80er party • factory mag...     27.08   9,70
# 95                         summer dream festival 2022      5.08  62,70
#
#                                                 links
# 1   https://www.eventbrite.de/e/kiezsalon-opening-...
# 2   https://www.eventbrite.de/e/kiezsalon-opening-...
# 3   https://www.eventbrite.com/e/banana-party-tick...
# 4   https://www.eventbrite.de/e/cdc-festival-boatr...
# 5   https://www.eventbrite.de/e/wahn-music-words-d...
# ..                                                ...
# 91  https://www.eventbrite.de/e/halli-galli-party-...
# 92  https://www.eventbrite.com/e/u33-13-party-tick...
# 93  https://www.eventbrite.com/e/dance-baby-black-...
# 94  https://www.eventbrite.de/e/dancing-with-mysel...
# 95  https://www.eventbrite.de/e/summer-dream-festi...
#
# [95 rows x 4 columns]

# %% [markdown]
# ### All Community Events

# %%
paid_community_events = pd.concat([Events_M_C_df, Events_J_C_df, Events_JL_C_df, Events_A_C_df], ignore_index=True)
paid_community_events.index +=1
paid_community_events
# Out:
#                                                  name      date     price  \
# 1                                  gypsy tales berlin     28.05     22.49
# 2      silent.move walk'n'dance disco tour // berlin.  Tomorrow    11,90
# 3           "act out!" - die geister, die uns riefen!     11.05  Donation
# 4                                     iwb may meet-up     25.05     11.83
# 5                                       sunday slips!     22.05  Donation
# 6                     black aspiring creators meet up     5:.05        10
# 7                   slam des westens #114 in the dark     25.05     7,57
# 8   noite cabo-verdiana/ stand up comedy com carlo...     28.05       25
# 9   fundraising im chor | das 1x1 der antragsstellung  Tomorrow       25
# 10      germania, berygtede bunkere og naziarkitektur     28.05     11.83
# 11                            dichterasse poetry slam     28.05     7,57
# 12  the 'pathology of freedom': colonialism and ps...     26.05     11.83
# 13  city walking tour - das afrikanische viertel i...  Tomorrow        0
# 14  hip berlin underground tour - street art, club...     10.05     81.09
# 15        freddy fischer and his cosmic rocktime band  Tomorrow    14,61
# 16  frauen schreiben anders – begegnung mit irakis...  Tomorrow        0
# 17                                      help with art     12.05  Donation
# 18                 konzert blue side park & kawa kawa     26.05       10
# 19                                      sunday slips!      5.06  Donation
# 20           unshaved bear summer berlin edition 2022     25.06    12,79
# 21                date deficient - vegan dating night      2.06       15
# 22                           bearground - leider geil      5.06    21,43
# 23     silent.move walk'n'dance disco tour // berlin.      3.06    11,90
# 24       juneteenth unity festival picnic in the park     19.06     15.25
# 25                           zim community summer bbq      4.06         5
# 26                        kopftuchmädchen b-day event      4.06    29,99
# 27                    liliana velásquez & chris davis      1.06     11.68
# 28                                dinner confidential     29.06     17.17
# 29  hip berlin underground tour - street art, club...      2.06     81.09
# 30                             freiland festival 2022      3.06       99
# 31  1st global local guide & content creator conve...      3.06  Donation
# 32                                      sunday slips!      3.07  Donation
# 33                         the black wall street gala      9.07    49,13
# 34     silent.move walk'n'dance disco tour // berlin.      1.07    11,90
# 35  hip berlin underground tour - street art, club...      1.07     81.09
# 36                                      sunday slips!      7.08  Donation
# 37     silent.move walk'n'dance disco tour // berlin.      5.08    11,90
# 38                   whipped cream - untertage berlin     27.08       19
# 39  hip berlin underground tour - street art, club...      4.08     81.09
#
#                                                 links
# 1   https://www.eventbrite.co.uk/e/gypsy-tales-ber...
# 2   https://www.eventbrite.de/e/silentmove-walknda...
# 3   https://www.eventbrite.de/e/act-out-die-geiste...
# 4   https://www.eventbrite.de/e/iwb-may-meet-up-ti...
# 5   https://www.eventbrite.de/e/sunday-slips-ticke...
# 6   https://www.eventbrite.ca/e/black-aspiring-cre...
# 7   https://www.eventbrite.de/e/slam-des-westens-1...
# 8   https://www.eventbrite.de/e/bilhetes-noite-cab...
# 9   https://www.eventbrite.de/e/fundraising-im-cho...
# 10  https://www.eventbrite.de/e/germania-berygtede...
# 11  https://www.eventbrite.de/e/dichterasse-poetry...
# 12  https://www.eventbrite.co.uk/e/the-pathology-o...
# 13  https://www.eventbrite.de/e/city-walking-tour-...
# 14  https://www.eventbrite.de/e/hip-berlin-undergr...
# 15  https://www.eventbrite.de/e/freddy-fischer-and...
# 16  https://www.eventbrite.de/e/frauen-schreiben-a...
# 17  https://www.eventbrite.de/e/help-with-art-tick...
# 18  https://www.eventbrite.de/e/konzert-blue-side-...
# 19  https://www.eventbrite.de/e/sunday-slips-ticke...
# 20  https://www.eventbrite.de/e/unshaved-bear-summ...
# 21  https://www.eventbrite.de/e/date-deficient-veg...
# 22  https://www.eventbrite.de/e/bearground-leider-...
# 23  https://www.eventbrite.de/e/silentmove-walknda...
# 24  https://www.eventbrite.de/e/juneteenth-unity-f...
# 25  https://www.eventbrite.com/e/zim-community-sum...
# 26  https://www.eventbrite.com/e/kopftuchmadchen-b...
# 27  https://www.eventbrite.de/e/liliana-velasquez-...
# 28  https://www.eventbrite.com/e/dinner-confidenti...
# 29  https://www.eventbrite.de/e/hip-berlin-undergr...
# 30  https://www.eventbrite.de/e/freiland-festival-...
# 31  https://www.eventbrite.de/e/1st-global-local-g...
# 32  https://www.eventbrite.de/e/sunday-slips-ticke...
# 33  https://www.eventbrite.de/e/the-black-wall-str...
# 34  https://www.eventbrite.de/e/silentmove-walknda...
# 35  https://www.eventbrite.de/e/hip-berlin-undergr...
# 36  https://www.eventbrite.de/e/sunday-slips-ticke...
# 37  https://www.eventbrite.de/e/silentmove-walknda...
# 38  https://www.eventbrite.de/e/whipped-cream-unte...
# 39  https://www.eventbrite.de/e/hip-berlin-undergr...

# %% [markdown]
# ### All Film Events

# %%
paid_film_events = pd.concat([Events_M_Cin_df, Events_J_Cin_df, Events_JL_Cin_df, Events_A_Cin_df], ignore_index=True)
paid_film_events.index +=1
paid_film_events
# Out:
#                                                  name      date     price  \
# 1          english comedy berlin with pizza and shots  Tomorrow    22,51
# 2   english stand up comedy - culture shock specia...  Tomorrow     12.54
# 3           that's what she said - womxn comedy night  Tomorrow        16
# 4            new york comedy club - berlin: main show     23.05      2.14
# 5     comedy roulette | the ultimate comedy game show  Tomorrow        13
# 6   laughing spree: english comedy on a boat (free...     24.05      2.13
# 7         expats in berlin #35  - english comedy show     26.05      8.55
# 8   new york comedy club - berlin: late show - dar...     23.05      2.14
# 9   high bars & low morals. english comedy special...     22.05        10
# 10  hook, value and emotions. video content in 202...     25.05         0
# 11  tati comedy - die stand up comedy show in berl...     28.05    14,90
# 12                movie: mee vasantrao  -  मी वसंतराव  Tomorrow     13.86
# 13  https://www.eventbrite.de/e/english-comedy-ber...      3.06    22,51
# 14  https://www.eventbrite.co.uk/e/english-stand-u...     18.06     11.77
# 15  https://www.eventbrite.de/e/berlin-music-video...      8.06     22.49
# 16  https://www.eventbrite.de/e/berlin-freak-burle...     10.06       30
# 17  https://www.eventbrite.de/e/yaaas-queen-womxn-...      8.06        14
# 18  https://www.eventbrite.com/e/new-york-comedy-c...     27.06      2.14
# 19  https://www.eventbrite.co.uk/e/english-stand-u...      4.06     12.54
# 20  https://www.eventbrite.de/e/thats-what-she-sai...     25.06        16
# 21  https://www.eventbrite.de/e/three-way-show-ele...     17.06        13
# 22  https://www.eventbrite.de/e/laughing-spree-eng...     12.06      2.26
# 23  https://www.eventbrite.com/e/new-york-comedy-c...      6.06      2.14
# 24  https://www.eventbrite.com/e/the-witching-hour...      4.06  Donation
# 25  https://www.eventbrite.co.uk/e/expats-in-berli...      2.06      2.28
# 26  https://www.eventbrite.de/e/kat-nip-presents-l...     24.06        10
# 27  https://www.eventbrite.co.uk/e/gamesforum-berl...     15.06       240
# 28  https://www.eventbrite.de/e/boys-do-cry-standu...     26.06         8
# 29         english comedy berlin with pizza and shots      1.07    22,51
# 30         yaaas queen! | womxn & lgbtq+ comedy night     13.07        14
# 31                                  the witching hour      2.07  Donation
# 32                              movie campout weekend      1.07        10
# 33                                  the witching hour      6.08  Donation
#
#                                                 links
# 1   https://www.eventbrite.de/e/english-comedy-ber...
# 2   https://www.eventbrite.co.uk/e/english-stand-u...
# 3   https://www.eventbrite.de/e/thats-what-she-sai...
# 4   https://www.eventbrite.com/e/new-york-comedy-c...
# 5   https://www.eventbrite.de/e/comedy-roulette-th...
# 6   https://www.eventbrite.de/e/laughing-spree-eng...
# 7   https://www.eventbrite.co.uk/e/expats-in-berli...
# 8   https://www.eventbrite.com/e/new-york-comedy-c...
# 9   https://www.eventbrite.com/e/high-bars-low-mor...
# 10  https://www.eventbrite.de/e/hook-value-and-emo...
# 11  https://www.eventbrite.de/e/tati-comedy-die-st...
# 12  https://www.eventbrite.de/e/movie-mee-vasantra...
# 13  https://www.eventbrite.de/e/english-comedy-ber...
# 14  https://www.eventbrite.co.uk/e/english-stand-u...
# 15  https://www.eventbrite.de/e/berlin-music-video...
# 16  https://www.eventbrite.de/e/berlin-freak-burle...
# 17  https://www.eventbrite.de/e/yaaas-queen-womxn-...
# 18  https://www.eventbrite.com/e/new-york-comedy-c...
# 19  https://www.eventbrite.co.uk/e/english-stand-u...
# 20  https://www.eventbrite.de/e/thats-what-she-sai...
# 21  https://www.eventbrite.de/e/three-way-show-ele...
# 22  https://www.eventbrite.de/e/laughing-spree-eng...
# 23  https://www.eventbrite.com/e/new-york-comedy-c...
# 24  https://www.eventbrite.com/e/the-witching-hour...
# 25  https://www.eventbrite.co.uk/e/expats-in-berli...
# 26  https://www.eventbrite.de/e/kat-nip-presents-l...
# 27  https://www.eventbrite.co.uk/e/gamesforum-berl...
# 28  https://www.eventbrite.de/e/boys-do-cry-standu...
# 29  https://www.eventbrite.de/e/english-comedy-ber...
# 30  https://www.eventbrite.de/e/yaaas-queen-womxn-...
# 31  https://www.eventbrite.com/e/the-witching-hour...
# 32  https://www.eventbrite.com/e/movie-campout-wee...
# 33  https://www.eventbrite.com/e/the-witching-hour...

# %% [markdown]
# ### All Science Events

# %%
paid_science_events = pd.concat([Events_M_S_df, Events_J_S_df, Events_JL_S_df, Events_A_S_df], ignore_index=True)
paid_science_events.index +=1
paid_science_events
# Out:
#                                                 name   date    price  \
# 1                                    prisma day 2022  16.06        0
# 2                   :clojured berlin conference 2022  11.06       79
# 3                       openinfra summit berlin 2022   7.06    1,199
# 4  workshop - introduction to laser cutting and e...   2.06    70.23
# 5       gophercon europe 2022 - online and in-person  28.07   126.72
# 6  4th edition - sx tech eu conference - berlin -...  31.08    74.70
#
#                                                links
# 1  https://www.eventbrite.com/e/prisma-day-2022-t...
# 2  https://www.eventbrite.de/e/clojured-berlin-co...
# 3  https://www.eventbrite.com/e/openinfra-summit-...
# 4  https://www.eventbrite.de/e/workshop-introduct...
# 5  https://www.eventbrite.com/e/gophercon-europe-...
# 6  https://www.eventbrite.ie/e/4th-edition-sx-tec...

# %% [markdown]
# ### All Sport Events

# %%
paid_sport_events = pd.concat([Events_M_Sp_df, Events_J_Sp_df], ignore_index=True)
paid_sport_events.index +=1
paid_sport_events
# Out:
#                                                  name      date   price  \
# 1   peacock’s paradise: discover an island full of...  Tomorrow     15
# 2   nature games in grunewald: let out your inner ...  Tomorrow     15
# 3   nature cycling: explore one of the most famous...     27.05     19
# 4   hiit the road berlin by growingannanas + live ...  Tomorrow   39.99
# 5   urban foraging: discover the edible treasures ...  Tomorrow     23
# 6   spreewald canoe tour: discover the unesco bios...     28.05     27
# 7   peacock’s paradise: discover an island full of...     11.06     15
# 8   fairytale forest: hike through the mystical la...      5.06      16
# 9   water world: enjoy a day in the gorgeous river...      4.06     15
# 10  spreewald canoe tour: discover the unesco bios...     12.06     27
#
#                                                 links
# 1   https://www.eventbrite.de/e/peacocks-paradise-...
# 2   https://www.eventbrite.de/e/nature-games-in-gr...
# 3   https://www.eventbrite.de/e/nature-cycling-exp...
# 4   https://www.eventbrite.de/e/hiit-the-road-berl...
# 5   https://www.eventbrite.de/e/urban-foraging-dis...
# 6   https://www.eventbrite.de/e/spreewald-canoe-to...
# 7   https://www.eventbrite.de/e/peacocks-paradise-...
# 8   https://www.eventbrite.de/e/fairytale-forest-h...
# 9   https://www.eventbrite.de/e/water-world-enjoy-...
# 10  https://www.eventbrite.de/e/spreewald-canoe-to...

# %% [markdown]
# ### All Outdoor Events

# %%
paid_out_events = pd.concat([Events_M_Out_df, Events_J_Out_df, Events_JL_Out_df, Events_A_Out_df], ignore_index=True)
paid_out_events.index +=1
paid_out_events = paid_out_events.append({'price': '€'}, ignore_index=True)
paid_out_events
# Out:
# /var/folders/58/4zdn6_kx1rz1scwtmmkg83kr0000gn/T/ipykernel_27490/657426963.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   paid_out_events = paid_out_events.append({'price': '€'}, ignore_index=True)
#                                                 name      date price  \
# 0  swedish lake: join us on an idyllic hike aroun...  Tomorrow    15
# 1  mystic river: venture into haunted forests and...     28.05   14
# 2  swedish lake: join us on an idyllic hike aroun...     19.06    15
# 3  mystic river: venture into haunted forests and...     26.06   14
# 4                                                NaN       NaN     €
#
#                                                links
# 0  https://www.eventbrite.de/e/swedish-lake-join-...
# 1  https://www.eventbrite.de/e/mystic-river-ventu...
# 2  https://www.eventbrite.de/e/swedish-lake-join-...
# 3  https://www.eventbrite.de/e/mystic-river-ventu...
# 4                                                NaN

# %% [markdown]
# #### Save all the DataFrames by pickle

# %%
import pickle

# to save the file
paid_music_events.to_pickle("paid_music")

# to open the file
# unpickled_df = pd.read_pickle("free_sport")
paid_community_events.to_pickle("paid_community")
paid_film_events.to_pickle("paid_film")
paid_science_events.to_pickle("paid_science")
paid_sport_events.to_pickle("paid_sport")
paid_out_events.to_pickle("paid_travel_out")

# %% [markdown]
# ## ALL PAID EVENTS

# %%
all_paid_events = pd.concat([paid_music_events, paid_community_events, paid_film_events, paid_science_events, paid_sport_events, paid_out_events], ignore_index=True)
all_paid_events.index +=1
all_paid_events
# Out:
#                                                   name      date   price  \
# 1    kiezsalon opening w/ tarta relena and jason sharp  Tomorrow  11,29
# 2    kiezsalon opening w/ richard skelton and booke...  Tomorrow  11,29
# 3                                         banana party     10.05     15
# 4                          cdc festival boatride party     28.05   43.80
# 5               wahn: music, words, dance, performance     27.05   11.83
# ..                                                 ...       ...     ...
# 184  swedish lake: join us on an idyllic hike aroun...  Tomorrow      15
# 185  mystic river: venture into haunted forests and...     28.05     14
# 186  swedish lake: join us on an idyllic hike aroun...     19.06      15
# 187  mystic river: venture into haunted forests and...     26.06     14
# 188                                                NaN       NaN       €
#
#                                                  links
# 1    https://www.eventbrite.de/e/kiezsalon-opening-...
# 2    https://www.eventbrite.de/e/kiezsalon-opening-...
# 3    https://www.eventbrite.com/e/banana-party-tick...
# 4    https://www.eventbrite.de/e/cdc-festival-boatr...
# 5    https://www.eventbrite.de/e/wahn-music-words-d...
# ..                                                 ...
# 184  https://www.eventbrite.de/e/swedish-lake-join-...
# 185  https://www.eventbrite.de/e/mystic-river-ventu...
# 186  https://www.eventbrite.de/e/swedish-lake-join-...
# 187  https://www.eventbrite.de/e/mystic-river-ventu...
# 188                                                NaN
#
# [188 rows x 4 columns]

# %%
all_paid_events.to_pickle("all_paid_events")
